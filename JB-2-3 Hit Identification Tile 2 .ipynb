# %%
# Hit Identification Plots (JB-2-3 Plate 01, Plate 02)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set color for all histograms
    color = '#1f77b4'

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7, width=0.7)
    ax.set_xlabel('')
    ax.set_ylabel(' AUC (a.u)')
    plt.tight_layout()
    plt.show()

#All plots degradation  Reaction Data
data = [[0,0], [7514.8156,8817.209, 8069.5032],  [14560.688], [8373.5807, 8817.2096, 8069.5032,10325.1842], [11738.5831], [12027.5909], [12300.3937], [12008.7951]
        , [12310.1452], [12697.7327], [12900.0757], [12278.4162], [14053.4834], [15464.2363]]
     
labels = ['Sterile', 'P01 Parent (HetCPIII)', 'P01 B6', 'P02 Parent (HetCPIII)',  'P02 G12', 'P02 H05',  'P02 G3', 'P02 G4', 'P02 B6', 'P02 H03', 'P02 E03', 'PO2 F03', 'PO2 H8', 'P02 H2']

plot_histogram_with_std(data, labels)

# %%
# Hit Identification Plots (JB-2-3 Plate 03, Plate 04, Plate 05)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set color for all histograms
    color = '#1f77b4'

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7, width=0.7)
    ax.set_xlabel('')
    ax.set_ylabel(' AUC (a.u)')
    plt.tight_layout()
    plt.show()

#All plots degradation  Reaction Data
data = [[0,0], [13588.9121, 8302.8756, 5275.9534, 5769.6867],  [30142.7111], [13444.0772], [13777.7682], [13119.9106],[13870.882, 11127.9118, 12072.5029, 12704.1287], [15469.598], [2672.1747, 3009.8836, 4223.7298, 4004.7927],
        [13552.2061], [7966.0394], [6337.079], [5823.0712], [5842.8578], [5094.0496], [5283.0799]]
     
labels = ['Sterile', 'PO3 Parent (HetCPIII)', 'P03 G1', 'P03 D12', 'P03 F1',  'P03 C1', 'PO4 Parent (HetCPIII)',
          'P04 H2', 'PO5 Parent (HetCPIII)', 'P05 A9', 'P05 D12', 'P05 C10', 'P05 C9', 'P05 H6', 'P05 F9','P05 G11']

plot_histogram_with_std(data, labels)

# %%
# Hit Identification Plots (JB-2-3 Plate 06, Plate 07)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set color for all histograms
    color = '#1f77b4'

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7, width=0.7)
    ax.set_xlabel('')
    ax.set_ylabel(' AUC (a.u)')
    plt.tight_layout()
    plt.show()

#All plots degradation  Reaction Data
data = [[0,0], [6851.4857,9210.7326, 7598.7189, 9385.0151],  [32844.6457], [15241.5842], [14776.3208], [14593.9039],[13614.0662], [13750.2497], [13236.7283],
        [11566.0028], [11803.9531], [9434.7409], [12468.6091, 11528.7346, 15341.0468, 14049.9032], [46767.0229]]
     
labels = ['Sterile', 'PO6 Parent (HetCPIII)', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1',
          'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'PO7 Parent (HetCPIII)', 'P07 B4']

plot_histogram_with_std(data, labels)

# %%
# Hit Identification Plots (JB-2-3 Plate 08)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set color for all histograms
    color = '#1f77b4'

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7, width=0.7)
    ax.set_xlabel('')
    ax.set_ylabel(' AUC (a.u)')
    plt.tight_layout()
    plt.show()

#All plots degradation  Reaction Data
data = [[0,0], [4791.2899, 8674.7857, 9206.9229, 10690.8233], [43341.124], [21039.9126], [20549.8785], [19377.8997],[23979.6803], [15046.8797], [15203.5771],
        [14960.5631], [12355.1317], [13612.0151], [12763.5616], [12285.9711]]
     
labels = ['Sterile', 'P08 Parent (HetCPIII)', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A5',
          'P08 A10', 'P08 F1', 'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9']

plot_histogram_with_std(data, labels)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4', '#2ca02c']

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=colors[0], alpha=0.7)
    for i in range(len(labels)):
        ax.errorbar(
            i,
            df.loc[i, 'Mean'],
            yerr=df.loc[i, 'Std Deviation'],
            fmt='none',
            capsize=4,
            capthick=1,
            ecolor='black',
            color=colors[i % len(colors)]  # Alternate between blue and green
        )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# All plots degradation Reaction Data
data = [[0, 0], [13588.9121, 8302.8756, 5275.9534, 5769.6867], [30142.7111], [13444.0772], [13777.7682], [13119.9106], [13870.882, 11127.9118, 12072.5029, 12704.1287], [15469.598], [2672.1747, 3009.8836, 4223.7298, 4004.7927],
        [13552.2061], [7966.0394], [6337.079], [5823.0712], [5842.8578], [5094.0496], [5283.0799]]

labels = ['Sterile', 'PO3 Parent (HetCPIII)', 'P03 G1', 'P03 D12', 'P03 F1',  'P03 C1', 'PO4 Parent (HetCPIII)',
          'P04 H2', 'PO5 Parent (HetCPIII)', 'P05 A9', 'P05 D12', 'P05 C10', 'P05 C9', 'P05 H6', 'P05 F9', 'P05 G11']

plot_histogram_with_std(data, labels)

# %%
# Monocyclopropanation activity P03-05
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 6] else '#008000' if i in [1, 7] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# All plots degradation Reaction Data
data = [[0, 0], [13588.9121, 8302.8756, 5275.9534, 5769.6867], [30142.7111], [13444.0772], [13777.7682], [13119.9106], [143.1942, 129.6363],
        [13870.882, 11127.9118, 12072.5029, 12704.1287], [15469.598], [0,0], 
        [2672.1747, 3009.8836, 4223.7298, 4004.7927],
        [13552.2061], [7966.0394], [6337.079], [5823.0712], [5842.8578], [5094.0496], [5283.0799]]

labels = ['P03 Sterile', 'P03 Parent (HetCPIII)', 'P03 G1', 'P03 D12', 'P03 F1',  'P03 C1', 'P04 Sterile', 
          'P04 Parent (HetCPIII)',
          'P04 H2', 'P05 Stile', 'P05 Parent (HetCPIII)', 'P05 A9', 'P05 D12', 'P05 C10', 'P05 C9', 'P05 H6', 'P05 F9', 'P05 G11']

plot_histogram_with_std(data, labels)

# %%
# Monocyclopropanation activity P01-02

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 3] else '#008000' if i in [1, 4] else '#1f77b4' for i in range(len(labels))]
    
    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
data = [[0,0], [7514.8156,8817.209, 8069.5032],  [14560.688], [0], [8373.5807, 8817.2096, 8069.5032,10325.1842], [11738.5831], [12027.5909], [12300.3937], [12008.7951]
        , [12310.1452], [12697.7327], [12900.0757], [12278.4162], [14053.4834], [15464.2363]]
     
labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 B6', 'P02 Sterile', 'P02 Parent (HetCPIII)',  'P02 G12', 'P02 H05',  'P02 G3', 'P02 G4', 'P02 B6', 'P02 H03', 'P02 E03', 'PO2 F03', 'PO2 H8', 'P02 H2']

plot_histogram_with_std(data, labels)

# %%
#Monocyclopropanation P06-P07

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 12] else '#008000' if i in [1, 13] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

#All plots degradation  Reaction Data
data = [[0,0], [6851.4857,9210.7326, 7598.7189, 9385.0151],  [32844.6457], [15241.5842], [14776.3208], [14593.9039],[13614.0662], [13750.2497], [13236.7283],
        [11566.0028], [11803.9531], [9434.7409], [0,0], [12468.6091, 11528.7346, 15341.0468, 14049.9032], [46767.0229]]
     
labels = ['P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1',
          'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 B4']

plot_histogram_with_std(data, labels)

# %%
#Monocyclopropanation P08

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    #Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 6] else '#008000' if i in [1, 7] else '#1f77b4' for i in range(len(labels))]


    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


#All plots degradation  Reaction Data
data = [[0,0], [4791.2899, 8674.7857, 9206.9229, 10690.8233], [43341.124], [21039.9126], [20549.8785], [19377.8997],[23979.6803], [15046.8797], [15203.5771],
        [14960.5631], [12355.1317], [13612.0151], [12763.5616], [12285.9711]]
     
labels = ['Sterile', 'P08 Parent (HetCPIII)', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A5',
          'P08 A10', 'P08 F1', 'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9']

plot_histogram_with_std(data, labels)

# %%
#2CH Functionalization P01-P02

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1,4] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
data = [[0,0], [10628.2728, 8504.8048, 6391.8551, 9312.7596],  [16931.3891], [0,0], [9199.2656, 9739.5467, 8899.8519, 11556.6004], [13332.7391], 
        [13240.2165], [13624.1253], [13458.9466]
        , [14159.9857], [14163.9874], [14521.9117], [17021.6505], [15505.2437], [17044.434]]
     
labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 B6', 'P02 Sterile', 'P02 Parent (HetCPIII)',  'P02 G12', 
          'P02 H05',  'P02 G3', 'P02 G4', 'P02 B6', 'P02 H03', 'P02 E03', 'PO2 F03', 'PO2 H8', 'P02 H2']

plot_histogram_with_std(data, labels)

# %%
#2CH Functionalization P03-P05

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 6, 9] else '#008000' if i in [1, 7, 10] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=5.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# All plots degradation Reaction Data
data = [[193.5299, 0], [15330.8692, 9347.3107, 5941.3745, 6511.3865], [12517.3359], [15890.7235]
        , [15128.5534], [14494.6289],[168.4992, 203.5406], [16243.972, 13585.2946, 14558.4358, 15024.4841], [17852.1734], [0,0],
        [3017.265, 3202.3302, 4637.6704, 4101.3961],[42514.2961], [5529.6209], [6885.4911], 
        [6459.8673], [6084.6977], [5747.9859], [5576.5325]]

labels = ['P03 Sterile', 'P03 Parent (HetCPIII)', 'P03 G1', 'P03 D12', 'P03 F1',  'P03 C1','P04 Sterile', 'P04 Parent (HetCPIII)',
          'P04 H2', 'P05 Sterile',  'P05 Parent (HetCPIII)', 'P05 A9', 'P05 D12', 'P05 C10', 
          'P05 C9', 'P05 H6', 'P05 F9', 'P05 G11']

plot_histogram_with_std(data, labels)

# %%
#2CH Functionalization P06-P07

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 12] else '#008000' if i in [1, 13] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

#All plots degradation  Reaction Data
data = [[0,0], [7121.2405, 9651.1366, 8057.8614, 9790.6065],  [13961.5742], [15717.6738], [15548.6889], 
        [15406.9795],[16024.8576], [14365.1625], [14002.9086],
        [12856.476], [12429.6335], [14127.3188], [0,0], [9245.0612, 9499.4958, 218.855], 
        [22620.9173]]
     
labels = ['P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1',
          'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 B4']

plot_histogram_with_std(data, labels)

# %%
#2CH Functionalization P08

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


#All plots degradation  Reaction Data
data = [[0,0], [5128.6683, 9446.2452, 10158.9029, 11721.7091], [20193.7637], [23873.3695], [24042.5197], 
        [21829.8698],[15248.0161], [17053.4452], [16629.7074],
        [16382.8525], [13749.9993], [15111.6361], [14745.3669], [13676.3802]]
     
labels = ['P08 Sterile', 'P08 Parent (HetCPIII)', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A5',
          'P08 A10', 'P08 F1', 'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9']

plot_histogram_with_std(data, labels)

# %%
#Total Activity Histograms P01-P02 (With AUC)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1,3, 4] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
data = [[0, 0], [17943.0884, 17322.0138, 14461.3583, 19137.2628], [31591.0771], 
        [0,0], [17572.8463, 18556.7563, 16969.3551, 19881.7846], [25071.3222], [25267.8074], 
        [25924.519], [25467.7417], [26470.131], [26861.7201], [27422.9874], [29299.0667],
        [29558.7265], [32508.6703]]



labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 B6', 'P02 Sterile', 'P02 Parent (HetCPIII)',  'P02 G12', 
          'P02 H05',  'P02 G3', 'P02 G4', 'P02 B6', 'P02 H03', 'P02 E03', 'PO2 F03', 'PO2 H8', 'P02 H2']


data_significance_test_P01P02 = [[31591.0771], [25071.3222], [25267.8074], [25467.7417], [25924.519], [26861.7201],[27422.9874], [29299.0667],
        [29558.7265]] 

plot_histogram_with_std(data, labels)


import numpy as np

data = [[0, 0], [17943.0884, 17322.0138, 14461.3583, 19137.2628], [31591.0771],
        [0, 0], [17572.8463, 18556.7563, 16969.3551, 19881.7846], [25071.3222], [25267.8074],
        [25924.519], [25467.7417], [26470.131], [26861.7201], [27422.9874], [29299.0667],
        [29558.7265], [32508.6703]]

# Divide the 2-3rd elements by the average of the second element
data[1:3] = [[x / np.mean(data[1]) for x in sublist] for sublist in data[1:3]]

# Divide the 5-15th elements by the value of the 5th element
data[4:16] = [[x / data[4][0] for x in sublist] for sublist in data[4:16]]

# Create a new variable with the updated values
normalized_data = data

plot_histogram_with_std(normalized_data, labels)

# %%
#Normalized Total Activity Histograms P01-P02 (Not good)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1, 3, 4] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


# All plots degradation Reaction Data
data = [[0, 0], [17943.0884, 17322.0138, 14461.3583, 19137.2628], [31591.0771],
        [0, 0], [17572.8463, 18556.7563, 16969.3551, 19881.7846], [25071.3222], [25267.8074],
        [25924.519], [25467.7417], [26470.131], [26861.7201], [27422.9874], [29299.0667],
        [29558.7265], [32508.6703]]

labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 B6', 'P02 Sterile', 'P02 Parent (HetCPIII)',  'P02 G12',
          'P02 H05',  'P02 G3', 'P02 G4', 'P02 B6', 'P02 H03', 'P02 E03', 'PO2 F03', 'PO2 H8', 'P02 H2']

# Divide the 2-3rd elements by the average of the second element
data[1:3] = [[x / np.mean(data[1]) for x in sublist] for sublist in data[1:3]]

# Divide the 5-15th elements by the value of the 5th element
data[4:16] = [[x / data[4][0] for x in sublist] for sublist in data[4:16]]

# Create a new variable with the updated values
normalized_data = data

plot_histogram_with_std(normalized_data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# Bars above y=1.5: []

# %%
#Normalized Total Activity Histograms P01-P02

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1, 3, 4] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    
    
    # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
    plt.show()


data = [[0, 0], [1.0], [1.780911900452485], [0, 0], [1.0], [1.3703047118755882], [1.3814915575427674], [1.4166337832772017], [1.3916072172440844], [1.4936440972561086], [1.5195220758943638], [1.549307254480581], [1.651616154451387], [1.663802201913504], [1.8333922039267258]]

labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 B6', 'P02 Sterile', 'P02 Parent (HetCPIII)',  'P02 G12',
          'P02 H05',  'P02 G3', 'P02 G4', 'P02 B6', 'P02 H03', 'P02 E03', 'PO2 F03', 'PO2 H8', 'P02 H2']

# Divide the 2-3rd elements by the average of the second element
data[1:3] = [[x / np.mean(data[1]) for x in sublist] for sublist in data[1:3]]

# Divide the 5-15th elements by the value of the 5th element
data[4:16] = [[x / data[4][0] for x in sublist] for sublist in data[4:16]]

# Create a new variable with the updated values
normalized_data = data

plot_histogram_with_std(normalized_data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# Bars above y=1.5: []

# %%
#Total Activity Histograms P03-05 (AUC)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 6, 9] else '#008000' if i in [1, 7, 10] else '#1f77b4' for i in range(len(labels))]
    
    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=5.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
data = [[193.5299, 0], [28919.7813, 17650.1863, 11217.3279, 12281.0732], [42660.047], [29334.8007], 
        [28891.3216], [27614.5395],[311.6934, 333.1769], [30114.854, 24713.2064, 26630.9387, 27728.6128], [33321.7714], 
        [0,0], [5689.4407, 6212.2138, 8861.4002, 8106.1888], [56066.5022], [13495.6603], [13222.5701], 
        [12282.9385], [11927.5555], [10842.0355], [10859.6124]]

labels = ['P03 Sterile', 'P03 Parent (HetCPIII)', 'P03 G1', 'P03 D12', 'P03 F1',  'P03 C1','P04 Sterile', 'P04 Parent (HetCPIII)',
          'P04 H2', 'P05 Sterile',  'P05 Parent (HetCPIII)', 'P05 A9', 'P05 D12', 'P05 C10', 
          'P05 C9', 'P05 H6', 'P05 F9', 'P05 G11']

plot_histogram_with_std(data, labels)

# %%
#Normalized Total Activity Histograms P03-05 (Good One)


import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1, 7, 10] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    
    # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
    plt.show()



# All plots degradation Reaction Data
data = [[193.5299, 0], [28919.7813, 17650.1863, 11217.3279, 12281.0732], [42660.047], [29334.8007], 
        [28891.3216], [27614.5395],[311.6934, 333.1769], [30114.854, 24713.2064, 26630.9387, 27728.6128], [33321.7714], 
        [0,0], [5689.4407, 6212.2138, 8861.4002, 8106.1888], [56066.5022], [13495.6603], [13222.5701], 
        [12282.9385], [11927.5555], [10842.0355], [10859.6124]]

average_2 = sum(data[1]) / len(data[1])
average_8 = sum(data[7]) / len(data[7])
average_11 = sum(data[10]) / len(data[10])

data[1] = [average_2]
data[7] = [average_8]
data[10] = [average_11]


# Perform division on elements 1-6 with the average of element 2
for i in range(0, 5):
    data[i] = [elem / average_2 for elem in data[i]]

# Perform division on elements 6-10 with the value of element 8
for i in range(5, 9):
    data[i] = [elem / average_8 for elem in data[i]]
    
# Perform division on elements 6-10 with the value of element 8
for i in range(9, 18):
    data[i] = [elem / average_11 for elem in data[i]]

print("Updated data array:")
print(data)

labels = ['P03 Sterile', 'P03 Parent (HetCPIII)', 'P03 G1', 'P03 D12', 'P03 F1',  'P03 C1','P04 Sterile', 'P04 Parent (HetCPIII)',
          'P04 H2', 'P05 Sterile',  'P05 Parent (HetCPIII)', 'P05 A9', 'P05 D12', 'P05 C10', 
          'P05 C9', 'P05 H6', 'P05 F9', 'P05 G11']


plot_histogram_with_std(data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# Updated data array:
# [[0.01104806083490281, 0.0], [1.0], [2.435338386863286], [1.6746387132600675], [1.649321777345731], [1.0116363576223613], [0.01141863603667661, 0.012205666712635555], [1.0], [1.2207161900570882], [0.0, 0.0], [1.0], [7.76833687380828], [1.8699014818313475], [1.8320632613736485], [1.701871890061823], [1.6526315280828194], [1.5022264785012465], [1.504661859255162]]
# Bars above y=1.5: []

# %%
#Total Activity Histograms P06-07

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1,13] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

#All plots degradation  Reaction Data
data= [[0, 0], [13972.7262, 18861.8692, 15656.5803, 19175.6216], [46806.2199], [30959.258], [30325.0097],
       [29900.8834], [29638.9238], [28115.4122], [27239.6369], [24422.4788], [24233.5866], 
       [23562.0597],[0,0], [21694.6703, 21028.2304, 15559.9028, 14268.7582], [69387.9402]]

     
labels = ['P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1',
          'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 B4']




plot_histogram_with_std(data, labels)

# %%
#Normalized Total Activity Histograms P06-07

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

   # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1,13] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


# All plots degradation Reaction Data
data = [[0, 0], [13972.7262, 18861.8692, 15656.5803, 19175.6216], [46806.2199], [30959.258], [30325.0097],
       [29900.8834], [29638.9238], [28115.4122], [27239.6369], [24422.4788], [24233.5866], 
       [23562.0597],[0,0], [21694.6703, 21028.2304, 15559.9028, 14268.7582], [69387.9402]]

labels = ['P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1',
          'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 B4']

# Divide histograms 1-12 by the value of histogram 2
data[0:11] = [[x / data[1][0] for x in sublist] for sublist in data[0:11]]

# Divide histograms 13-15 by the value of histogram 14
data[11:15] = [[x / data[13][0] for x in sublist] for sublist in data[11:15]]


# Create a new variable with the updated values
normalized_data = data

plot_histogram_with_std(normalized_data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# Bars above y=1.5: []

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

   # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1,13] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    
    # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, 5])
    plt.show()

data = [[0, 0], [13972.7262, 18861.8692, 15656.5803, 19175.6216], [46806.2199], [30959.258], [30325.0097],
        [29900.8834], [29638.9238], [28115.4122], [27239.6369], [24422.4788], [24233.5866],
        [23562.0597],[0,0], [21694.6703, 21028.2304, 15559.9028, 14268.7582], [69387.9402]]

average_2 = sum(data[1]) / len(data[1])
average_14 = sum(data[13]) / len(data[13])

data[1] = [average_2]
data[13] = [average_14]

# Perform division on elements 1-12 with the average of element 2
for i in range(1, 13):
    data[i] = [elem / average_2 for elem in data[i]]

# Perform division on elements 13-15 with the value of element 14
for i in range(13, 15):
    data[i] = [elem / average_14 for elem in data[i]]

print("Updated data array:")
print(data)

labels = ['P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1',
          'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 B4']

plot_histogram_with_std(data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# Updated data array:
# [[0, 0], [1.0], [2.7668648003235696], [1.830100388096837], [1.7926079501327306], [1.7675364931155089], [1.7520512264587405], [1.6619916013078395], [1.6102217327788322], [1.4436905409737781], [1.4325245211509365], [1.3928284263573385], [0.0, 0.0], [1.0], [3.8255794127171767]]
# Bars above y=1.5: []

# %%
#Total Activity Histograms P08

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


#All plots degradation  Reaction Data
data = [[0, 0], [9920.9582, 18121.0309, 19365.8258, 22412.5324], [63534.8877], [44913.2821], [44592.3982], [41207.7695], [39227.6964], [32100.325, 32098.3249, 31833.2845, 32703.5323], [31833.2845], [31343.4156], [26097.131], [28723.6512], [27508.9285], [25962.3513]]

labels = ['P08 Sterile', 'P08 Parent (HetCPIII)', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A5',
          'P08 A10', 'P08 F1', 'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9']

plot_histogram_with_std(data, labels)

# %%
#Normalized Total Activity Histograms P08

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

   # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
     # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
     # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
    
    
    plt.show()


# All plots degradation Reaction Data
data =  [[0, 0], [9920.9582, 18121.0309, 19365.8258, 22412.5324], [63534.8877], [44913.2821], [44592.3982], [41207.7695], [39227.6964], [32100.325, 32098.3249, 31833.2845, 32703.5323], [31833.2845], [31343.4156], [26097.131], [28723.6512], [27508.9285], [25962.3513]]

average_2 = sum(data[1]) / len(data[1])
average_14 = sum(data[13]) / len(data[13])

data[1] = [average_2]

# Perform division on elements 1-12 with the average of element 2
for i in range(1, 14):
    data[i] = [elem / average_2 for elem in data[i]]

print("Updated data array:")
print(data)




labels = ['P08 Sterile', 'P08 Parent (HetCPIII)', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A5',
          'P08 A10', 'P08 F1', 'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9']

plot_histogram_with_std(data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# Updated data array:
# [[0, 0], [1.0], [3.6399067124090347], [2.573076980383339], [2.5546935771257617], [2.3607885720155966], [2.2473504023948045], [1.8390240805920486, 1.8389094950835343, 1.8237253597849121, 1.8735817603130143], [1.8237253597849121], [1.79566082450581], [1.495101758108843], [1.6455748108259556], [1.5759834812508877], [1.4873802439536132]]
# Bars above y=1.5: []

# %%
#1-way ANOVA and variation between HetCPIII betweem plates (Tile 2 Experiment)

import pandas as pd
from scipy.stats import f_oneway
import numpy as np


# Sample data
plates = ['Plate 1', 'Plate 2', 'Plate 3', 'Plate 4', 'Plate 5', 'Plate 6', 'Plate 7', 'Plate 8']
enzyme_performance = [[17943.0884, 17322.0138, 14461.3583, 19137.2628],
                      [17572.8463, 18556.7563, 16969.3551, 19881.7846],
                      [28919.7813, 17650.1863, 11217.3279, 12281.0732],
                      [30114.854, 24713.2064, 26630.9387, 27728.6128],
                      [30114.854, 24713.2064, 26630.9387, 27728.6128],
                      [5689.4407, 6212.2138, 8861.4002, 8106.1888],
                      [13972.7262, 18861.8692, 15656.5803, 19175.6216],
                      [21694.6703, 21028.2304, 15559.9028, 14268.7582]]

# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

import seaborn as sns
import matplotlib.pyplot as plt

# Create a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df)

# Add labels and title
plt.xlabel('')
plt.ylabel('Total Activity (a.u.)')
plt.title('')

# Display the plot
plt.show()
# Out:
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.26653626956073995
# p-value: 0.9610768424739721

# %%
# HetCPIII normalized total activity across plates
import pandas as pd
from scipy.stats import f_oneway
import seaborn as sns
import matplotlib.pyplot as plt

array = [[17943.0884, 17322.0138, 14461.3583, 19137.2628],
         [17572.8463, 18556.7563, 16969.3551, 19881.7846],
         [28919.7813, 17650.1863, 11217.3279, 12281.0732],
         [30114.854, 24713.2064, 26630.9387, 27728.6128],
         [30114.854, 24713.2064, 26630.9387, 27728.6128],
         [5689.4407, 6212.2138, 8861.4002, 8106.1888],
         [13972.7262, 18861.8692, 15656.5803, 19175.6216],
         [21694.6703, 21028.2304, 15559.9028, 14268.7582]]

result = []

for sublist in array:
    average = np.mean(sublist)
    sublist_result = [x / average for x in sublist]
    result.append(sublist_result)

enzyme_performance = result

# Sample data
plates = ['Plate 1', 'Plate 2', 'Plate 3', 'Plate 4', 'Plate 5', 'Plate 6', 'Plate 7', 'Plate 8']

# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

# Set the font size for better readability
plt.rcParams['font.size'] = 12

# Create a box plot with enhanced aesthetics
plt.figure(figsize=(10, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df, palette='Set3', width=0.6)

# Add labels and title
plt.xlabel('')
plt.ylabel('Normalized Total Activity')
plt.title('')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Increase the spacing between the plot and the x-axis labels
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.7664504842226244
# p-value: 0.6205232635062876
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16176\4088566551.py in <module>
#      63 plt.show()
#      64
# ---> 65 mean(17943.0884, 17322.0138, 14461.3583, 19137.2628)
#
# NameError: name 'mean' is not defined

# %%
import numpy as np

array = [[17943.0884, 17322.0138, 14461.3583, 19137.2628],
         [17572.8463, 18556.7563, 16969.3551, 19881.7846],
         [28919.7813, 17650.1863, 11217.3279, 12281.0732],
         [30114.854, 24713.2064, 26630.9387, 27728.6128],
         [30114.854, 24713.2064, 26630.9387, 27728.6128],
         [5689.4407, 6212.2138, 8861.4002, 8106.1888],
         [13972.7262, 18861.8692, 15656.5803, 19175.6216],
         [21694.6703, 21028.2304, 15559.9028, 14268.7582]]

result = []

for sublist in array:
    average = np.mean(sublist)
    sublist_result = [x / average for x in sublist]
    result.append(sublist_result)

print("Result:", result)
# Out:
# Result: [[1.042237482387189, 1.0061619076004855, 0.8399986295832482, 1.1116019804290775], [0.9631497705388509, 1.017076873442544, 0.9300730338008635, 1.0897003222177422], [1.6509464590974556, 1.0075979576787264, 0.640364724232548, 0.7010908589912698], [1.1032333604871158, 0.9053483621432697, 0.9756029365085875, 1.0158153408610266], [1.1032333604871158, 0.9053483621432697, 0.9756029365085875, 1.0158153408610266], [0.7883047853332215, 0.8607380099863026, 1.2277980474271866, 1.1231591572532893], [0.8259723679873348, 1.1149851893463265, 0.9255103492241089, 1.1335320934422293], [1.1960966678957101, 1.1593537014104, 0.8578672841993421, 0.7866823464945484]]

# %%
#Z-Score Hit Identification (Plate1)

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats


labels = ['D1F-A3', 'D1F-A4', 'D1F-A5', 'D1F-A6', 'D1F-A7', 'D1F-A8', 'D1F-A9', 'D1F-A10', 'D1F-A11', 'D1F-A12',
          'D1F-B1', 'D1F-B2', 'D1F-B3', 'D1F-B4', 'D1F-B5', 'D1F-B6', 'D1F-B7', 'D1F-B8', 'D1F-B9', 'D1F-B10',
          'D1F-B11', 'D1F-B12', 'D1F-C1', 'D1F-C2', 'D1F-C3', 'D1F-C5', 'D1F-C6', 'D1F-C7', 'D1F-C8', 'D1F-C9',
          'D1F-C10', 'D1F-C11', 'D1F-C12', 'D1F-D1', 'D1F-D2', 'D1F-D3', 'D1F-D4', 'D1F-D5', 'D1F-D6', 'D1F-D7',
          'D1F-D8', 'D1F-D9', 'D1F-D10', 'D1F-D11', 'D1F-D12', 'D1F-E1', 'D1F-E2', 'D1F-E3', 'D1F-E4', 'D1F-E5',
          'D1F-E7', 'D1F-E8', 'D1F-E9', 'D1F-E10', 'D1F-E11', 'D1F-E12', 'D1F-F1', 'D1F-F2', 'D1F-F3', 'D1F-F4',
          'D1F-F5', 'D1F-F6', 'D1F-F7', 'D1F-F8', 'D1F-F9', 'D1F-F10', 'D1F-F11', 'D1F-F12', 'D1F-G1', 'D1F-G2',
          'D1F-G3', 'D1F-G4', 'D1F-G5', 'D1F-G6', 'D1F-G7', 'D1F-G9', 'D1F-G10', 'D1F-G11', 'D1F-G12', 'D1F-H2',
          'D1F-H3', 'D1F-H4', 'D1F-H5', 'D1F-H6', 'D1F-H7', 'D1F-H8', 'D1F-H9', 'D1F-H10', 'D1F-H11', 'D1F-H12']

hit_assay_data = [[3033.0183], [20596.3087], [2178.7211], [633.7007], [17631.5901], [118.0878], [13951.5873],
                  [152.5832], [592.1997], [4469.4836], [15570.7716], [19677.2287], [20299.6571], [105.3135],
                  [11475.2313], [31492.0771], [4046.8649], [165.7612], [139.3457], [1126.5761], [14790.9928],
                  [16514.2294], [15358.3144], [106.9396], [134.8147], [140.4549], [4571.5121], [112.4904],
                  [20700.5224], [807.9109], [12967.3582], [140.9002], [9436.3739], [18790.7956], [4458.7937],
                  [17647.3077], [1244.9598], [240.3342], [13574.2969], [141.5133], [8755.4839], [6432.3184],
                  [2274.7545], [0], [277.2181], [17255.8605], [11233.5597], [16895.8949], [13746.9718],
                  [17075.9423], [16008.9006], [0], [18801.5138], [662.9349], [0], [592.7378], [13585.4716],
                  [13386.2782], [15007.6911], [13517.2124], [15227.379], [15996.8724], [106.7899], [14473.6861],
                  [184.1088], [3256.5216], [0], [6275.6432], [2279.858], [11283.9587], [0], [264.6926],
                  [14120.7448], [15964.6851], [18737.0325], [15323.1726], [1009.6672], [0], [5147.8989],
                  [0], [7451.7251], [23638.4254], [110.7441], [20754.3971], [10059.3152], [15037.616],
                  [22960.8791], [23243.5419], [14245.1745], [20703.8616]]

validation_assay_data = [19237.5564, 16139.8541, 12280.8859, 17823.3764]

# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="17873">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x0" value "D1F-A10", key "x1" value "D1F-H9" [renderer: GlyphRenderer(id='17925', ...)]
#   <div class="bk-root" id="f42ac659-2fe0-48f7-84c8-4e92b7a14dce" data-root-id="17875"></div>

# %%
#Z-Score Hit Identification Plate2

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats


labels = ['D1F-A3', 'D1F-A4', 'D1F-A5', 'D1F-A6', 'D1F-A7', 'D1F-A8', 'D1F-A9', 'D1F-A10', 'D1F-A11', 'D1F-A12',
          'D1F-B1', 'D1F-B2', 'D1F-B3', 'D1F-B4', 'D1F-B5', 'D1F-B6', 'D1F-B7', 'D1F-B8', 'D1F-B9', 'D1F-B10',
          'D1F-B11', 'D1F-B12', 'D1F-C1', 'D1F-C2', 'D1F-C3', 'D1F-C5', 'D1F-C6', 'D1F-C7', 'D1F-C8', 'D1F-C9',
          'D1F-C10', 'D1F-C11', 'D1F-C12', 'D1F-D1', 'D1F-D2', 'D1F-D3', 'D1F-D4', 'D1F-D5', 'D1F-D6', 'D1F-D7',
          'D1F-D8', 'D1F-D9', 'D1F-D10', 'D1F-D11', 'D1F-D12', 'D1F-E1', 'D1F-E2', 'D1F-E3', 'D1F-E4', 'D1F-E5',
          'D1F-E7', 'D1F-E8', 'D1F-E9', 'D1F-E10', 'D1F-E11', 'D1F-E12', 'D1F-F1', 'D1F-F2', 'D1F-F3', 'D1F-F4',
          'D1F-F5', 'D1F-F6', 'D1F-F7', 'D1F-F8', 'D1F-F9', 'D1F-F10', 'D1F-F11', 'D1F-F12', 'D1F-G1', 'D1F-G2',
          'D1F-G3', 'D1F-G4', 'D1F-G5', 'D1F-G6', 'D1F-G7', 'D1F-G9', 'D1F-G10', 'D1F-G11', 'D1F-G12', 'D1F-H2',
          'D1F-H3', 'D1F-H4', 'D1F-H5', 'D1F-H6', 'D1F-H7', 'D1F-H8', 'D1F-H9', 'D1F-H10', 'D1F-H11', 'D1F-H12']

hit_assay_data = [[3033.0183], [20596.3087], [2178.7211], [633.7007], [17631.5901], [118.0878], [13951.5873],
                  [152.5832], [592.1997], [4469.4836], [15570.7716], [19677.2287], [20299.6571], [105.3135],
                  [11475.2313], [31492.0771], [4046.8649], [165.7612], [139.3457], [1126.5761], [14790.9928],
                  [16514.2294], [15358.3144], [106.9396], [134.8147], [140.4549], [4571.5121], [112.4904],
                  [20700.5224], [807.9109], [12967.3582], [140.9002], [9436.3739], [18790.7956], [4458.7937],
                  [17647.3077], [1244.9598], [240.3342], [13574.2969], [141.5133], [8755.4839], [6432.3184],
                  [2274.7545], [0], [277.2181], [17255.8605], [11233.5597], [16895.8949], [13746.9718],
                  [17075.9423], [16008.9006], [0], [18801.5138], [662.9349], [0], [592.7378], [13585.4716],
                  [13386.2782], [15007.6911], [13517.2124], [15227.379], [15996.8724], [106.7899], [14473.6861],
                  [184.1088], [3256.5216], [0], [6275.6432], [2279.858], [11283.9587], [0], [264.6926],
                  [14120.7448], [15964.6851], [18737.0325], [15323.1726], [1009.6672], [0], [5147.8989],
                  [0], [7451.7251], [23638.4254], [110.7441], [20754.3971], [10059.3152], [15037.616],
                  [22960.8791], [23243.5419], [14245.1745], [20703.8616]]

validation_assay_data = [19237.5564, 16139.8541, 12280.8859, 17823.3764]

# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=2, y1=2, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-2, y1=-2, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2938">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x0" value "D1F-A10", key "x1" value "D1F-H9" [renderer: GlyphRenderer(id='2990', ...)]
#   <div class="bk-root" id="37c990ea-58c5-41b2-ab50-dff62a5a46fc" data-root-id="2940"></div>

# %%
#Z-Score Hit Identification Plate2

import pandas as pd
import numpy as np

# Define the data
data = {
    'Sample': ['D1B-A1', 'D1B-A2', 'D1B-A3', 'D1B-A4', 'D1B-A5', 'D1B-A6', 'D1B-A7', 'D1B-A8', 'D1B-A9',
               'D1B-A10', 'D1B-A11', 'D1B-A12', 'D1B-B1', 'D1B-B2', 'D1B-B3', 'D1B-B4', 'D1B-B5', 'D1B-B6',
               'D1B-B7', 'D1B-B8', 'D1B-B9', 'D1B-B10', 'D1B-B11', 'D1B-B12', 'D1B-C1', 'D1B-C2', 'D1B-C3',
               'D1B-C4', 'D1B-C5', 'D1B-C6', 'D1B-C7', 'D1B-C8', 'D1B-C9', 'D1B-C10', 'D1B-C11', 'D1B-C12',
               'D1B-D1', 'D1B-D2', 'D1B-D3', 'D1B-D4', 'D1B-D5', 'D1B-D6', 'D1B-D7', 'D1B-D8', 'D1B-D9',
               'D1B-D10', 'D1B-D11', 'D1B-D12', 'D1B-E1', 'D1B-E2', 'D1B-E3', 'D1B-E4', 'D1B-E5', 'D1B-E6',
               'D1B-E7', 'D1B-E8', 'D1B-E9', 'D1B-E10', 'D1B-E11', 'D1B-E12', 'D1B-F1', 'D1B-F2', 'D1B-F3',
               'D1B-F4', 'D1B-F5', 'D1B-F6', 'D1B-F7', 'D1B-F8', 'D1B-F9', 'D1B-F10', 'D1B-F11', 'D1B-F12',
               'D1B-G1', 'D1B-G2', 'D1B-G3', 'D1B-G4', 'D1B-G5', 'D1B-G6', 'D1B-G7', 'D1B-G8', 'D1B-G9',
               'D1B-G10', 'D1B-G11', 'D1B-G12', 'D1B-H1', 'D1B-H2', 'D1B-H3', 'D1B-H4', 'D1B-H5', 'D1B-H6',
               'D1B-H7', 'D1B-H8', 'D1B-H9', 'D1B-H10', 'D1B-H11', 'D1B-H12'],
    'Value': [0, 17572.8463, 8678.441, 23018.3359, 0, 215.4331, 22728.9803, 4123.9418, 19176.5554, 9074.2227,
              2000.0856, 19691.7494, 21710.3615, 20624.3896, 8656.4335, 686.1451, 1465.8075, 26470.1309,
              24221.6429, 162.3207, 22032.1783, 21600.2512, 0, 112.1455, 0, 15539.0771, 0, 18556.7563,
              14418.4035, 6356.147, 16224.563, 1204.4864, 19450.2451, 22187.1959, 19174.7282, 4601.8457,
              20720.6659, 14399.6704, 8825.9578, 304.667, 19704.7438, 12114.2042, 11485.4444, 0, 4027.9512,
              17362.0113, 12054.6038, 12041.5953, 0, 7976.5277, 27421.9874, 105.6832, 17637.5933, 16969.3551,
              16187.6517, 12421.409, 0, 1060.052, 2617.0013, 0, 1854.2119, 23613.8809, 29300.0667, 0,
              23558.0369, 10618.832, 6401.5426, 18126.7741, 1533.5421, 0, 0, 11869.1081, 18265.9414, 0,
              25924.519, 25467.7417, 16775.1348, 20974.2369, 16870.8561, 21881.7846, 17336.3919, 12683.8934,
              672.9711, 25071.3222, 0, 32508.6703, 26861.7201, 0, 25267.8074, 433.5979, 3941.2894, 29558.7271,
              8451.335, 18460.3632, 22527.4632, 18641.3229]
}

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="17134">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x0" value "D1B-A10", key "x1" value "D1B-H9" [renderer: GlyphRenderer(id='17186', ...)]
#   <div class="bk-root" id="90e584a2-f2c6-4004-a60a-2dab52eaf949" data-root-id="17136"></div>

# %%
#Z-Score Hit Identification Plate3

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Segment
from bokeh.plotting import figure, show



# Define the data
data = {
    'Sample': ['D1B-A1', 'D1B-A2', 'D1B-A3', 'D1B-A4', 'D1B-A5', 'D1B-A6', 'D1B-A7', 'D1B-A8', 'D1B-A9',
               'D1B-A10', 'D1B-A11', 'D1B-A12', 'D1B-B1', 'D1B-B2', 'D1B-B3', 'D1B-B4', 'D1B-B5', 'D1B-B6',
               'D1B-B7', 'D1B-B8', 'D1B-B9', 'D1B-B10', 'D1B-B11', 'D1B-B12', 'D1B-C1', 'D1B-C2', 'D1B-C3',
               'D1B-C4', 'D1B-C5', 'D1B-C6', 'D1B-C7', 'D1B-C8', 'D1B-C9', 'D1B-C10', 'D1B-C11', 'D1B-C12',
               'D1B-D1', 'D1B-D2', 'D1B-D3', 'D1B-D4', 'D1B-D5', 'D1B-D6', 'D1B-D7', 'D1B-D8', 'D1B-D9',
               'D1B-D10', 'D1B-D11', 'D1B-D12', 'D1B-E1', 'D1B-E2', 'D1B-E3', 'D1B-E4', 'D1B-E5', 'D1B-E6',
               'D1B-E7', 'D1B-E8', 'D1B-E9', 'D1B-E10', 'D1B-E11', 'D1B-E12', 'D1B-F1', 'D1B-F2', 'D1B-F3',
               'D1B-F4', 'D1B-F5', 'D1B-F6', 'D1B-F7', 'D1B-F8', 'D1B-F9', 'D1B-F10', 'D1B-F11', 'D1B-F12',
               'D1B-G1', 'D1B-G2', 'D1B-G3', 'D1B-G4', 'D1B-G5', 'D1B-G6', 'D1B-G7', 'D1B-G8', 'D1B-G9',
               'D1B-G10', 'D1B-G11', 'D1B-G12', 'D1B-H1', 'D1B-H2', 'D1B-H3', 'D1B-H4', 'D1B-H5', 'D1B-H6',
               'D1B-H7', 'D1B-H8', 'D1B-H9', 'D1B-H10', 'D1B-H11', 'D1B-H12'],
    'Value':[0, 28919.7813, 1281.4123, 0, 0, 14880.4098, 16356.3612,
           387.9375, 1370.6779, 467.3412, 18090.0562, 326.5664,
           21128.571, 18430.953, 22413.9146, 14608.6943, 100.0955,
           100.7874, 4559.6435, 19298.8977, 8741.093, 1318.6903,
           20299.9856, 14148.3631, 27614.5395, 134.4003, 12995.8734,
           17650.1863, 5290.2179, 9826.5066, 11762.3156, 121.6166,
           16243.9392, 5824.1226, 17471.3168, 20655.828, 16207.2858,
           554.9326, 12013.262, 10812.4694, 828.1365, 121.5742,
           2391.7404, 2505.0643, 0, 0, 15508.637, 29334.8007,
           17480.747, 2580.1968, 13270.9119, 8111.5779, 10947.1487,
           11217.3279, 140.7203, 8067.8349, 10104.7601, 105.7874,
           177.9001, 6015.0234, 28906.3216, 0, 14854.0727, 10619.3229,
           10417.2081, 1253.6243, 126.0287, 3334.0942, 150.123,
           7554.5163, 7725.5261, 17681.3433, 42660.047, 18737.7263,
           178.7757, 13454.5492, 166.3651, 5931.4543, 4421.638,
           12281.0732, 9886.1828, 10334.7561, 18773.2098, 22076.9276,
           370.2382, 5967.918, 2032.2643, 360.0588, 16782.7902,
           2963.9032, 120.7629, 0, 408.2562, 266.3725, 21835.118,
           21281.0905]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id
           31483.7016, 28642.4348, 17441.7904, 21882.7272, 5873.4473,
           960.649, 349.9252, 474.7518, 668.6666, 965.8886, 24995.8488,
           18745.3283, 5065.6362, 568.2141, 15658.6689, 961.698,
           30188.7469, 496.8579, 445.435, 23585.9646, 302.3756, 5147.736,
           367.5227, 19458.8478, 27728.6128, 22096.8415, 528.0812,
           5312.371, 1332.9842, 333.1769, 33321.7714, 14379.1876,
           32215.849, 590.0349, 356.7754, 19678.5539, 1270.3824,
           625.8878, 32985.0186, 688.7824, 26436.2872]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1152">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x0" value "D1B-A10", key "x1" value "D1B-H9" [renderer: GlyphRenderer(id='1204', ...)]
#   <div class="bk-root" id="a42cdb4d-e559-47b7-902b-49db73e788c6" data-root-id="1154"></div>

# %%
#Z-Score Hit Identification Plate6

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Segment
from bokeh.plotting import figure, show



# Define the data
data = {
    'Sample': ['D1B-A1', 'D1B-A2', 'D1B-A3', 'D1B-A4', 'D1B-A5', 'D1B-A6', 'D1B-A7', 'D1B-A8', 'D1B-A9',
               'D1B-A10', 'D1B-A11', 'D1B-A12', 'D1B-B1', 'D1B-B2', 'D1B-B3', 'D1B-B4', 'D1B-B5', 'D1B-B6',
               'D1B-B7', 'D1B-B8', 'D1B-B9', 'D1B-B10', 'D1B-B11', 'D1B-B12', 'D1B-C1', 'D1B-C2', 'D1B-C3',
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="28936">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x0" value "D1B-A10", key "x1" value "D1B-H9" [renderer: GlyphRenderer(id='28988', ...)]
#   <div class="bk-root" id="eee0dcca-a3a8-4b5e-aabe-3f9403d78bbc" data-root-id="28938"></div>

# %%
#Z-Score Hit Identification Plate7

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Segment
from bokeh.plotting import figure, show



# Define the data
data = {
    'Sample': ['D1B-A1', 'D1B-A2', 'D1B-A3', 'D1B-A4', 'D1B-A5', 'D1B-A6', 'D1B-A7', 'D1B-A8', 'D1B-A9',
               'D1B-A10', 'D1B-A11', 'D1B-A12', 'D1B-B1', 'D1B-B2', 'D1B-B3', 'D1B-B4', 'D1B-B5', 'D1B-B6',
               'D1B-B7', 'D1B-B8', 'D1B-B9', 'D1B-B10', 'D1B-B11', 'D1B-B12', 'D1B-C1', 'D1B-C2', 'D1B-C3',
               'D1B-C4', 'D1B-C5', 'D1B-C6', 'D1B-C7', 'D1B-C8', 'D1B-C9', 'D1B-C10', 'D1B-C11', 'D1B-C12',
               'D1B-D1', 'D1B-D2', 'D1B-D3', 'D1B-D4', 'D1B-D5', 'D1B-D6', 'D1B-D7', 'D1B-D8', 'D1B-D9',
               'D1B-D10', 'D1B-D11', 'D1B-D12', 'D1B-E1', 'D1B-E2', 'D1B-E3', 'D1B-E4', 'D1B-E5', 'D1B-E6',
               'D1B-E7', 'D1B-E8', 'D1B-E9', 'D1B-E10', 'D1B-E11', 'D1B-E12', 'D1B-F1', 'D1B-F2', 'D1B-F3',
               'D1B-F4', 'D1B-F5', 'D1B-F6', 'D1B-F7', 'D1B-F8', 'D1B-F9', 'D1B-F10', 'D1B-F11', 'D1B-F12',
               'D1B-G1', 'D1B-G2', 'D1B-G3', 'D1B-G4', 'D1B-G5', 'D1B-G6', 'D1B-G7', 'D1B-G8', 'D1B-G9',
               'D1B-G10', 'D1B-G11', 'D1B-G12', 'D1B-H1', 'D1B-H2', 'D1B-H3', 'D1B-H4', 'D1B-H5', 'D1B-H6',
               'D1B-H7', 'D1B-H8', 'D1B-H9', 'D1B-H10', 'D1B-H11', 'D1B-H12'],
    'Value':[35670.2583, 0, 1949.169, 15436.5239, 0, 1256.7563, 27307.0681, 0,
           12652.0555, 17081.8143, 36226.0287, 0, 11088.4106, 5683.3118,
           29171.0668, 69387.9402, 30051.7009, 25230.6598, 25241.9898,
           5468.7906, 0, 21414.9772, 297.1221, 0, 0, 24946.7165, 3178.0164,
           16721.7518, 274.4059, 13859.7131, 0, 16549.216, 26693.9397, 0,
           20597.917, 0, 0, 658.9483, 0, 28817.4642, 31382.8184, 23695.1923,
           32491.9174, 20540.3749, 0, 0, 22855.689, 17625.7559, 0, 22243.1173,
           22225.5393, 17981.6985, 709.7522, 17768.7575, 0, 0, 1705.754,
           23460.6258, 24394.3003, 22708.444, 6921.1957, 17164.1212, 0,
           25744.3918, 0, 7705.5487, 0, 0, 24920.4466, 20261.5522, 20425.0526,
           114.126, 0, 1450.6909, 11458.218, 25578.0328, 29222.7581,
           13880.3089, 23084.57, 410.1768, 10268.9034, 26065.6397, 26290.228,
           35082.0922, 142.9948, 0, 0, 489.5074, 20767.0863, 13092.9462,
           827.6211, 104.12, 27754.6616, 19512.535, 26391.3383, 0]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="29899">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x0" value "D1B-A10", key "x1" value "D1B-H9" [renderer: GlyphRenderer(id='29951', ...)]
#   <div class="bk-root" id="2b1250c8-ce8b-46cc-8c5c-3d997a811acd" data-root-id="29901"></div>

# %%
#Z-Score Hit Identification Plate8

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Segment
from bokeh.plotting import figure, show



# Define the data
data = {
    'Sample': ['D1B-A1', 'D1B-A2', 'D1B-A3', 'D1B-A4', 'D1B-A5', 'D1B-A6', 'D1B-A7', 'D1B-A8', 'D1B-A9',
               'D1B-A10', 'D1B-A11', 'D1B-A12', 'D1B-B1', 'D1B-B2', 'D1B-B3', 'D1B-B4', 'D1B-B5', 'D1B-B6',
               'D1B-B7', 'D1B-B8', 'D1B-B9', 'D1B-B10', 'D1B-B11', 'D1B-B12', 'D1B-C1', 'D1B-C2', 'D1B-C3',
               'D1B-C4', 'D1B-C5', 'D1B-C6', 'D1B-C7', 'D1B-C8', 'D1B-C9', 'D1B-C10', 'D1B-C11', 'D1B-C12',
               'D1B-D1', 'D1B-D2', 'D1B-D3', 'D1B-D4', 'D1B-D5', 'D1B-D6', 'D1B-D7', 'D1B-D8', 'D1B-D9',
               'D1B-D10', 'D1B-D11', 'D1B-D12', 'D1B-E1', 'D1B-E2', 'D1B-E3', 'D1B-E4', 'D1B-E5', 'D1B-E6',
               'D1B-E7', 'D1B-E8', 'D1B-E9', 'D1B-E10', 'D1B-E11', 'D1B-E12', 'D1B-F1', 'D1B-F2', 'D1B-F3',
               'D1B-F4', 'D1B-F5', 'D1B-F6', 'D1B-F7', 'D1B-F8', 'D1B-F9', 'D1B-F10', 'D1B-F11', 'D1B-F12',
               'D1B-G1', 'D1B-G2', 'D1B-G3', 'D1B-G4', 'D1B-G5', 'D1B-G6', 'D1B-G7', 'D1B-G8', 'D1B-G9',
               'D1B-G10', 'D1B-G11', 'D1B-G12', 'D1B-H1', 'D1B-H2', 'D1B-H3', 'D1B-H4', 'D1B-H5', 'D1B-H6',
               'D1B-H7', 'D1B-H8', 'D1B-H9', 'D1B-H10', 'D1B-H11', 'D1B-H12'],
    'Value':[0, 9919.9582, 102.1562, 22225.1806, 39227.6964, 9696.754, 168.5939,
           102.2124, 5618.4883, 32100.3249, 139.1327, 5245.5426, 0, 20968.1586,
           100.1861, 17152.677, 12554.1915, 18029.7302, 23093.6751, 0,
           24068.9309, 17832.3257, 7059.4384, 41207.7695, 22374.3913,
           27508.9285, 28723.6512, 18121.0309, 17164.1529, 13523.1837,
           11320.7249, 1499.7817, 25962.3513, 63534.8877, 14957.4994,
           703.0605, 23274.2522, 17614.4326, 349.404, 536.4357, 1063.656,
           14703.2094, 601.9153, 12952.8722, 0, 17488.6757, 23504.8686,
           18054.8384, 1530.8121, 23283.663, 21195.219, 16404.5141, 15759.0321,
           19365.8258, 4073.1562, 20041.8308, 18042.2581, 9173.3214, 1691.1429,
           0, 31833.2845, 13371.2534, 15201.4882, 19150.0547, 4645.7176,
           3232.0281, 16593.1339, 16607.6389, 2095.1037, 14811.8292, 10729.5557,
           0, 9400.4405, 248.109, 0, 8265.3833, 16688.5355, 15715.6512,
           862.1618, 22412.5324, 10729.8136, 23876.6094, 2337.0562, 0, 0,
           4650.2611, 1324.0187, 8436.1995, 2159.1747, 21334.1221, 5301.1251,
           485.5957, 26105.131, 31343.4156, 44592.3982, 44913.2821]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="30878">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x0" value "D1B-A10", key "x1" value "D1B-H9" [renderer: GlyphRenderer(id='30930', ...)]
#   <div class="bk-root" id="1d72efc2-1f00-4047-a9b3-a8ba7e335d98" data-root-id="30880"></div>

# %%
#1-ANOVA for the variation of hits between plates- Is total activity differences between plates similar as with parent? 

import pandas as pd
from scipy.stats import f_oneway
import numpy as np

# Sample data
plates = ['Plate 1', 'Plate 2', 'Plate 3', 'Plate 4', 'Plate 5', 'Plate 6', 'Plate 7', 'Plate 8']
enzyme_performance = [[0, 14183.6764, 16139.8541,12280.8859, 17823.3764 ,  16823.3764, 3033.0183, 20596.3087, 2178.7211, 633.7007, 17631.5901, 118.0878, 13951.5873,
           152.5832, 592.1997, 4469.4836, 15570.7716, 19677.2287, 20299.6571, 105.3135,
           11475.2313, 31492.0771, 4046.8649, 165.7612, 139.3457, 1126.5761, 14790.9928,
           16514.2294, 15358.3144, 106.9396, 134.8147, 140.4549, 4571.5121, 112.4904,
           20700.5224, 807.9109, 12967.3582, 140.9002, 9436.3739, 18790.7956, 4458.7937,
           17647.3077, 1244.9598, 240.3342, 13574.2969, 141.5133, 8755.4839, 6432.3184,
           2274.7545, 0, 277.2181, 17255.8605, 11233.5597, 16895.8949, 13746.9718,
           17075.9423, 16008.9006, 0, 18801.5138, 662.9349, 0, 592.7378, 13585.4716,
           13386.2782, 15007.6911, 13517.2124, 15227.379, 15996.8724, 106.7899, 14473.6861,
           184.1088, 3256.5216, 0, 6275.6432, 2279.858, 11283.9587, 0, 264.6926,
           14120.7448, 15964.6851, 18737.0325, 15323.1726, 1009.6672, 0, 5147.8989,
           0, 7451.7251, 23638.4254, 110.7441, 20754.3971, 10059.3152, 15037.616,
           22960.8791, 23243.5419, 14245.1745, 20703.8616],
                      [0, 17572.8463, 8678.441, 23018.3359, 0, 215.4331, 22728.9803, 4123.9418, 19176.5554, 9074.2227,
              2000.0856, 19691.7494, 21710.3615, 20624.3896, 8656.4335, 686.1451, 1465.8075, 26470.1309,
              24221.6429, 162.3207, 22032.1783, 21600.2512, 0, 112.1455, 0, 15539.0771, 0, 18556.7563,
              14418.4035, 6356.147, 16224.563, 1204.4864, 19450.2451, 22187.1959, 19174.7282, 4601.8457,
           32491.9174, 20540.3749, 0, 0, 22855.689, 17625.7559, 0, 22243.1173,
           22225.5393, 17981.6985, 709.7522, 17768.7575, 0, 0, 1705.754,
           23460.6258, 24394.3003, 22708.444, 6921.1957, 17164.1212, 0,
           25744.3918, 0, 7705.5487, 0, 0, 24920.4466, 20261.5522, 20425.0526,
           114.126, 0, 1450.6909, 11458.218, 25578.0328, 29222.7581,
           13880.3089, 23084.57, 410.1768, 10268.9034, 26065.6397, 26290.228,
           35082.0922, 142.9948, 0, 0, 489.5074, 20767.0863, 13092.9462,
           827.6211, 104.12, 27754.6616, 19512.535, 26391.3383, 0],
                      [0, 9919.9582, 102.1562, 22225.1806, 39227.6964, 9696.754, 168.5939,
           102.2124, 5618.4883, 32100.3249, 139.1327, 5245.5426, 0, 20968.1586,
           100.1861, 17152.677, 12554.1915, 18029.7302, 23093.6751, 0,
           24068.9309, 17832.3257, 7059.4384, 41207.7695, 22374.3913,
           27508.9285, 28723.6512, 18121.0309, 17164.1529, 13523.1837,
           11320.7249, 1499.7817, 25962.3513, 63534.8877, 14957.4994,
           703.0605, 23274.2522, 17614.4326, 349.404, 536.4357, 1063.656,
           14703.2094, 601.9153, 12952.8722, 0, 17488.6757, 23504.8686,
           18054.8384, 1530.8121, 23283.663, 21195.219, 16404.5141, 15759.0321,
           19365.8258, 4073.1562, 20041.8308, 18042.2581, 9173.3214, 1691.1429,
           0, 31833.2845, 13371.2534, 15201.4882, 19150.0547, 4645.7176,
           3232.0281, 16593.1339, 16607.6389, 2095.1037, 14811.8292, 10729.5557,
           0, 9400.4405, 248.109, 0, 8265.3833, 16688.5355, 15715.6512,
           862.1618, 22412.5324, 10729.8136, 23876.6094, 2337.0562, 0, 0,
           4650.2611, 1324.0187, 8436.1995, 2159.1747, 21334.1221, 5301.1251,
           485.5957, 26105.131, 31343.4156, 44592.3982, 44913.2821]]

for i in range(len(enzyme_performance)):
    inner_array_length = len(enzyme_performance[i])
    print("Length of inner array", i, ":", inner_array_length)


# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

import seaborn as sns
import matplotlib.pyplot as plt

# Create a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df)

# Add labels and title
plt.xlabel('')
plt.ylabel('Total Activity (a.u.)')
plt.title('')

# Display the plot
plt.show()
# Out:
# Length of inner array 0 : 96
# Length of inner array 1 : 96
# Length of inner array 2 : 96
# Length of inner array 3 : 96
# Length of inner array 4 : 96
# Length of inner array 5 : 96
# Length of inner array 6 : 96
# Length of inner array 7 : 96
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.6907263282017938
# p-value: 0.6800177360350261

# %%
import numpy as np

           114.126, 0, 1450.6909, 11458.218, 25578.0328, 29222.7581,
           13880.3089, 23084.57, 410.1768, 10268.9034, 26065.6397, 26290.228,
           35082.0922, 142.9948, 0, 0, 489.5074, 20767.0863, 13092.9462,
           827.6211, 104.12, 27754.6616, 19512.535, 26391.3383, 0],
                      [0, 9919.9582, 102.1562, 22225.1806, 39227.6964, 9696.754, 168.5939,
           102.2124, 5618.4883, 32100.3249, 139.1327, 5245.5426, 0, 20968.1586,
           100.1861, 17152.677, 12554.1915, 18029.7302, 23093.6751, 0,
           24068.9309, 17832.3257, 7059.4384, 41207.7695, 22374.3913,
           27508.9285, 28723.6512, 18121.0309, 17164.1529, 13523.1837,
           11320.7249, 1499.7817, 25962.3513, 63534.8877, 14957.4994,
           703.0605, 23274.2522, 17614.4326, 349.404, 536.4357, 1063.656,
           14703.2094, 601.9153, 12952.8722, 0, 17488.6757, 23504.8686,
           18054.8384, 1530.8121, 23283.663, 21195.219, 16404.5141, 15759.0321,
           19365.8258, 4073.1562, 20041.8308, 18042.2581, 9173.3214, 1691.1429,
           0, 31833.2845, 13371.2534, 15201.4882, 19150.0547, 4645.7176,
           3232.0281, 16593.1339, 16607.6389, 2095.1037, 14811.8292, 10729.5557,
           0, 9400.4405, 248.109, 0, 8265.3833, 16688.5355, 15715.6512,
           862.1618, 22412.5324, 10729.8136, 23876.6094, 2337.0562, 0, 0,
           4650.2611, 1324.0187, 8436.1995, 2159.1747, 21334.1221, 5301.1251,
           485.5957, 26105.131, 31343.4156, 44592.3982, 44913.2821]])


# Compute mean for indices 1, 27, 53, and 79 for the first array
indices = [1, 27, 53, 79]
first_array_mean = np.mean(array_of_arrays[0, indices])

# Divide all values of the first array by the computed average
array_of_arrays[0] /= first_array_mean

# Divide values for the remaining arrays
for i in range(1, len(array_of_arrays)):
    array_mean = np.mean(array_of_arrays[i, indices])
    array_of_arrays[i] /= array_mean
    
enzyme_performance = array_of_arrays

for i in range(len(enzyme_performance)):
    inner_array_length = len(enzyme_performance[i])
    print("Length of inner array", i, ":", inner_array_length)


# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

import seaborn as sns
import matplotlib.pyplot as plt

# Create a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df)

# Add labels and title
plt.xlabel('')
plt.ylabel('Normalized Total Activity')
plt.title('')

# Display the plot
plt.show()
# Out:
# Length of inner array 0 : 96
# Length of inner array 1 : 96
# Length of inner array 2 : 96
# Length of inner array 3 : 96
# Length of inner array 4 : 96
# Length of inner array 5 : 96
# Length of inner array 6 : 96
# Length of inner array 7 : 96
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.5697938891643511
# p-value: 0.7807910276715129

# %%
import numpy as np
from scipy.stats import f_oneway

           18054.8384, 1530.8121, 23283.663, 21195.219, 16404.5141, 15759.0321,
           19365.8258, 4073.1562, 20041.8308, 18042.2581, 9173.3214, 1691.1429,
           0, 31833.2845, 13371.2534, 15201.4882, 19150.0547, 4645.7176,
           3232.0281, 16593.1339, 16607.6389, 2095.1037, 14811.8292, 10729.5557,
           0, 9400.4405, 248.109, 0, 8265.3833, 16688.5355, 15715.6512,
           862.1618, 22412.5324, 10729.8136, 23876.6094, 2337.0562, 0, 0,
           4650.2611, 1324.0187, 8436.1995, 2159.1747, 21334.1221, 5301.1251,
           485.5957, 26105.131, 31343.4156, 44592.3982, 44913.2821]])


# Compute mean for indices 1, 27, 53, and 79 for the first array
indices = [1, 27, 53, 79]
first_array_mean = np.mean(array_of_arrays[0, indices])

# Divide all values of the first array by the computed average
array_of_arrays[0] /= first_array_mean

# Divide values for the remaining arrays
for i in range(1, len(array_of_arrays)):
    array_mean = np.mean(array_of_arrays[i, indices])
    array_of_arrays[i] /= array_mean


# Extracting the edge values and the rest of the plate values
edge_values = np.concatenate((array_of_arrays[:, 1:12],  # A2-A12
                              array_of_arrays[1:7, 11],  # A12-G12
                              array_of_arrays[7, 1:12][::-1],  # H12-H2
                              array_of_arrays[1:7, 0][::-1]  # H2-A1
                              ), axis=None)

rest_values = array_of_arrays[1:7, 1:11].flatten()

# Creating a list of labels for the box plots
labels = ['Plate Edges', 'Rest of the Plate']

# Creating a list of data for the box plots
data = [edge_values, rest_values]

# Performing the one-way ANOVA
f_value, p_value = f_oneway(edge_values, rest_values)

# Printing the results
print("One-Way ANOVA:")
print("F-value:", f_value)
print("p-value:", p_value)

# Creating the box plots
plt.boxplot(data, labels=labels)

# Adding a title and labels to the plot
plt.title('')
plt.xlabel('')
plt.ylabel('Normalized Total Activity')

# Displaying the plot
plt.show()
# Out:
# One-Way ANOVA:
# F-value: 0.323759913345261
# p-value: 0.5701121998969135

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have the array data with dimensions (8, 96)
array_data = np.random.rand(8, 96)

# Extracting the edge values and the rest of the plate values
edge_values = np.concatenate((array_data[:, 1:12],  # A2-A12
                              array_data[1:7, 11],  # A12-G12
                              array_data[7, 1:12][::-1],  # H12-H2
                              array_data[1:7, 0][::-1]  # H2-A1
                              ), axis=None)

rest_values = array_data[1:7, 1:11].flatten()

# Creating a list of labels for the box plots
labels = ['Edge Values', 'Rest of Plate Values']

# Creating a list of data for the box plots
data = [edge_values, rest_values]

# Creating the box plots
plt.boxplot(data, labels=labels)

# Adding a title and labels to the plot
plt.title('Box Plots of Edge Values vs. Rest of Plate Values')
plt.xlabel('Population')
plt.ylabel('Values')

# Displaying the plot
plt.show()

# %%
#Shapiro-Wilk test (Normality of data) & Levene's test (Homogeneity of Variance)

import scipy.stats as stats
import numpy as np

# Example data
data = np.array([[0, 14183.6764, 16139.8541,12280.8859, 17823.3764 ,  16823.3764, 3033.0183, 20596.3087, 2178.7211, 633.7007, 17631.5901, 118.0878, 13951.5873,
           3232.0281, 16593.1339, 16607.6389, 2095.1037, 14811.8292, 10729.5557,
           0, 9400.4405, 248.109, 0, 8265.3833, 16688.5355, 15715.6512,
           862.1618, 22412.5324, 10729.8136, 23876.6094, 2337.0562, 0, 0,
           4650.2611, 1324.0187, 8436.1995, 2159.1747, 21334.1221, 5301.1251,
           485.5957, 26105.131, 31343.4156, 44592.3982, 44913.2821]])

# Shapiro-Wilk test
p_values_sw = []
for group in data:
    _, p_value = stats.shapiro(group)
    p_values_sw.append(p_value)

print("Shapiro-Wilk test results:")
for i, p_value in enumerate(p_values_sw):
    print(f"Group {i+1} p-value:", p_value)

# Levene's test
_, p_value_levene = stats.levene(*data)

print("\nLevene's test result:")
print("p-value:", p_value_levene)
# Out:
# Shapiro-Wilk test results:
# Group 1 p-value: 1.9638811465938488e-07
# Group 2 p-value: 2.8884255698358174e-06
# Group 3 p-value: 3.224587317163241e-07
# Group 4 p-value: 3.419514449376493e-09
# Group 5 p-value: 5.977203188780797e-15
# Group 6 p-value: 6.639026395305336e-08
# Group 7 p-value: 1.1327248472525753e-08
# Group 8 p-value: 6.692124543405953e-07
#
# Levene's test result:
# p-value: 8.767429809039436e-22

# %%
import scipy.stats as stats
import numpy as np

# Array of arrays
array_of_arrays =  np.array([[0, 14183.6764, 16139.8541,12280.8859, 17823.3764 ,  16823.3764, 3033.0183, 20596.3087, 2178.7211, 633.7007, 17631.5901, 118.0878, 13951.5873,
           152.5832, 592.1997, 4469.4836, 15570.7716, 19677.2287, 20299.6571, 105.3135,
           11475.2313, 31492.0771, 4046.8649, 165.7612, 139.3457, 1126.5761, 14790.9928,
           16514.2294, 15358.3144, 106.9396, 134.8147, 140.4549, 4571.5121, 112.4904,
           20700.5224, 807.9109, 12967.3582, 140.9002, 9436.3739, 18790.7956, 4458.7937,
           17647.3077, 1244.9598, 240.3342, 13574.2969, 141.5133, 8755.4839, 6432.3184,
           2274.7545, 0, 277.2181, 17255.8605, 11233.5597, 16895.8949, 13746.9718,
           17075.9423, 16008.9006, 0, 18801.5138, 662.9349, 0, 592.7378, 13585.4716,
           13386.2782, 15007.6911, 13517.2124, 15227.379, 15996.8724, 106.7899, 14473.6861,
           184.1088, 3256.5216, 0, 6275.6432, 2279.858, 11283.9587, 0, 264.6926,
           14120.7448, 15964.6851, 18737.0325, 15323.1726, 1009.6672, 0, 5147.8989,
           0, 7451.7251, 23638.4254, 110.7441, 20754.3971, 10059.3152, 15037.616,
           22960.8791, 23243.5419, 14245.1745, 20703.8616],
                      [0, 17572.8463, 8678.441, 23018.3359, 0, 215.4331, 22728.9803, 4123.9418, 19176.5554, 9074.2227,
              2000.0856, 19691.7494, 21710.3615, 20624.3896, 8656.4335, 686.1451, 1465.8075, 26470.1309,
              24221.6429, 162.3207, 22032.1783, 21600.2512, 0, 112.1455, 0, 15539.0771, 0, 18556.7563,
              14418.4035, 6356.147, 16224.563, 1204.4864, 19450.2451, 22187.1959, 19174.7282, 4601.8457,
           32491.9174, 20540.3749, 0, 0, 22855.689, 17625.7559, 0, 22243.1173,
           22225.5393, 17981.6985, 709.7522, 17768.7575, 0, 0, 1705.754,
           23460.6258, 24394.3003, 22708.444, 6921.1957, 17164.1212, 0,
           25744.3918, 0, 7705.5487, 0, 0, 24920.4466, 20261.5522, 20425.0526,
           114.126, 0, 1450.6909, 11458.218, 25578.0328, 29222.7581,
           13880.3089, 23084.57, 410.1768, 10268.9034, 26065.6397, 26290.228,
           35082.0922, 142.9948, 0, 0, 489.5074, 20767.0863, 13092.9462,
           827.6211, 104.12, 27754.6616, 19512.535, 26391.3383, 0],
                      [0, 9919.9582, 102.1562, 22225.1806, 39227.6964, 9696.754, 168.5939,
           102.2124, 5618.4883, 32100.3249, 139.1327, 5245.5426, 0, 20968.1586,
           100.1861, 17152.677, 12554.1915, 18029.7302, 23093.6751, 0,
           24068.9309, 17832.3257, 7059.4384, 41207.7695, 22374.3913,
           27508.9285, 28723.6512, 18121.0309, 17164.1529, 13523.1837,
           11320.7249, 1499.7817, 25962.3513, 63534.8877, 14957.4994,
           703.0605, 23274.2522, 17614.4326, 349.404, 536.4357, 1063.656,
           14703.2094, 601.9153, 12952.8722, 0, 17488.6757, 23504.8686,
           18054.8384, 1530.8121, 23283.663, 21195.219, 16404.5141, 15759.0321,
           19365.8258, 4073.1562, 20041.8308, 18042.2581, 9173.3214, 1691.1429,
           0, 31833.2845, 13371.2534, 15201.4882, 19150.0547, 4645.7176,
           3232.0281, 16593.1339, 16607.6389, 2095.1037, 14811.8292, 10729.5557,
           0, 9400.4405, 248.109, 0, 8265.3833, 16688.5355, 15715.6512,
           862.1618, 22412.5324, 10729.8136, 23876.6094, 2337.0562, 0, 0,
           4650.2611, 1324.0187, 8436.1995, 2159.1747, 21334.1221, 5301.1251,
           485.5957, 26105.131, 31343.4156, 44592.3982, 44913.2821]])


# Compute mean for indices 1, 27, 53, and 79 for the first array
indices = [1, 27, 53, 79]
first_array_mean = np.mean(array_of_arrays[0, indices])

# Divide all values of the first array by the computed average
array_of_arrays[0] /= first_array_mean

# Divide values for the remaining arrays
for i in range(1, len(array_of_arrays)):
    array_mean = np.mean(array_of_arrays[i, indices])
    array_of_arrays[i] /= array_mean
    
enzyme_performance = array_of_arrays

# Shapiro-Wilk test
p_values_sw = []
for group in enzyme_performance:
    _, p_value = stats.shapiro(group)
    p_values_sw.append(p_value)

print("Shapiro-Wilk test results:")
for i, p_value in enumerate(p_values_sw):
    print(f"Group {i+1} p-value:", p_value)

# Levene's test
_, p_value_levene = stats.levene(*data)

print("\nLevene's test result:")
print("p-value:", p_value_levene)
# Out:
# Shapiro-Wilk test results:
# Group 1 p-value: 1.963846614216891e-07
# Group 2 p-value: 2.8884255698358174e-06
# Group 3 p-value: 3.224587317163241e-07
# Group 4 p-value: 3.419543759264343e-09
# Group 5 p-value: 5.9772480815270014e-15
# Group 6 p-value: 6.639026395305336e-08
# Group 7 p-value: 1.132737281750451e-08
# Group 8 p-value: 6.692124543405953e-07
           703.0605, 23274.2522, 17614.4326, 349.404, 536.4357, 1063.656,
           14703.2094, 601.9153, 12952.8722, 0, 17488.6757, 23504.8686,
           18054.8384, 1530.8121, 23283.663, 21195.219, 16404.5141, 15759.0321,
           19365.8258, 4073.1562, 20041.8308, 18042.2581, 9173.3214, 1691.1429,
           0, 31833.2845, 13371.2534, 15201.4882, 19150.0547, 4645.7176,
           3232.0281, 16593.1339, 16607.6389, 2095.1037, 14811.8292, 10729.5557,
           0, 9400.4405, 248.109, 0, 8265.3833, 16688.5355, 15715.6512,
           862.1618, 22412.5324, 10729.8136, 23876.6094, 2337.0562, 0, 0,
           4650.2611, 1324.0187, 8436.1995, 2159.1747, 21334.1221, 5301.1251,
           485.5957, 26105.131, 31343.4156, 44592.3982, 44913.2821]])


# Compute mean for indices 1, 27, 53, and 79 for the first array
indices = [1, 27, 53, 79]
first_array_mean = np.mean(array_of_arrays[0, indices])

# Divide all values of the first array by the computed average
array_of_arrays[0] /= first_array_mean

# Divide values for the remaining arrays
for i in range(1, len(array_of_arrays)):
    array_mean = np.mean(array_of_arrays[i, indices])
    array_of_arrays[i] /= array_mean
    
enzyme_performance = array_of_arrays

# Shapiro-Wilk test
p_values_sw = []
for group in enzyme_performance:
    _, p_value = stats.shapiro(group)
    p_values_sw.append(p_value)

print("Shapiro-Wilk test results:")
for i, p_value in enumerate(p_values_sw):
    print(f"Group {i+1} p-value:", p_value)

# Levene's test
_, p_value_levene = stats.levene(*data)

print("\nLevene's test result:")
print("p-value:", p_value_levene)
# Out:
# Shapiro-Wilk test results:
# Group 1 p-value: 1.963846614216891e-07
# Group 2 p-value: 2.8884255698358174e-06
# Group 3 p-value: 3.224587317163241e-07
# Group 4 p-value: 3.419543759264343e-09
# Group 5 p-value: 5.9772480815270014e-15
# Group 6 p-value: 6.639026395305336e-08
# Group 7 p-value: 1.132737281750451e-08
# Group 8 p-value: 6.692124543405953e-07
#
# Levene's test result:
# p-value: 8.767429809039436e-22

# %%
import numpy as np
from scipy import stats

# Generate random data with 8 group labels
data = [[0, 14183.6764, 16139.8541,12280.8859, 17823.3764 ,  16823.3764, 3033.0183, 20596.3087, 2178.7211, 633.7007, 17631.5901, 118.0878, 13951.5873,
           152.5832, 592.1997, 4469.4836, 15570.7716, 19677.2287, 20299.6571, 105.3135,
           11475.2313, 31492.0771, 4046.8649, 165.7612, 139.3457, 1126.5761, 14790.9928,
           16514.2294, 15358.3144, 106.9396, 134.8147, 140.4549, 4571.5121, 112.4904,
           20700.5224, 807.9109, 12967.3582, 140.9002, 9436.3739, 18790.7956, 4458.7937,
           17647.3077, 1244.9598, 240.3342, 13574.2969, 141.5133, 8755.4839, 6432.3184,
           2274.7545, 0, 277.2181, 17255.8605, 11233.5597, 16895.8949, 13746.9718,
           17075.9423, 16008.9006, 0, 18801.5138, 662.9349, 0, 592.7378, 13585.4716,
           13386.2782, 15007.6911, 13517.2124, 15227.379, 15996.8724, 106.7899, 14473.6861,
           184.1088, 3256.5216, 0, 6275.6432, 2279.858, 11283.9587, 0, 264.6926,
