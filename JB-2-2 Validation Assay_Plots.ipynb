# %%
#HetCPI, HetCPII HetCPIII (Monocyclopropanation and 2-'CH Functionalization)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for bars
    color = '#1f77b4'

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')
    
# Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('SM+EDA', '\nSM+EDA').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.yticks(fontsize=10)   
    
    plt.tight_layout()
    plt.show()

#Monocyclopropanation HetCPIII Reaction Data
data = [[1260.9679, 1602.9799, 1854.5487], [1153.3761, 1466.0375, 1648.3701], [7800.7637, 7683.0645, 9035.4004], 
        [7789.7882, 10139.2771, 10143.3534], [10481.2127, 9645.8605, 11162.6457], [11479.1047, 9572.1214, 10929.9005]
]



labels = ['HetCPI Monocyclo SM+EDA', 'HetCPI 2-CH Functio SM+EDA', 'HetCPII Monocyclo SM+EDA',
         'HetCPII 2-CH Functio SM+EDA',  'HetCPIII Monocyclo SM+EDA', 'HetCPIII 2-CH Functio SM+EDA']

plot_histogram_with_std(data, labels)

# %%
#HetCPI, HetCPII HetCPIII (Monocyclopropanation and 2-'CH Functionalization)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

     # Define colors for bars
    color = '#1f77b4'


    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')
    
# Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('SM+EDA', '\nSM+EDA').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.yticks(fontsize=10)   
    
# Add legend
    legend_labels = ['Monocyclopropanation', '2-CH Functionalization']
    legend_handles = [plt.Rectangle((0, 0), 1, 1, color='#1f77b4'), plt.Rectangle((0, 0), 1, 1, color='#ff7f0e')]
    ax.legend(legend_handles, legend_labels, loc='upper right')
    # Set the y-axis limits
    plt.ylim(0, 9)  # Increase the range of the y-label
    
    plt.tight_layout()
    plt.show()


data = [1572.8322, 1422.5945666666666, 8172.742866666667, 8357.4729, 10429.9063, 10660.3755]

divided_data = [
    data[0] / data[0], data[2] / data[0], data[4] / data[0],
    data[1] / data[0], data[3] / data[0], data[5] / data[0]
]

print(divided_data)



labels = ['HetCPI Monocyclo SM+EDA', 'HetCPI 2-CH Functio SM+EDA', 'HetCPII Monocyclo SM+EDA',
         'HetCPII 2-CH Functio SM+EDA',  'HetCPIII Monocyclo SM+EDA', 'HetCPIII 2-CH Functio SM+EDA']

plot_histogram_with_std(divided_data, labels)
# Out:
# [1.0, 5.196195033816492, 6.631289911282336, 0.9044795539324961, 5.313645600592358, 6.777821245012659]

# %%
def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for bars
    colors = ['#1f77b4', '#ff7f0e', '#1f77b4', '#ff7f0e', '#1f77b4', '#ff7f0e']

    # Plot histogram with error bars
    fig, ax = plt.subplots()
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7, ax=ax)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('SM+EDA', '\nSM+EDA').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=8, wrap=True)
    plt.yticks(fontsize=10)

    # Add legend
    legend_labels = ['Monocyclopropanation', '2-CH Functionalization']
    legend_handles = [plt.Rectangle((0, 0), 1, 1, color='#1f77b4'), plt.Rectangle((0, 0), 1, 1, color='#ff7f0e')]
    ax.legend(legend_handles, legend_labels, loc='upper right')

    # Set the y-axis limits
    plt.ylim(0, 9)  # Increase the range of the y-label

    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust the right margin to make space for the legend
    plt.show()

data = [1, 1, 5.196, 5.874, 7.3316,7.493] 


labels = ['HetCPI Monocyclo SM+EDA', 'HetCPI 2-CH Functio SM+EDA', 'HetCPII Monocyclo SM+EDA',
         'HetCPII 2-CH Functio SM+EDA',  'HetCPIII Monocyclo SM+EDA', 'HetCPIII 2-CH Functio SM+EDA']

plot_histogram_with_std(data, labels)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def plot_histogram_with_std(data, labels):
    # Convert data to NumPy arrays
    data = np.array(data)

    # Calculate measures of data variation
    mean = np.mean(data, axis=1)
    std_deviation = np.std(data, axis=1)

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for bars
    colors = ['#1f77b4', '#1f77b4', '#1f77b4', '#ff7f0e', '#ff7f0e', '#ff7f0e']

    # Plot histogram with error bars
    fig, ax = plt.subplots()
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7, ax=ax)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')


    # Add legend
    legend_labels = ['Monocyclopropanation', '2-CH Functionalization']
    legend_handles = [plt.Rectangle((0, 0), 1, 1, color='#1f77b4'), plt.Rectangle((0, 0), 1, 1, color='#ff7f0e')]
    ax.legend(legend_handles, legend_labels, loc='upper right')
    
    # Adjust tick label font size and make labels appear on multiple lines

    plt.xticks(range(len(labels)), [label.replace('SM+EDA', '\nSM+EDA').replace('Cyclo', '\nCyclo').replace('2-CH', '\n2-CH ') for label in labels], fontsize=9, wrap=True)
    plt.yticks(fontsize=10)

    # Set the y-axis limits
    plt.ylim(0, 10.5)  # Increase the range of the y-label

    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust the right margin to make space for the legend
    plt.show()

data = np.array([[1260.9679, 1602.9799, 1854.5487], [1153.3761, 1466.0375, 1648.3701], [7800.7637, 7683.0645, 9035.4004],
        [7789.7882, 10139.2771, 10143.3534], [10481.2127, 9645.8605, 11162.6457], [11479.1047, 9572.1214, 10929.9005]])

divided_data = [
    data[0] / data[0], data[2] / data[0], data[4] / data[0],
    data[1] / data[0], data[3] / data[0], data[5] / data[0]
]

print(divided_data)

labels = ['HetCPI  ', 'HetCPII  ', 'HetCPIII  ',
         'HetCPI ',  'HetCPII ', 'HetCPIII ']

plot_histogram_with_std(divided_data, labels)
# Out:
# [array([1., 1., 1.]), array([6.18633012, 4.79298867, 4.8720211 ]), array([8.31203768, 6.01745568, 6.01906313]), array([0.91467523, 0.91457011, 0.88882546]), array([6.17762609, 6.32526777, 5.46944569]), array([9.10340755, 5.97145441, 5.89356349])]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set colors for all histograms
    colors = ['#800080'] * 4 + ['#1f77b4'] * (len(labels) - 4)

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6, rotation=45, ha='right')
    ax.set_xlabel('')
    ax.set_ylabel('Normalized Activity')
    plt.tight_layout()
    plt.show()

# All plots degradation Reaction Data
data = [[104011.6052], [16611.2529], [102436.5435], [18934.5836],
        [93008.6197, 96784.8427, 97280.3408, 109443.9164, 104413.7711, 106582.3565, 110569.6544, 109766.5255, 110229.4001], 
        [0,0,0], [108226.2345, 108627.1427, 109311.2397, 104367.0014, 108959.6542, 108120.2728, 107581.3338, 110506.9616, 108592.4507], [0,0,0], 
        [101627.3998, 104375.913, 102716.0704], [0,0,0],[91546.6729, 112085.6556, 105386.9458], [0,0,0], 
        [100850.3851, 110988.1734, 106139.2711], [0,0,0], [117314.94, 118279.2254, 109227.3439], [0,0,0]] 
        
labels = ['Neg Cyclo (Pdt+EDA)', 'Neg  2-CH  (Pdt+EDA)', 'Neg Cyclo (Pdt)', 'Neg 2-CH  (Pdt)', 
         'HetCPI Cyclo (Pdt+EDA)',  'HetCPI 2-CH  (Pdt+EDA)', 'HetCPI Cyclo (Pdt)', 'HetCPI 2-CH  (Pdt)',
         'HetCPII Cyclo (Pdt+EDA)', 'HetCPII 2-CH  (Pdt+EDA)', 'HetCPII Cyclo (Pdt)', 'HetCPII 2-CH  (Pdt)'
         , 'HetCPIII Cyclo (Pdt+EDA)', 'HetCPIII 2-CH  (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)', 'HetCPIII 2-CH  (Pdt)']

divided_data = []

for i, sublist in enumerate(data):
    divisor = data[i][0]  # Get the value of the ith element in the first sublist
    
    if divisor != 0:
        # Divide the elements in the sublist by the divisor
        divided_sublist = [element / divisor for element in sublist]
    else:
        divided_sublist = [0] * len(sublist)  # Set all elements to 0 if divisor is 0
        
    divided_data.append(divided_sublist)

# Display the divided data
for i, sublist in enumerate(divided_data):
    label = labels[i]
    print(f"{label}: {sublist}")
    
plot_histogram_with_std(divided_data, labels)
# Out:
# Neg Cyclo (Pdt+EDA): [1.0]
# Neg  2-CH  (Pdt+EDA): [1.0]
# Neg Cyclo (Pdt): [1.0]
# Neg 2-CH  (Pdt): [1.0]
# HetCPI Cyclo (Pdt+EDA): [1.0, 1.0406007853054935, 1.0459282280908853, 1.1767072423288527, 1.1226246710980918, 1.145940632640095, 1.1888108301858822, 1.180175835896208, 1.185152520868988]
# HetCPI 2-CH  (Pdt+EDA): [0, 0, 0]
# HetCPI Cyclo (Pdt): [1.0, 1.0037043532176109, 1.0100253437164535, 0.9643410572507721, 1.0067767275040878, 0.9990209240810277, 0.9940411795441334, 1.0210736990946496, 1.003383802473512]
# HetCPI 2-CH  (Pdt): [0, 0, 0]
# HetCPII Cyclo (Pdt+EDA): [1.0, 1.0270450016964814, 1.010712372865413]
# HetCPII 2-CH  (Pdt+EDA): [0, 0, 0]
# HetCPII Cyclo (Pdt): [1.0, 1.2243553157025764, 1.1511826968864096]
# HetCPII 2-CH  (Pdt): [0, 0, 0]
# HetCPIII Cyclo (Pdt+EDA): [1.0, 1.1005230499610656, 1.0524428934481085]
# HetCPIII 2-CH  (Pdt+EDA): [0, 0, 0]
# HetCPIII Cyclo (Pdt): [1.0, 1.0082196299976798, 0.9310608171474154]
# HetCPIII 2-CH  (Pdt): [0, 0, 0]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set colors for all histograms
    colors = ['#800080'] * 4 + ['#1f77b4'] * (len(labels) - 4)

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6, rotation=45, ha='right')
    ax.set_xlabel('')
    ax.set_ylabel('Normalized Activity')
    plt.tight_layout()
    plt.show()




data =   [[0.8622876860849311], [0.1377123139150688], 
             [0.8439943333112543], [0.1560056666887458], 
             [0.8770728143177062, 0.9130725607847464, 0.9181140122281998, 1.0342200627703295, 0.9854145916376634, 1.0047173830851317, 1.045362850292477, 1.0379357052198676, 1.042456119422098], 
          [0.0, 0.0, 0.0], [0.9967792064086307, 1.0025142343342354, 1.0095222991203196, 0.9625520580440583, 1.0016179576315723, 0.9962618762337758, 0.9908922226033656, 1.0223944392215003, 0.9978897069598423],
          [0.0, 0.0, 0.0], [0.9773893143558585, 1.001056118932614, 0.9855545667115278], [0.0, 0.0, 0.0], [0.8676380133186383, 1.0616756426730825, 0.9976865190082793], 
          [0.0, 0.0, 0.0], [0.9614878303338434, 1.057587936417634, 1.018878134060607], [0.0, 0.0, 0.0], [1.0732070583379898, 1.0819478791899868, 0.9994708007200236], 
             [0.0, 0.0, 0.0]]



labels = ['Neg Cyclo (Pdt+EDA)', 'Neg  2-CH  (Pdt+EDA)', 'Neg Cyclo (Pdt)', 'Neg 2-CH  (Pdt)', 
         'HetCPI Cyclo (Pdt+EDA)',  'HetCPI 2-CH  (Pdt+EDA)', 'HetCPI Cyclo (Pdt)', 'HetCPI 2-CH  (Pdt)',
         'HetCPII Cyclo (Pdt+EDA)', 'HetCPII 2-CH  (Pdt+EDA)', 'HetCPII Cyclo (Pdt)', 'HetCPII 2-CH  (Pdt)'
         , 'HetCPIII Cyclo (Pdt+EDA)', 'HetCPIII 2-CH  (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)', 'HetCPIII 2-CH  (Pdt)']
    
plot_histogram_with_std(data, labels)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set colors for all histograms
    colors = ['#800080'] * 4 + ['#1f77b4'] * (len(labels) - 4)

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6, rotation=45, ha='right')
    ax.set_xlabel('')
    ax.set_ylabel('Normalized Activity')
    # Set the y-axis limits
    plt.ylim(0, 1.5)  # Increase the range of the y-label

    plt.tight_layout()
    plt.show()

data =   [[0.8622876860849311], [0.1377123139150688], 
             [0.8439943333112543], [0.1560056666887458], 
             [0.8770728143177062, 0.9130725607847464, 0.9181140122281998, 1.0342200627703295, 0.9854145916376634, 1.0047173830851317, 1.045362850292477, 1.0379357052198676, 1.042456119422098], 
          [0.0, 0.0, 0.0], [0.9967792064086307, 1.0025142343342354, 1.0095222991203196, 0.9625520580440583, 1.0016179576315723, 0.9962618762337758, 0.9908922226033656, 1.0223944392215003, 0.9978897069598423],
          [0.0, 0.0, 0.0], [0.9773893143558585, 1.001056118932614, 0.9855545667115278], [0.0, 0.0, 0.0], [0.8676380133186383, 1.0616756426730825, 0.9976865190082793], 
          [0.0, 0.0, 0.0], [0.9614878303338434, 1.057587936417634, 1.018878134060607], [0.0, 0.0, 0.0], [1.0732070583379898, 1.0819478791899868, 0.9994708007200236], 
             [0.0, 0.0, 0.0]]

labels = ['Neg Cyclo (Pdt+EDA)', 'Neg  2-CH  (Pdt+EDA)', 'Neg Cyclo (Pdt)', 'Neg 2-CH  (Pdt)', 
         'HetCPI Cyclo (Pdt+EDA)',  'HetCPI 2-CH  (Pdt+EDA)', 'HetCPI Cyclo (Pdt)', 'HetCPI 2-CH  (Pdt)',
         'HetCPII Cyclo (Pdt+EDA)', 'HetCPII 2-CH  (Pdt+EDA)', 'HetCPII Cyclo (Pdt)', 'HetCPII 2-CH  (Pdt)'
         , 'HetCPIII Cyclo (Pdt+EDA)', 'HetCPIII 2-CH  (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)', 'HetCPIII 2-CH  (Pdt)']
    
plot_histogram_with_std(data, labels)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set colors for all histograms
    colors = ['#800080'] * 4 + ['#1f77b4'] * (len(labels) - 4)

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6, rotation=45, ha='right')
    ax.set_xlabel('')
    ax.set_ylabel('Normalized Activity')

    

    # Increase size of y-axis
    plt.ylim(bottom=0, top=1.2)

    plt.tight_layout()
    plt.show()


data =   [[0.8622876860849311], [0.1377123139150688], 
             [0.8439943333112543], [0.1560056666887458], 
             [0.8770728143177062, 0.9130725607847464, 0.9181140122281998, 1.0342200627703295, 0.9854145916376634, 1.0047173830851317, 1.045362850292477, 1.0379357052198676, 1.042456119422098], 
          [0.0, 0.0, 0.0], [0.9967792064086307, 1.0025142343342354, 1.0095222991203196, 0.9625520580440583, 1.0016179576315723, 0.9962618762337758, 0.9908922226033656, 1.0223944392215003, 0.9978897069598423],
          [0.0, 0.0, 0.0], [0.9773893143558585, 1.001056118932614, 0.9855545667115278], [0.0, 0.0, 0.0], [0.8676380133186383, 1.0616756426730825, 0.9976865190082793], 
          [0.0, 0.0, 0.0], [0.9614878303338434, 1.057587936417634, 1.018878134060607], [0.0, 0.0, 0.0], [1.0732070583379898, 1.0819478791899868, 0.9994708007200236], 
             [0.0, 0.0, 0.0]]

labels = ['Neg Cyclo (Pdt+EDA)', 'Neg  2-CH  (Pdt+EDA)', 'Neg Cyclo (Pdt)', 'Neg 2-CH  (Pdt)', 
         'HetCPI Cyclo (Pdt+EDA)',  'HetCPI 2-CH  (Pdt+EDA)', 'HetCPI Cyclo (Pdt)', 'HetCPI 2-CH  (Pdt)',
         'HetCPII Cyclo (Pdt+EDA)', 'HetCPII 2-CH  (Pdt+EDA)', 'HetCPII Cyclo (Pdt)', 'HetCPII 2-CH  (Pdt)'
         , 'HetCPIII Cyclo (Pdt+EDA)', 'HetCPIII 2-CH  (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)', 'HetCPIII 2-CH  (Pdt)']

plot_histogram_with_std(data, labels)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set colors for all histograms
    colors = ['#800080', '#800080', '#800080', '#800080', '#1f77b4', '#1f77b4', '#1f77b4', '#1f77b4', '#17becf', '#17becf', '#17becf', '#17becf','#8c564b', '#8c564b', '#8c564b', '#8c564b' ]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6, rotation=45, ha='right')
    ax.set_xlabel('')
    ax.set_ylabel('Normalized Activity')

    # Create proxy artists for the legend
    group1_patch = mpatches.Patch(color='#800080', label='Negative Controls')
    group2_patch = mpatches.Patch(color='#1f77b4', label='HetCPI')
    group3_patch = mpatches.Patch(color='#17becf', label='HetCPII')
    group4_patch = mpatches.Patch(color='#8c564b', label='HetCPIII')

    # Add legends
    ax.legend(handles=[group1_patch, group2_patch, group3_patch, group4_patch], title='', loc='upper right')

    # Increase size of y-axis
    plt.ylim(bottom=0, top=1.7)

    plt.tight_layout()
    plt.show()


data = [[0.8622876860849311], [0.1377123139150688],
        [0.8439943333112543], [0.1560056666887458],
        [0.8770728143177062, 0.9130725607847464, 0.9181140122281998, 1.0342200627703295, 0.9854145916376634, 1.0047173830851317, 1.045362850292477, 1.0379357052198676, 1.042456119422098],
        [0.0, 0.0, 0.0], [0.9967792064086307, 1.0025142343342354, 1.0095222991203196, 0.9625520580440583, 1.0016179576315723, 0.9962618762337758, 0.9908922226033656, 1.0223944392215003, 0.9978897069598423],
        [0.0, 0.0, 0.0], [0.9773893143558585, 1.001056118932614, 0.9855545667115278], [0.0, 0.0, 0.0], [0.8676380133186383, 1.0616756426730825, 0.9976865190082793],
        [0.0, 0.0, 0.0], [0.9614878303338434, 1.057587936417634, 1.018878134060607], [0.0, 0.0, 0.0], [1.0732070583379898, 1.0819478791899868, 0.9994708007200236],
        [0.0, 0.0, 0.0]]

labels = ['Neg Cyclo (Pdt+EDA)', 'Neg 2-CH  (Pdt+EDA)', 'Neg Cyclo (Pdt)', 'Neg 2-CH  (Pdt)',
          'Het CPI Cyclo (Pdt+EDA)', 'HetCPI 2-CH  (Pdt+EDA)', 'HetCPI Cyclo (Pdt)', 'HetCPI 2-CH  (Pdt)',
          'HetCPII Cyclo (Pdt+EDA)', 'HetCPII 2-CH (Pdt+EDA)', 'HetCPII Cyclo (Pdt)', 'HetCPII 2-CH  (Pdt)',
          'HetCPIII Cyclo (Pdt+EDA)', ' HetCPIII 2-CH  (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)', '2-CH  (Pdt)']

plot_histogram_with_std(data, labels)

# %%
import numpy as np

import matplotlib.pyplot as plt
import numpy as np

def plot_histogram_with_std(data, labels):
    fig, ax = plt.subplots()
    index = np.arange(len(data))
    bar_width = 0.5
    opacity = 0.8
    
    rects = ax.bar(index, data, bar_width, alpha=opacity, color='purple')
    
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.set_title('')
    ax.set_xticks(index)
    ax.set_xticklabels(labels, fontsize='small')  # Set font size of x-axis tick labels
    
    plt.tight_layout()
    plt.show()
    
    
# Negative control data

data = [[104011.6052], [16611.2529], [102436.5435], [18934.5836]]
labels = ['Neg Cyclo (Pdt+EDA)', 'Neg  2-CH  (Pdt+EDA)', 'Neg Cyclo (Pdt)', 'Neg 2-CH  (Pdt)']


sum_1_2 = data[0][0] + data[1][0]  # Compute sum of the 1st and 2nd element
sum_3_4 = data[2][0] + data[3][0]  # Compute sum of the 3rd and 4th element

result = [
    [data[0][0] / sum_1_2, data[1][0] / sum_1_2],  # Element-wise division for 1st two values
    [data[2][0] / sum_3_4, data[3][0] / sum_3_4]   # Element-wise division for next two values
]

print("Element-wise division results:", result)

result = [0.8622876860849311, 0.1377123139150688, 0.8439943333112543, 0.1560056666887458]

plot_histogram_with_std(result, labels)
# Out:
# Element-wise division results: [[0.8622876860849311, 0.1377123139150688], [0.8439943333112543, 0.1560056666887458]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Set color for all histograms

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, color=color, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')

    plt.tight_layout()
    plt.show()

# All plots degradation Reaction Data
data = [[104011.6052],  [102436.5435],
        [93008.6197, 96784.8427, 97280.3408, 109443.9164, 104413.7711, 106582.3565, 110569.6544, 109766.5255, 110229.4001], 
        [108226.2345, 108627.1427, 109311.2397, 104367.0014, 108959.6542, 108120.2728, 107581.3338, 110506.9616, 108592.4507], 
        [101627.3998, 104375.913, 102716.0704], [91546.6729, 112085.6556, 105386.9458],  
        [100850.3851, 110988.1734, 106139.2711], [117314.94, 118279.2254, 109227.3439]] 
        
labels = ['Neg Cyclo (Pdt+EDA)', 'Neg Cyclo (Pdt)', 
         'HetCPI Cyclo (Pdt+EDA)', 'HetCPI Cyclo (Pdt)',
         'HetCPII Cyclo (Pdt+EDA)', 'HetCPII Cyclo (Pdt)',
          'HetCPIII Cyclo (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)']

divided_data = []

for i, sublist in enumerate(data):
    divisor = data[i][0]  # Get the value of the ith element in the first sublist
    
    if i % 2 == 0:
        # Divide the elements in the sublist by the divisor (for 1st, 3rd, 5th, 7th elements)
        divided_sublist = [element / divisor for element in sublist]
    else:
        # Divide the elements in the sublist by the divisor (for 2nd, 4th, 6th, 8th elements)
        divided_sublist = [element / data[i-1][0] for element in sublist]
        
    divided_data.append(divided_sublist)

# Display the divided data
for i, sublist in enumerate(divided_data):
    label = labels[i]
    print(f"{label}: {sublist}")

plot_histogram_with_std(divided_data, labels)
# Out:
# Neg Cyclo (Pdt+EDA): [1.0]
# Neg Cyclo (Pdt): [0.9848568657605911]
# HetCPI Cyclo (Pdt+EDA): [1.0, 1.0406007853054935, 1.0459282280908853, 1.1767072423288527, 1.1226246710980918, 1.145940632640095, 1.1888108301858822, 1.180175835896208, 1.185152520868988]
# HetCPI Cyclo (Pdt): [1.1636151020097336, 1.167925543356924, 1.1752807433610373, 1.1221218177050314, 1.1715006044756948, 1.1624758344844033, 1.1566813285371227, 1.1881367765314768, 1.1675525456701301]
# HetCPII Cyclo (Pdt+EDA): [1.0, 1.0270450016964814, 1.010712372865413]
# HetCPII Cyclo (Pdt): [0.9008069977207073, 1.1029078360814266, 1.0369934290102736]
# HetCPIII Cyclo (Pdt+EDA): [1.0, 1.1005230499610656, 1.0524428934481085]
# HetCPIII Cyclo (Pdt): [1.163257233809016, 1.1728187778630506, 1.0830632306628645]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15476\442118789.py in <module>
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the bars
    colors = ['purple' if i < 2 else 'blue' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')

    plt.tight_layout()
    plt.show()

# All plots degradation Reaction Data
data = [[104011.6052],  [102436.5435],
        [93008.6197, 96784.8427, 97280.3408, 109443.9164, 104413.7711, 106582.3565, 110569.6544, 109766.5255, 110229.4001], 
        [108226.2345, 108627.1427, 109311.2397, 104367.0014, 108959.6542, 108120.2728, 107581.3338, 110506.9616, 108592.4507], 
        [101627.3998, 104375.913, 102716.0704], [91546.6729, 112085.6556, 105386.9458],  
        [100850.3851, 110988.1734, 106139.2711], [117314.94, 118279.2254, 109227.3439]] 
        
labels = ['Neg Cyclo (Pdt+EDA)', 'Neg Cyclo (Pdt)', 
         'HetCPI Cyclo (Pdt+EDA)', 'HetCPI Cyclo (Pdt)',
         'HetCPII Cyclo (Pdt+EDA)', 'HetCPII Cyclo (Pdt)',
         'HetCPIII Cyclo (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)']

divided_data = []

for i, sublist in enumerate(data):
    divisor = data[i//2][0]  # Get the value of the corresponding element in the first sublist
    
    divided_sublist = [element / divisor for element in sublist]
        
    divided_data.append(divided_sublist)


# Display the divided data
for i, sublist in enumerate(divided_data):
    label = labels[i]
    print(f"{label}: {sublist}")

plot_histogram_with_std(divided_data, labels)
# Out:
# Neg Cyclo (Pdt+EDA): [1.0]
# Neg Cyclo (Pdt): [0.9848568657605911]
# HetCPI Cyclo (Pdt+EDA): [0.90796327679682, 0.9448272988633202, 0.949664421271692, 1.068406963575455, 1.0193019749831758, 1.0404720118265216, 1.0793965768671216, 1.071556319156747, 1.0760749663522178]
# HetCPI Cyclo (Pdt): [1.0565197809510236, 1.0604335034010592, 1.0671117548982898, 1.0188454025686644, 1.0636795276092073, 1.0554853678755767, 1.050224169268265, 1.0787845609023308, 1.0600948351991202]
# HetCPII Cyclo (Pdt+EDA): [1.0926664660522858, 1.1222176324803583, 1.104371516654171]
# HetCPII Cyclo (Pdt): [0.9842815987946546, 1.205110407632466, 1.1330879453960976]
# HetCPIII Cyclo (Pdt+EDA): [0.9318478607883193, 1.0255200498544554, 0.9807166588614888]
# HetCPIII Cyclo (Pdt): [1.0839787648714694, 1.0928886692440545, 1.009250154591676]

# %%
import pandas as pd
import os

data = [[104011.6052],  [102436.5435],
        [93008.6197, 96784.8427, 97280.3408, 109443.9164, 104413.7711, 106582.3565, 110569.6544, 109766.5255, 110229.4001], [108226.2345, 108627.1427, 109311.2397, 104367.0014, 108959.6542, 108120.2728, 107581.3338, 110506.9616, 108592.4507], 
        [101627.3998, 104375.913, 102716.0704], [91546.6729, 112085.6556, 105386.9458],  
        [100850.3851, 110988.1734, 106139.2711], [117314.94, 118279.2254, 109227.3439]] 

# Flatten the data list
flattened_data = [item for sublist in data for item in sublist]

# Create a DataFrame with a single column from the flattened data
df = pd.DataFrame(flattened_data, columns=["Data"])

# Define the output file path
output_file = "output.xlsx"

# Get the absolute path of the current working directory
current_directory = os.getcwd()

# Define the absolute path of the output file
output_path = os.path.join(current_directory, output_file)

# Save the DataFrame as an Excel file
df.to_excel(output_path, index=False)

# Print the absolute path of the output file
print("Output file is saved at:", output_path)
# Out:
# Output file is saved at: C:\Users\josep\evSeq\examples\output.xlsx

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (green and blue)
    colors = ['#800080'] * 2 + ['#1f77b4'] * (len(labels) - 2)

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=8.1, rotation=45, ha='right')
    ax.set_xlabel('')
    ax.set_ylabel('AUC (a.u)')
    plt.tight_layout()
    plt.show()

# Example data and labels
data = [[104011.6052],  [102436.5435],
        [93008.6197, 96784.8427, 97280.3408, 109443.9164, 104413.7711, 106582.3565, 110569.6544, 109766.5255, 110229.4001], [108226.2345, 108627.1427, 109311.2397, 104367.0014, 108959.6542, 108120.2728, 107581.3338, 110506.9616, 108592.4507], 
        [101627.3998, 104375.913, 102716.0704], [91546.6729, 112085.6556, 105386.9458],  
        [100850.3851, 110988.1734, 106139.2711], [117314.94, 118279.2254, 109227.3439]] 
        
labels = ['Neg Cyclo (Pdt+EDA)', 'Neg Cyclo (Pdt)', 
         'HetCPI Cyclo (Pdt+EDA)', 'HetCPI Cyclo (Pdt)',
         'HetCPII Cyclo (Pdt+EDA)', 'HetCPII Cyclo (Pdt)',
          'HetCPIII Cyclo (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)']

# Call the function to plot the histograms
plot_histogram_with_std(data, labels)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (green and blue)
    colors = ['#800080'] * 4 + ['#1f77b4'] * (len(labels) - 4)

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, palette=colors, alpha=0.7)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6, rotation=45, ha='right')
    ax.set_xlabel('')
    ax.set_ylabel('AUC (a.u)')
    plt.tight_layout()
    plt.show()

# Example data and labels
data = [[104011.6052], [16611.2529], [102436.5435], [18934.5836],
        [93008.6197, 96784.8427, 97280.3408, 109443.9164, 104413.7711, 106582.3565, 110569.6544, 109766.5255, 110229.4001], [0,0,0], [108226.2345, 108627.1427, 109311.2397, 104367.0014, 108959.6542, 108120.2728, 107581.3338, 110506.9616, 108592.4507], [0,0,0], 
        [101627.3998, 104375.913, 102716.0704], [0,0,0],[91546.6729, 112085.6556, 105386.9458], [0,0,0], 
        [100850.3851, 110988.1734, 106139.2711], [0,0,0], [117314.94, 118279.2254, 109227.3439], [0,0,0]] 

labels = ['Neg Cyclo (Pdt+EDA)', 'Neg  2-CH  (Pdt+EDA)', 'Neg Cyclo (Pdt)', 'Neg 2-CH  (Pdt)', 
         'HetCPI Cyclo (Pdt+EDA)',  'HetCPI 2-CH  (Pdt+EDA)', 'HetCPI Cyclo (Pdt)', 'HetCPI 2-CH  (Pdt)',
         'HetCPII Cyclo (Pdt+EDA)', 'HetCPII 2-CH  (Pdt+EDA)', 'HetCPII Cyclo (Pdt)', 'HetCPII 2-CH  (Pdt)'
         , 'HetCPIII Cyclo (Pdt+EDA)', 'HetCPIII 2-CH  (Pdt+EDA)', 'HetCPIII Cyclo (Pdt)', 'HetCPIII 2-CH  (Pdt)']

plot_histogram_with_std(data, labels)
