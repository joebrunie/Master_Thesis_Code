# %%
# Monocyclopropanation activity P01-03 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 7, 13] else '#008000' if i in [1, 8, 14] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=5.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data = [[155.151,112.3656], [9464.0281, 5101.5952, 6947.4182, 6619.0017],  [29064.1998], [11103.2107], 
        [8889.8604], [10186.1956], [15197.5214], [0, 188.1612], [8532.213, 6030.996, 7094.8844, 5168.4942]
        , [13847.5157], [10586.4909], [14254.7671], [22728.7949], [170.2994, 606.4612], [9202.5996, 7869.6527, 8257.5057, 6070.0618], 
        [12998.8024], [7854.3335],[23488.7517],[11988.9546]]
     
labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 G3', 'P01 D8',  'P01 E4', 'P01 B4',   
          'P01 H12', 'P02 Sterile', 'P02 Parent (HetCPII)',  'P02 H11', 'P02 B3', 'P02 H2', 'P02 A10', 'P03 Sterile',  
          'P03 Parent (HetCPII)', 'P03 C3', 'P03 H12', 'P03 B6', 'P03 D12']

plot_histogram_with_std(data, labels)

# %%
# Monocyclopropanation activity P05-06 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 13] else '#008000' if i in [1, 14] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data = [[0,209.9774], [8288.4425, 5559.9387,4340.7185, 4270.159], [34366.394], [63974.1353], 
        [22674.0891], [35261.5101], [47554.1437], [27844.0552]
        , [18917.3326], [20562.5291], [15809.9537], [14654.4039], [11984.4504], 
        [435.784, 0], [2704.5882, 2274.7398, 2129.0644], [46889.4925],[14203.2591],[12093.203],[9141.0604],[9609.3794],
        [7351.7921],[6967.9455],[6100.5775],[6143.8581],[6849.3785],[5053.9981],[5893.0188],[4916.8347],
        [5547.8978],[5810.7122],[5097.9219]]
     
labels = ['P05 Sterile', 'P05 Parent (HetCPIII)', 'P05 F1', 'P05 A10',  'P05 G7', 'P05 D11',   
          'P05 H12', 'P05 G1', 'P05 C1', 'P05 E1', 'P05 D12', 'P05 H4', 
          'P05 D1', 'P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 D5', 'P06 E10', 'P06 A10', 'P06 D2', 'P06 C11', 
         'P06 E11','P06 A3', 'P06 A5', 'P06 C3', 'P06 F2', 'P06 D7', 
         'P06 F7', 'P06 B7', 'P06 B2', 'P06 B12', 'P06 B1']

plot_histogram_with_std(data, labels)

# %%
# Monocyclopropanation activity P07

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data = [[0,0], [1279.1165,3415.3073, 2476.1516, 3792.4102 ], [17649.0151], [12601.6155], 
        [12041.5026], [10375.3757], [10880.5606], [11356.3303]
        , [12363.9222], [11989.2528], [11494.377], [7026.628], [8806.9775], 
        [9048.5709], [13160.3684],[4234.4766],[8595.2424],[9007.7951],[6550.1158],
        [7769.8465],[7306.0806],[7095.0447],[6413.7697],[5961.1993]]
     
labels = ['P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 E7', 'P07 E4',  'P07 F2', 'P07 A5',   
          'P07 F4', 'P07 C1', 'P07 H4', 'P07 G2', 'P07 F1', 'P07 G11', 
          'P07 A4', 'P07 C3', 'P07 E1', 'P07 D5', 'P07 F5', 'P07 E2', 'P07 D3', 
         'P07 H6','P07 G6', 'P07 D11', 'P07 F7', 'P07 E5']

plot_histogram_with_std(data, labels)

# %%
# Monocyclopropanation activity P08

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data = [[174.8547,615.1132], [4484.8369, 2461.7574, 4358.0153, 3662.8887], [29356.6536], [34387.4045], 
        [22155.7827], [19785.5238], [13813.4733], [15752.1493], [13914.7806], [12113.5195], [6529.7027], 
        [19543.9063], [10641.0267], [11857.1497], [10618.563],[10133.6561],[9917.957],[10773.0998],[10320.9052],
        [8852.9632],[9085.3679],[8835.1854],[9197.9067],[8115.8472],[7267.3147],[8988.0323],[7359.7983],
        [7063.806],[8411.6299],[6621.3945], [7351.8344],[6427.7296],[7077.2343]]
     
labels = ['P08 Sterile', 'P08 Parent (HetCPIII)', 'P08 G11', 'P08 G4',  'P08 D2', 'P08 A12',   
          'P08 G9', 'P08 F11', 'P08 H10', 'P08 A10', 'P08 E2', 'P08 A5', 
          'P08 D12', 'P08 E8', 'P08 D10', 'P08 B11', 'P08 A11', 'P08 G12', 'P08 F12', 
         'P08 F3','P08 C12', 'P08 C1', 'P08 H11', 'P08 A7', 'P08 F10', 
         'P08 H2', 'P08 E10', 'P08 E3', 'P08 C10', 'P08 B9', 'P08 E12' , 'P08 B8' , 'P08 H12']

plot_histogram_with_std(data, labels)

# %%
# 2'CH Functionalization activity P01-03 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 7, 13] else '#008000' if i in [1, 8, 14] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=5.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data = [[158.2935, 115.8991], [10962.2266, 5880.5701, 7844.7827, 6939.5992],  [24616.0897], [34380.0481], 
        [27089.2945], [23424.1998], [13818.1525], [0, 234.4934], [8532.213, 6030.996, 7094.8844, 5168.4942]
        , [13847.5157], [10586.4909], [14254.7671], [22728.7949],[216.4026, 615.589],  [9202.599, 7869.6527, 8257.5057, 6070.0618], 
        [12998.8024], [7854.3335],[23488.7517],[11988.9546]]
     
labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 G3', 'P01 D8',  'P01 E4', 'P01 B4',   
          'P01 H12', 'P02 Sterile', 'P02 Parent (HetCPII)',  'P02 H11', 'P02 B3', 'P02 H2', 'P02 A10', 'P03 Sterile',  
          'P03 Parent (HetCPII)', 'P03 C3', 'P03 H12', 'P03 B6', 'P03 D12']

plot_histogram_with_std(data, labels)

# %%
# 2'CH Functionalization activity P05-06 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 13] else '#008000' if i in [1, 14] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data = [[128.6701,278.1534], [8809.7253, 5753.8654, 4300.523, 3655.4001], [85565.8925], [51813.222], 
        [56890.1363], [22378.4607], [0], [17475.3718]
        , [19048.0022], [13635.1775], [10903.0414], [11213.4919], [10763.9903],[275.0895, 0],  
        [2010.7137, 1986.8567, 1687.1624], [38374.2819],[13869.2845],[11223.4206],[8657.459],[8184.1699],
        [7114.9703],[6492.8394],[6121.3866],[5865.6711],[4741.4208],[5034.1526],[4475.9021],[4942.3085],
        [4043.8198],[3425.9866],[3601.4216]]
     
labels = ['P05 Sterile', 'P05 Parent (HetCPIII)', 'P05 F1', 'P05 A10',  'P05 G7', 'P05 D11',   
          'P05 H12', 'P05 G1', 'P05 C1', 'P05 E1', 'P05 D12', 'P05 H4', 
          'P05 D1', 'P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 D5', 'P06 E10', 'P06 A10', 'P06 D2', 'P06 C11', 
         'P06 E11','P06 A3', 'P06 A5', 'P06 C3', 'P06 F2', 'P06 D7', 
         'P06 F7', 'P06 B7', 'P06 B2', 'P06 B12', 'P06 B1']

plot_histogram_with_std(data, labels)

# %%
# 2'CH Functionalization activity P07 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data = [[0,0], [850.6257, 2729.5015, 2410.136, 3139.4912], [21423.3372], [10633.5668], 
        [8835.4919], [10285.5562], [9447.2131], [8433.3603]
        , [7190.0553], [7545.8502], [7564.5459], [10079.6326], [8156.6764], 
        [7702.6882], [3233.8494],[12080.8537],[7570.3181],[6628.7803],[8145.0034],
        [5712.0069],[5461.0927],[5798.679],[5991.1585],[5372.3239]]
     
labels = ['P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 E7', 'P07 E4',  'P07 F2', 'P07 A5',   
          'P07 F4', 'P07 C1', 'P07 H4', 'P07 G2', 'P07 F1', 'P07 G11', 
          'P07 A4', 'P07 C3', 'P07 E1', 'P07 D5', 'P07 F5', 'P07 E2', 'P07 D3', 
         'P07 H6','P07 G6', 'P07 D11', 'P07 F7', 'P07 E5']

plot_histogram_with_std(data, labels)

# %%
# 2'CH Functionalization activity P08 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data = [[329.8535, 707.5613], [4798.0871, 2642.0552, 4735.5697, 3525.7053], [29690.1506], [21872.505], 
        [28303.5231], [25891.1649], [19368.4004], [15727.8704], [15042.6721], [15977.5712], [19269.079], 
        [4274.0992], [11988.2397], [10752.5493], [11481.6464],[11308.4889],[11250.7166],[9438.6448],[9675.1148],
        [10424.3881],[9533.0179],[8988.4433],[7848.0169],[9732.9464],[9087.9369],[7142.1622],[7916.1503],
        [7774.3852],[6311.5503],[7718.3959], [6807.0784],[7231.0833],[5899.5083]]
     
labels = ['P08 Sterile', 'P08 Parent (HetCPIII)', 'P08 G11', 'P08 G4',  'P08 D2', 'P08 A12',   
          'P08 G9', 'P08 F11', 'P08 H10', 'P08 A10', 'P08 E2', 'P08 A5', 
          'P08 D12', 'P08 E8', 'P08 D10', 'P08 B11', 'P08 A11', 'P08 G12', 'P08 F12', 
         'P08 F3','P08 C12', 'P08 C1', 'P08 H11', 'P08 A7', 'P08 F10', 
         'P08 H2', 'P08 E10', 'P08 E3', 'P08 C10', 'P08 B9', 'P08 E12' , 'P08 B8' , 'P08 H12']

plot_histogram_with_std(data, labels)

# %%
# Total Activity  P01-03 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 7, 13] else '#008000' if i in [1, 8, 14] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

data1 = [[155.151,112.3656], [9464.0281, 5101.5952, 6947.4182, 6619.0017],  [29064.1998], [11103.2107], 
        [8889.8604], [10186.1956], [15197.5214], [0, 188.1612], [8532.213, 6030.996, 7094.8844, 5168.4942]
        , [13847.5157], [10586.4909], [14254.7671], [22728.7949], [170.2994, 606.4612], [9202.5996, 7869.6527, 8257.5057, 6070.0618], 
        [12998.8024], [7854.3335],[23488.7517],[11988.9546]]

data2 = [[158.2935, 115.8991], [10962.2266, 5880.5701, 7844.7827, 6939.5992],  [24616.0897], [34380.0481], 
        [27089.2945], [23424.1998], [13818.1525], [0, 234.4934], [8532.213, 6030.996, 7094.8844, 5168.4942]
        , [13847.5157], [10586.4909], [14254.7671], [22728.7949],[216.4026, 615.589],  [9202.599, 7869.6527, 8257.5057, 6070.0618], 
        [12998.8024], [7854.3335],[23488.7517],[11988.9546]]

labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 G3', 'P01 D8',  'P01 E4', 'P01 B4',   
          'P01 H12', 'P02 Sterile', 'P02 Parent (HetCPII)',  'P02 H11', 'P02 B3', 'P02 H2', 'P02 A10', 'P03 Sterile',  
          'P03 Parent (HetCPII)', 'P03 C3', 'P03 H12', 'P03 B6', 'P03 D12']

# Ensure data1 and data2 have the same shape
if len(data1) != len(data2):
    raise ValueError("Arrays must have the same length")

data = []
for arr1, arr2 in zip(data1, data2):
    if len(arr1) != len(arr2):
        raise ValueError("Sub-arrays must have the same length")
    data.append([x + y for x, y in zip(arr1, arr2)])
    
    
plot_histogram_with_std(data, labels)

print(data)

# Flatten the nested list
flat_data = [value for sublist in data for value in sublist]

# Convert the flattened list to a DataFrame
df = pd.DataFrame({'Label': labels})

# Export the DataFrame to an Excel file
df.to_excel('output.xlsx', index=False)
# Out:
# [[313.4445, 228.2647], [20426.254699999998, 10982.1653, 14792.2009, 13558.6009], [53680.2895], [45483.258799999996], [35979.1549], [33610.395399999994], [29015.6739], [0, 422.6546], [17064.426, 12061.992, 14189.7688, 10336.9884], [27695.0314], [21172.9818], [28509.5342], [45457.5898], [386.702, 1222.0502000000001], [18405.1986, 15739.3054, 16515.0114, 12140.1236], [25997.6048], [15708.667], [46977.5034], [23977.9092]]

# %%
# Normalized Total Activity  P01-03 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 7, 13] else '#008000' if i in [1, 8, 14] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

data1 = [[155.151,112.3656], [9464.0281, 5101.5952, 6947.4182, 6619.0017],  [29064.1998], [11103.2107], 
        [8889.8604], [10186.1956], [15197.5214], [0, 188.1612], [8532.213, 6030.996, 7094.8844, 5168.4942]
        , [13847.5157], [10586.4909], [14254.7671], [22728.7949], [170.2994, 606.4612], [9202.5996, 7869.6527, 8257.5057, 6070.0618], 
        [12998.8024], [7854.3335],[23488.7517],[11988.9546]]

data2 = [[158.2935, 115.8991], [10962.2266, 5880.5701, 7844.7827, 6939.5992],  [24616.0897], [34380.0481], 
        [27089.2945], [23424.1998], [13818.1525], [0, 234.4934], [8532.213, 6030.996, 7094.8844, 5168.4942]
        , [13847.5157], [10586.4909], [14254.7671], [22728.7949],[216.4026, 615.589],  [9202.599, 7869.6527, 8257.5057, 6070.0618], 
        [12998.8024], [7854.3335],[23488.7517],[11988.9546]]

labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 G3', 'P01 D8',  'P01 E4', 'P01 B4',   
          'P01 H12', 'P02 Sterile', 'P02 Parent (HetCPII)',  'P02 H11', 'P02 B3', 'P02 H2', 'P02 A10', 'P03 Sterile',  
          'P03 Parent (HetCPII)', 'P03 C3', 'P03 H12', 'P03 B6', 'P03 D12']

# Ensure data1 and data2 have the same shape
if len(data1) != len(data2):
    raise ValueError("Arrays must have the same length")

data = []
for arr1, arr2 in zip(data1, data2):
    if len(arr1) != len(arr2):
        raise ValueError("Sub-arrays must have the same length")
    data.append([x + y for x, y in zip(arr1, arr2)])
    
# Divide the 1-5rd elements by the average of the second element
data[1:5] = [[x / np.mean(data[2]) for x in sublist] for sublist in data[1:5]]

# Divide the 2-3rd elements by the average of the second element
data[5:7] = [[x / np.mean(data[6]) for x in sublist] for sublist in data[5:7]]

# Divide the 5-15th elements by the value of the 5th element
data[7:9] = [[x / data[8][0] for x in sublist] for sublist in data[7:9]]

# Create a new variable with the updated values
normalized_data = data

plot_histogram_with_std(normalized_data, labels)
plot_histogram_with_std(data, labels)

print(data)
# Out:
# [[313.4445, 228.2647], [0.38051685060305046, 0.20458468838920849, 0.27556112379013903, 0.25258062179415036], [1.0], [0.8472990593688955], [0.6702488983409823], [1.1583530858471631], [1.0], [0.0, 0.02476816975853744], [1.0, 0.7068501454429232, 0.8315409378551614, 0.6057624440458765], [27695.0314], [21172.9818], [28509.5342], [45457.5898], [386.702, 1222.0502000000001], [18405.1986, 15739.3054, 16515.0114, 12140.1236], [25997.6048], [15708.667], [46977.5034], [23977.9092]]

# %%
#Normalized Total Activity (P01-03) - With 1.5-fold threshold

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

   # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 7, 13] else '#008000' if i in [1, 8, 14] else '#1f77b4' for i in range(len(labels))]
    
    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=6.2, rotation=45, ha='right')
    plt.tight_layout()
    # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
    plt.show()


# All plots degradation Reaction Data
data =[[313.4445, 228.2647], [20426.254699999998, 10982.1653, 14792.2009, 13558.6009], [53680.2895], 
       [45483.258799999996], [35979.1549], [33610.395399999994], [29015.6739], [0, 422.6546], [17064.426, 12061.992, 14189.7688, 10336.9884], [27695.0314], 
       [21172.9818], [28509.5342], [45457.5898], 
       [386.702, 1222.0502000000001], [18405.1986, 15739.3054, 16515.0114, 12140.1236], [25997.6048], [15708.667], [46977.5034], [23977.9092]]

labels = ['P01 Sterile', 'P01 Parent (HetCPIII)', 'P01 G3', 'P01 D8',  'P01 E4', 'P01 B4',   
          'P01 H12', 'P02 Sterile', 'P02 Parent (HetCPII)',  'P02 H11', 'P02 B3', 'P02 H2', 'P02 A10', 'P03 Sterile',  
          'P03 Parent (HetCPII)', 'P03 C3', 'P03 H12', 'P03 B6', 'P03 D12']

average_2 = sum(data[1]) / len(data[1])
average_9 = sum(data[8]) / len(data[8])
average_15 = sum(data[14]) / len(data[14])

data[1] = [average_2]
data[8] = [average_9]
data[14] = [average_15]


# Perform division on elements 1-7 with the average of element 2
for i in range(0, 6):
    data[i] = [elem / average_2 for elem in data[i]]

# Perform division on elements 8-13 with the value of element 8
for i in range(6, 13):
    data[i] = [elem / average_9 for elem in data[i]]
    
# Perform division on elements 6-10 with the value of element 8
for i in range(13, 19):
    data[i] = [elem / average_15 for elem in data[i]]

print("Updated data array:")
print(data)

# Create a new variable with the updated values
normalized_data = data

plot_histogram_with_std(normalized_data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# Updated data array:
# [[0.020980494093381923, 0.015278960677496643], [1.0], [3.5931049891951576], [3.044434477558742], [2.4082746606315415], [2.2497210899088382], [2.163202739956386], [0.0, 0.03151012766155917], [1.0], [2.064745006927381], [1.5785072716441955], [2.1254685556801864], [3.3889953115020863], [0.02463084222506438, 0.07783803980147083], [1.0], [1.6559079137381665], [1.000557789830607], [2.992214869260634], [1.5272641423941942]]
# Bars above y=1.5: []

# %%
# Total Activity  P05-06 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 13] else '#008000' if i in [1, 14] else '#1f77b4' for i in range(len(labels))]
    
    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# All plots degradation Reaction Data
data2 = [
    [128.6701, 278.1534],
    [8809.7253, 5753.8654, 4300.523, 3655.4001],
    [85565.8925],
    [51813.222],
    [56890.1363],
    [22378.4607],
    [0],
    [17475.3718],
    [19048.0022],
    [13635.1775],
    [10903.0414],
    [11213.4919],
    [10763.9903],
    [275.0895, 0],
    [2010.7137, 1986.8567, 1687.1624],
    [38374.2819],
    [13869.2845],
    [11223.4206],
    [8657.459],
    [8184.1699],
    [7114.9703],
    [6492.8394],
    [6121.3866],
    [5865.6711],
    [4741.4208],
    [5034.1526],
    [4475.9021],
    [4942.3085],
    [4043.8198],
    [3425.9866],
    [3601.4216]
]

data1 = [
    [0, 209.9774],
    [8288.4425, 5559.9387, 4340.7185, 4270.159],
    [34366.394],
    [63974.1353],
    [22674.0891],
    [35261.5101],
    [47554.1437],
    [27844.0552],
    [18917.3326],
    [20562.5291],
    [15809.9537],
    [14654.4039],
    [11984.4504],
    [435.784, 0],
    [2704.5882, 2274.7398, 2129.0644],
    [46889.4925],
    [14203.2591],
    [12093.203],
    [9141.0604],
    [9609.3794],
    [7351.7921],
    [6967.9455],
    [6100.5775],
    [6143.8581],
    [6849.3785],
    [5053.9981],
    [5893.0188],
    [4916.8347],
    [5547.8978],
    [5810.7122],
    [5097.9219]
]

labels = [
    'P05 Sterile', 'P05 Parent (HetCPIII)', 'P05 F1', 'P05 A10', 'P05 G7', 'P05 D11',
    'P05 H12', 'P05 G1', 'P05 C1', 'P05 E1', 'P05 D12', 'P05 H4',
    'P05 D1', 'P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 D5', 'P06 E10', 'P06 A10', 'P06 D2', 'P06 C11',
    'P06 E11', 'P06 A3', 'P06 A5', 'P06 C3', 'P06 F2', 'P06 D7',
    'P06 F7', 'P06 B7', 'P06 B2', 'P06 B12', 'P06 B1'
]

# Ensure data1 and data2 have the same shape
if len(data1) != len(data2):
    raise ValueError("Arrays must have the same length")

data = []
for arr1, arr2 in zip(data1, data2):
    if len(arr1) != len(arr2):
        raise ValueError("Sub-arrays must have the same length")
    data.append([x + y for x, y in zip(arr1, arr2)])

plot_histogram_with_std(data, labels)

print(data)
len(labels)
# Out:
# [[128.6701, 488.13079999999997], [17098.1678, 11313.8041, 8641.2415, 7925.5590999999995], [119932.2865], [115787.3573], [79564.2254], [57639.970799999996], [47554.1437], [45319.426999999996], [37965.3348], [34197.7066], [26712.9951], [25867.8958], [22748.4407], [710.8734999999999, 0], [4715.3019, 4261.5965, 3816.2268000000004], [85263.7744], [28072.543599999997], [23316.6236], [17798.5194], [17793.5493], [14466.7624], [13460.784899999999], [12221.964100000001], [12009.5292], [11590.799299999999], [10088.1507], [10368.920900000001], [9859.1432], [9591.7176], [9236.6988], [8699.3435]]
# 31

# %%
#Normalized Total Activity (P05-06)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0, 13] else '#008000' if i in [1, 14] else '#1f77b4' for i in range(len(labels))]
    
    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=5.8, rotation=45, ha='right')
    plt.tight_layout()
    # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
    plt.show()


# All plots degradation Reaction Data
data = [[128.6701, 488.13079999999997], [17098.1678, 11313.8041, 8641.2415, 7925.5590999999995], [119932.2865], [115787.3573], [79564.2254], 
        [57639.970799999996], [47554.1437], [45319.426999999996], [37965.3348], [34197.7066], [26712.9951], [25867.8958], [22748.4407], [710.8734999999999, 0], [4715.3019, 4261.5965, 3816.2268000000004], [85263.7744], [28072.543599999997], [23316.6236], [17798.5194], [17793.5493], [14466.7624], [13460.784899999999], [12221.964100000001], [12009.5292], [11590.799299999999], [10088.1507], [10368.920900000001],
        [9859.1432], [9591.7176], [9236.6988], [8699.3435]]

labels = [
    'P05 Sterile', 'P05 Parent (HetCPIII)', 'P05 F1', 'P05 A10', 'P05 G7', 'P05 D11',
    'P05 H12', 'P05 G1', 'P05 C1', 'P05 E1', 'P05 D12', 'P05 H4',
    'P05 D1', 'P06 Sterile', 'P06 Parent (HetCPIII)', 'P06 D5', 'P06 E10', 'P06 A10', 'P06 D2', 'P06 C11',
    'P06 E11', 'P06 A3', 'P06 A5', 'P06 C3', 'P06 F2', 'P06 D7',
    'P06 F7', 'P06 B7', 'P06 B2', 'P06 B12', 'P06 B1'
]


# Divide the 1-7th elements by the average of the second element
data[0:13] = [[x / np.mean(data[1]) for x in sublist] for sublist in data[0:13]]

# Divide the 14-19th elements by the value of the 14th element
data[13:31] = [[x / data[14][0] for x in sublist] for sublist in data[13:31]]

# Create a new variable with the updated values
normalized_data = data
print(normalized_data)
plot_histogram_with_std(normalized_data, labels)


# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# [[0.01144274001697134, 0.043409881850377315], [1.5205544170864158, 1.006146097028326, 0.7684728612813968, 0.7048266246038618], [10.665678926653682], [10.297066893054943], [7.075713362342204], [5.125970994428539], [4.229029922948654], [4.030294690678809], [3.376289097262492], [3.041230758353844], [2.3756090809281205], [2.300453690682644], [2.023037929725628], [0.15075885172909073, 0.0], [1.0, 0.90378020122105, 0.8093282001731427], [18.08235744141854], [5.953498672057455], [4.9448845682606235], [3.774629870464922], [3.7735758340309022], [3.068045844530124], [2.854702664955556], [2.5919791265114966], [2.5469268892411745], [2.4581245370524414], [2.1394495864623218], [2.1989940665305014], [2.090882706789145], [2.0341682894153603], [1.9588775005053227], [1.8449176075025016]]
# Bars above y=1.5: ['P05 Sterile']

# %%
# Total Activity P07 (JB-2-8)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1] else '#2ca02c' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    

data1 = [[0,0], [1279.1165,3415.3073, 2476.1516, 3792.4102 ], [17649.0151], [12601.6155], 
        [12041.5026], [10375.3757], [10880.5606], [11356.3303]
        , [12363.9222], [11989.2528], [11494.377], [7026.628], [8806.9775], 
        [9048.5709], [13160.3684],[4234.4766],[8595.2424],[9007.7951],[6550.1158],
        [7769.8465],[7306.0806],[7095.0447],[6413.7697],[5961.1993]]

data2 = [[0,0], [850.6257, 2729.5015, 2410.136, 3139.4912], [21423.3372], [10633.5668], 
        [8835.4919], [10285.5562], [9447.2131], [8433.3603]
        , [7190.0553], [7545.8502], [7564.5459], [10079.6326], [8156.6764], 
        [7702.6882], [3233.8494],[12080.8537],[7570.3181],[6628.7803],[8145.0034],
        [5712.0069],[5461.0927],[5798.679],[5991.1585],[5372.3239]]
     
labels = ['P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 E7', 'P07 E4',  'P07 F2', 'P07 A5',   
          'P07 F4', 'P07 C1', 'P07 H4', 'P07 G2', 'P07 F1', 'P07 G11', 
          'P07 A4', 'P07 C3', 'P07 E1', 'P07 D5', 'P07 F5', 'P07 E2', 'P07 D3', 
         'P07 H6','P07 G6', 'P07 D11', 'P07 F7', 'P07 E5']
    

# Ensure data1 and data2 have the same shape
if len(data1) != len(data2):
    raise ValueError("Arrays must have the same length")

data = []
for arr1, arr2 in zip(data1, data2):
    if len(arr1) != len(arr2):
        raise ValueError("Sub-arrays must have the same length")
    data.append([x + y for x, y in zip(arr1, arr2)])

plot_histogram_with_std(data, labels)

len(labels)
print(data)
# Out:
# [[0, 0], [2129.7422, 6144.8088, 4886.2876, 6931.9014], [39072.3523], [23235.1823], [20876.9945], [20660.931900000003], [20327.7737], [19789.6906], [19553.9775], [19535.103], [19058.9229], [17106.2606], [16963.6539], [16751.2591], [16394.2178], [16315.3303], [16165.5605], [15636.5754], [14695.1192], [13481.8534], [12767.1733], [12893.7237], [12404.928199999998], [11333.5232]]

# %%
#Normalized Total Activity (P07)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#1f77b4' if i not in [1] else '#2ca02c' for i in range(len(labels))]
    
    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=5.8, rotation=45, ha='right')
    plt.tight_layout()
     # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
    plt.show()


# All plots degradation Reaction Data
data = [[0, 0], [2129.7422, 6144.8088, 4886.2876, 6931.9014], [39072.3523], [23235.1823], [20876.9945], [20660.931900000003], 
        [20327.7737], [19789.6906], [19553.9775], [19535.103], [19058.9229], [17106.2606], [16963.6539], [16751.2591], 
        [16394.2178], [16315.3303], [16165.5605], [15636.5754], [14695.1192], [13481.8534], [12767.1733], [12893.7237], [12404.928199999998], [11333.5232]]

labels = ['P07 Sterile', 'P07 Parent (HetCPIII)', 'P07 E7', 'P07 E4',  'P07 F2', 'P07 A5',   
          'P07 F4', 'P07 C1', 'P07 H4', 'P07 G2', 'P07 F1', 'P07 G11', 
          'P07 A4', 'P07 C3', 'P07 E1', 'P07 D5', 'P07 F5', 'P07 E2', 'P07 D3', 
         'P07 H6','P07 G6', 'P07 D11', 'P07 F7', 'P07 E5']


# Divide the 1-7th elements by the average of the second element
data[0:24] = [[x / np.mean(data[1]) for x in sublist] for sublist in data[0:24]]

# Create a new variable with the updated values
normalized_data = data
print(normalized_data)
plot_histogram_with_std(normalized_data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# [[0.0, 0.0], [0.4239824334560643, 1.223289367204274, 0.9727468926587415, 1.3799813066809206], [7.778402009880186], [4.625587610251266], [4.156126939382085], [4.113113870980266], [4.046789775809572], [3.939669870809059], [3.8927448421668727], [3.888987365585779], [3.794190916719174], [3.4054609973552643], [3.377071300380138], [3.334788406160633], [3.2637097379451485], [3.2480050605343025], [3.2181893559564303], [3.112880652414753], [2.9254584889865693], [2.6839253182990475], [2.5416490334319763], [2.5668422922906484], [2.4695344089457185], [2.2562424437881545]]
# Bars above y=1.5: []

# %%
#Total Activity P08

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=4.5, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    #All plots degradation  Reaction Data
    
data2 = [[329.8535, 707.5613], [4798.0871, 2642.0552, 4735.5697, 3525.7053], [29690.1506], [21872.505], 
        [28303.5231], [25891.1649], [19368.4004], [15727.8704], [15042.6721], [15977.5712], [19269.079], 
        [4274.0992], [11988.2397], [10752.5493], [11481.6464],[11308.4889],[11250.7166],[9438.6448],[9675.1148],
        [10424.3881],[9533.0179],[8988.4433],[7848.0169],[9732.9464],[9087.9369],[7142.1622],[7916.1503],
        [7774.3852],[6311.5503],[7718.3959], [6807.0784],[7231.0833],[5899.5083]]

data1 = [[174.8547,615.1132], [4484.8369, 2461.7574, 4358.0153, 3662.8887], [29356.6536], [34387.4045], 
        [22155.7827], [19785.5238], [13813.4733], [15752.1493], [13914.7806], [12113.5195], [6529.7027], 
        [19543.9063], [10641.0267], [11857.1497], [10618.563],[10133.6561],[9917.957],[10773.0998],[10320.9052],
        [8852.9632],[9085.3679],[8835.1854],[9197.9067],[8115.8472],[7267.3147],[8988.0323],[7359.7983],
        [7063.806],[8411.6299],[6621.3945], [7351.8344],[6427.7296],[7077.2343]]
     
labels = ['P08 Sterile', 'P08 Parent (HetCPIII)', 'P08 G11', 'P08 G4',  'P08 D2', 'P08 A12',   
          'P08 G9', 'P08 F11', 'P08 H10', 'P08 A10', 'P08 E2', 'P08 A5', 
          'P08 D12', 'P08 E8', 'P08 D10', 'P08 B11', 'P08 A11', 'P08 G12', 'P08 F12', 
         'P08 F3','P08 C12', 'P08 C1', 'P08 H11', 'P08 A7', 'P08 F10', 
         'P08 H2', 'P08 E10', 'P08 E3', 'P08 C10', 'P08 B9', 'P08 E12' , 'P08 B8' , 'P08 H12']

# Ensure data1 and data2 have the same shape
if len(data1) != len(data2):
    raise ValueError("Arrays must have the same length")

data = []
for arr1, arr2 in zip(data1, data2):
    if len(arr1) != len(arr2):
        raise ValueError("Sub-arrays must have the same length")
    data.append([x + y for x, y in zip(arr1, arr2)])
plot_histogram_with_std(data, labels)

len(labels)
print(data)
# Out:
# [[504.70820000000003, 1322.6745], [9282.923999999999, 5103.812599999999, 9093.585, 7188.594], [59046.8042], [56259.909499999994], [50459.3058], [45676.6887], [33181.8737], [31480.019699999997], [28957.4527], [28091.0907], [25798.7817], [23818.0055], [22629.2664], [22609.699], [22100.2094], [21442.145], [21168.673600000002], [20211.744599999998], [19996.019999999997], [19277.351300000002], [18618.3858], [17823.6287], [17045.9236], [17848.7936], [16355.2516], [16130.194500000001], [15275.9486], [14838.1912], [14723.180199999999], [14339.790400000002], [14158.9128], [13658.8129], [12976.742600000001]]

# %%
#Normalized Total Activity (P08)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_histogram_with_std(data, labels):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    df = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]
    
    # Plot histogram with error bars
    ax = sns.barplot(x='Conditions', y='Mean', data=df, alpha=0.7, palette=colors)
    ax.errorbar(
        range(len(labels)),
        df['Mean'],
        yerr=df['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add a horizontal threshold line at y=1.5
    plt.axhline(y=1.5, color='red', linestyle='--')

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('Normalized Total Activity')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(len(labels)), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio', '\n2-CH Functio') for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(len(labels)), labels, fontsize=5.8, rotation=45, ha='right')
    plt.tight_layout()
    # Add legend
    blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
    green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
    plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

    # Adjust y-axis limits
    plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
    plt.show()


# All plots degradation Reaction Data
data = [[504.70820000000003, 1322.6745], [9282.923999999999, 5103.812599999999, 9093.585, 7188.594], [59046.8042], [56259.909499999994],
        [50459.3058], [45676.6887], [33181.8737], [31480.019699999997], [28957.4527], [28091.0907], [25798.7817], [23818.0055], [22629.2664], [22609.699], 
        [22100.2094], [21442.145], [21168.673600000002], [20211.744599999998], [19996.019999999997], [19277.351300000002], [18618.3858], [17823.6287], [17045.9236], 
        [17848.7936], [16355.2516], [16130.194500000001], 
        [15275.9486], [14838.1912], [14723.180199999999], [14339.790400000002], [14158.9128], [13658.8129], [12976.742600000001]]

labels = ['P08 Sterile', 'P08 Parent (HetCPIII)', 'P08 G11', 'P08 G4',  'P08 D2', 'P08 A12',   
          'P08 G9', 'P08 F11', 'P08 H10', 'P08 A10', 'P08 E2', 'P08 A5', 
          'P08 D12', 'P08 E8', 'P08 D10', 'P08 B11', 'P08 A11', 'P08 G12', 'P08 F12', 
         'P08 F3','P08 C12', 'P08 C1', 'P08 H11', 'P08 A7', 'P08 F10', 
         'P08 H2', 'P08 E10', 'P08 E3', 'P08 C10', 'P08 B9', 'P08 E12' , 'P08 B8' , 'P08 H12']


# Divide the 1-7th elements by the average of the second element
data[0:33] = [[x / np.mean(data[1]) for x in sublist] for sublist in data[0:33]]

# Create a new variable with the updated values
normalized_data = data
print(normalized_data)
plot_histogram_with_std(normalized_data, labels)

# Print names of bars above y=1.5
above_threshold = [label for label, value in zip(labels, normalized_data[1]) if value > 1.5]
print("Bars above y=1.5:", above_threshold)
# Out:
# [[0.06582667696278117, 0.17251010987815954], [1.2107273854834306, 0.665665870494619, 1.1860328051507631, 0.9375739388711873], [7.701192304301754], [7.337710955779603], [6.581165954234131], [5.9573920768166975], [4.327753107775353], [4.10578842898508], [3.7767820783334125], [3.6637866256999323], [3.3648117248723333], [3.106468557368882], [2.951427001220741], [2.9488749188119328], [2.8824246267122664], [2.796596433947603], [2.7609288670121748], [2.6361211936688105], [2.607985265706623], [2.514252743908559], [2.4283070249800423], [2.3246506570320347], [2.22321829989972], [2.327932794598059], [2.13313725379974], [2.103784132491467], [1.9923689248406293], [1.9352743205566747], [1.920273985820353], [1.8702702876132997], [1.8466792872194022], [1.7814536487882868], [1.692494481285149]]
# Bars above y=1.5: []

# %%
#Z-Score Hit Identification Plate1

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverT
    8462.5922, 11843.9215, 20112.252, 17847.9682, 53680.2895, 724.6395, 7901.0641, 8401.7202, 4378.5549, 13558.6009,
    9878.9781, 1022.4875, 300.2542, 25153.8818, 228.2647, 21017.5609, 10317.5475, 18748.4278, 18250.2243, 495.3395,
    25161.712, 372.3721, 18583.5787, 23570.3361, 20545.6166, 29015.6739]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Filter variants with Z-score higher than 3
significant_variants = df_z_scores[df_z_scores['Z-score'] > 3]['Sample']

# Print the names of significant variants
print("Variants with Z-score > 3:")
for variant in significant_variants:
    print(variant)


# Show the plot
show(p_z_scores)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x0" value "D1B-A10", key "x1" value "D1B-H9" [renderer: GlyphRenderer(id='1054', ...)]
# Variants with Z-score > 3:
# D1B-B4
# D1B-D8
# D1B-E4
# D1B-G3
# D1B-H12
#   <div class="bk-root" id="12855495-8af1-48f3-957b-074c634535cc" data-root-id="1004"></div>

# %%
#Z-Score Hit Identification Plate2

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverT
                  10918.2595, 1679.3251, 1746.4153, 18757.5033, 1311.5462, 422.6546, 22939.5173,
                  11177.4822, 13150.4668, 257.3936, 19793.6999, 18824.4133, 15163.0557, 16570.4854,
                  412.0208, 24036.1683, 19810.2184]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)

# Filter variants with Z-score higher than 3
significant_variants = df_z_scores[df_z_scores['Z-score'] > 3]['Sample']

# Print the names of significant variants
print("Variants with Z-score > 3:")
for variant in significant_variants:
    print(variant)

# Show the plot
show(p_z_scores)

# %%
#Z-Score Hit Identification Plate3

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverT
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)


# Filter variants with Z-score higher than 3
significant_variants = df_z_scores[df_z_scores['Z-score'] > 3]['Sample']

# Print the names of significant variants
print("Variants with Z-score > 3:")
for variant in significant_variants:
    print(variant)

# Show the plot
show(p_z_scores)

# %%
#Z-Score Hit Identification Plate4

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Segment
from bokeh.plotting import figure, show



# Define the data
data = {
    'Sample': ['D1B-A1', 'D1B-A2', 'D1B-A3', 'D1B-A4', 'D1B-A5', 'D1B-A6', 'D1B-A7', 'D1B-A8', 'D1B-A9',
               'D1B-A10', 'D1B-A11', 'D1B-A12', 'D1B-B1', 'D1B-B2', 'D1B-B3', 'D1B-B4', 'D1B-B5', 'D1B-B6',
               'D1B-B7', 'D1B-B8', 'D1B-B9', 'D1B-B10', 'D1B-B11', 'D1B-B12', 'D1B-C1', 'D1B-C2', 'D1B-C3',
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)


# Filter variants with Z-score higher than 3
significant_variants = df_z_scores[df_z_scores['Z-score'] > 3]['Sample']

# Print the names of significant variants
print("Variants with Z-score > 3:")
for variant in significant_variants:
    print(variant)



# Show the plot
show(p_z_scores)

# %%
#Z-Score Hit Identification Plate5

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Segment
from bokeh.plotting import figure, show



# Define the data
data = {
    'Sample': ['D1B-A1', 'D1B-A2', 'D1B-A3', 'D1B-A4', 'D1B-A5', 'D1B-A6', 'D1B-A7', 'D1B-A8', 'D1B-A9',
               'D1B-A10', 'D1B-A11', 'D1B-A12', 'D1B-B1', 'D1B-B2', 'D1B-B3', 'D1B-B4', 'D1B-B5', 'D1B-B6',
               'D1B-B7', 'D1B-B8', 'D1B-B9', 'D1B-B10', 'D1B-B11', 'D1B-B12', 'D1B-C1', 'D1B-C2', 'D1B-C3',
               'D1B-C4', 'D1B-C5', 'D1B-C6', 'D1B-C7', 'D1B-C8', 'D1B-C9', 'D1B-C10', 'D1B-C11', 'D1B-C12',
               'D1B-D1', 'D1B-D2', 'D1B-D3', 'D1B-D4', 'D1B-D5', 'D1B-D6', 'D1B-D7', 'D1B-D8', 'D1B-D9',
               'D1B-D10', 'D1B-D11', 'D1B-D12', 'D1B-E1', 'D1B-E2', 'D1B-E3', 'D1B-E4', 'D1B-E5', 'D1B-E6',
               'D1B-E7', 'D1B-E8', 'D1B-E9', 'D1B-E10', 'D1B-E11', 'D1B-E12', 'D1B-F1', 'D1B-F2', 'D1B-F3',
               'D1B-F4', 'D1B-F5', 'D1B-F6', 'D1B-F7', 'D1B-F8', 'D1B-F9', 'D1B-F10', 'D1B-F11', 'D1B-F12',
               'D1B-G1', 'D1B-G2', 'D1B-G3', 'D1B-G4', 'D1B-G5', 'D1B-G6', 'D1B-G7', 'D1B-G8', 'D1B-G9',
               'D1B-G10', 'D1B-G11', 'D1B-G12', 'D1B-H1', 'D1B-H2', 'D1B-H3', 'D1B-H4', 'D1B-H5', 'D1B-H6',
               'D1B-H7', 'D1B-H8', 'D1B-H9', 'D1B-H10', 'D1B-H11', 'D1B-H12'],
    'Value':[128.6701, 17098.1678, 17646.3976, 20659.1986, 0, 0, 356.7612, 9546.7401, 18833.5859,
        115787.3573, 606.1192, 410.3285, 721.5561, 399.8078, 14587.085, 7183.2858, 6659.3612,
        10236.484, 9724.9208, 10456.956, 5935.7515, 10682.9502, 7757.3999, 175.534, 37965.3348,
        9062.0244, 6095.9816, 11313.8041, 8216.5295, 828.4932, 424.5568, 5431.2593, 8116.2017,
        372.1924, 9462.1375, 484.0522, 22748.4407, 19635.9062, 6284.4306, 5629.6522, 15250.6653,
        5987.8742, 2124.9373, 5671.9339, 1042.9203, 5849.0659, 57639.9708, 26712.9951,
        34197.7066, 14429.7913, 7714.7998, 10725.3229, 12514.6974, 8641.2415, 14016.178,
        8056.0828, 10348.3899, 779.9591, 2396.0618, 6316.1429, 119932.2865, 11994.8957,
        1510.0673, 9529.3119, 7199.3193, 9542.6039, 11473.6193, 6440.789, 4542.6412, 517.4846,
        14506.0817, 871.2412, 45319.427, 1750.9767, 426.5233, 12404.729, 3589.2899, 9427.9886,
        79564.2254, 7925.5591, 6314.0824, 16708.1836, 18842.3661, 12809.5772, 488.1308,
        11611.8519, 8142.1955, 25867.8958, 465.9155, 16417.052, 599.4172, 11391.9976,
        14083.5712, 515.1929, 13050.2343, 47554.1437]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)


# Filter variants with Z-score higher than 3
significant_variants = df_z_scores[df_z_scores['Z-score'] > 3]['Sample']

# Print the names of significant variants
print("Variants with Z-score > 3:")
for variant in significant_variants:
    print(variant)

# Show the plot
show(p_z_scores)

# %%
#Z-Score Hit Identification Plate6

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Segment
from bokeh.plotting import figure, show



# Define the data
data = {
    'Sample': ['D1B-A1', 'D1B-A2', 'D1B-A3', 'D1B-A4', 'D1B-A5', 'D1B-A6', 'D1B-A7', 'D1B-A8', 'D1B-A9',
               'D1B-A10', 'D1B-A11', 'D1B-A12', 'D1B-B1', 'D1B-B2', 'D1B-B3', 'D1B-B4', 'D1B-B5', 'D1B-B6',
               'D1B-B7', 'D1B-B8', 'D1B-B9', 'D1B-B10', 'D1B-B11', 'D1B-B12', 'D1B-C1', 'D1B-C2', 'D1B-C3',
               'D1B-C4', 'D1B-C5', 'D1B-C6', 'D1B-C7', 'D1B-C8', 'D1B-C9', 'D1B-C10', 'D1B-C11', 'D1B-C12',
               'D1B-D1', 'D1B-D2', 'D1B-D3', 'D1B-D4', 'D1B-D5', 'D1B-D6', 'D1B-D7', 'D1B-D8', 'D1B-D9',
               'D1B-D10', 'D1B-D11', 'D1B-D12', 'D1B-E1', 'D1B-E2', 'D1B-E3', 'D1B-E4', 'D1B-E5', 'D1B-E6',
               'D1B-E7', 'D1B-E8', 'D1B-E9', 'D1B-E10', 'D1B-E11', 'D1B-E12', 'D1B-F1', 'D1B-F2', 'D1B-F3',
               'D1B-F4', 'D1B-F5', 'D1B-F6', 'D1B-F7'],
    
    'Value':[710.8735, 4715.3019, 13460.7849, 535.4703, 12221.9641, 7571.7986, 6043.7177,
           7435.8967, 4672.2424, 23316.6236, 6665.5294, 6220.8592, 8699.3435, 9591.7176,
           6537.3617, 3983.7407, 735.3925, 255.6069, 9859.1432, 337.1105, 156.0875,
           7734.9981, 2735.8117, 9236.6988, 1415.0003, 188.082, 12009.5292, 4261.5965,
           2116.1904, 5915.2408, 3018.4255, 3413.1389, 3818.2087, 3855.6638, 17793.5493,
           172.3724, 1436.6354, 17798.5194, 5764.6195, 351.3613, 85263.7744, 3659.4114,
           10088.1507, 3329.0995, 238.3569, 3852.0825, 6638.1312, 174.1739, 6793.3625,
           2300.9156, 6330.1086, 100.6138, 3360.629, 3816.2268, 3793.7576, 3009.3329,
           1104.0966, 28072.5436, 14466.7624, 2731.7141, 132.8621, 11590.7993, 1488.8743,
           7388.7668, 7806.8786, 2923.7778, 10368.9209]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)


# Filter variants with Z-score higher than 3
significant_variants = df_z_scores[df_z_scores['Z-score'] > 3]['Sample']

# Print the names of significant variants
print("Variants with Z-score > 3:")
for variant in significant_variants:
    print(variant)

# Show the plot
show(p_z_scores)

# %%
#Z-Score Hit Identification Plate7

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverT
           258.7943, 0, 333.6756, 0, 574.9847, 242.6916, 19535.103, 0, 104.225,
           7789.1156, 12767.1733, 0, 6931.9014, 6733.4202, 822.6509, 17106.2606,
           1082.9762, 0, 397.0522, 0, 19553.9775, 8209.7607, 13481.8534, 0,
           346.4958, 1858.325, 5674.0409, 2466.0306, 142.5721]}


# Create a DataFrame from the data
df = pd.DataFrame(data)

# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)


# Filter variants with Z-score higher than 3
significant_variants = df_z_scores[df_z_scores['Z-score'] > 3]['Sample']

# Print the names of significant variants
print("Variants with Z-score > 3:")
for variant in significant_variants:
    print(variant)

# Show the plot
show(p_z_scores)

# %%
#Z-Score Hit Identification Plate8

import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverT
# Define steriles and parent_enzymes
steriles = ['D1B-A1', 'D1B-H1']
parent_enzymes = ['D1B-A2', 'D1B-C4', 'D1B-E6', 'D1B-G8']

# Exclude steriles and parent_enzymes
excluded_categories = steriles + parent_enzymes
filtered_df = df[~df['Sample'].isin(excluded_categories)]

# Extract parent_enzymes and their values
parent_enzymes_df = df[df['Sample'].isin(parent_enzymes)]

# Store parent_enzymes and values as separate variables
parent_enzymes_samples = parent_enzymes_df['Sample'].tolist()
parent_enzymes_values = parent_enzymes_df['Value'].tolist()

# Store the remaining samples and values
remaining_samples = filtered_df['Sample'].tolist()
remaining_values = filtered_df['Value'].tolist()

labels = remaining_samples
hit_assay_data = remaining_values
validation_assay_data = parent_enzymes_values


# Calculate element-wise Z-scores for the hit assay data against the validation assay data
z_scores = [(value - np.mean(validation_assay_data)) / np.std(validation_assay_data) for value in hit_assay_data]

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.5)

# Add hover tool to display sample labels and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@{Z-score}{0.000}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=3, y1=3, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-3, y1=-3, line_color='black', line_dash='dashed', line_width=1)
)

# Add a horizontal line at Z-score 0
z_score_line = Segment(x0=df_z_scores['Sample'].min(), y0=0, x1=df_z_scores['Sample'].max(), y1=0,
                       line_color='red', line_width=2, line_dash='dashed')

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '7px'
p_z_scores.yaxis.major_label_text_font_size = '15px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False
p_z_scores.add_glyph(z_score_line)


# Filter variants with Z-score higher than 3
significant_variants = df_z_scores[df_z_scores['Z-score'] > 3]['Sample']

# Print the names of significant variants
print("Variants with Z-score > 3:")
for variant in significant_variants:
    print(variant)

# Show the plot
show(p_z_scores)

# %%
#1-way ANOVA and variation between HetCPIII betweem plates (Tile 3 Experiment)

import pandas as pd
from scipy.stats import f_oneway
import numpy as np

# Sample data
plates = ['Plate1', 'Plate2', 'Plate3', 'Plate4', 'Plate5', 'Plate6', 'Plate7', 'Plate8']
enzyme_performance = [[17943.0884, 17322.0138, 14461.3583, 19137.2628],
                      [17572.8463, 18556.7563, 16969.3551, 19881.7846],
                      [28919.7813, 17650.1863, 11217.3279, 12281.0732],
                      [30114.854, 24713.2064, 26630.9387, 27728.6128],
                      [30114.854, 24713.2064, 26630.9387, 27728.6128],
                      [5689.4407, 6212.2138, 8861.4002, 8106.1888],
                      [13972.7262, 18861.8692, 15656.5803, 19175.6216],
                      [21694.6703, 21028.2304, 15559.9028, 14268.7582]]

# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

import seaborn as sns
import matplotlib.pyplot as plt

# Create a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df)

# Add labels and title
plt.xlabel('Plate')
plt.ylabel('Enzyme Performance')
plt.title('Enzyme Performance Across Plates')

# Display the plot
plt.show()
# Out:
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.26653626956073995
# p-value: 0.9610768424739721

# %%
import pandas as pd
from scipy.stats import f_oneway
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
plates = ['Plate 1', 'Plate 2', 'Plate 3', 'Plate 4', 'Plate 5', 'Plate 6', 'Plate 7', 'Plate 8']

enzyme_performance = [[9464.0281, 5101.5952, 6947.4182, 6619.0017] ,
                      [8532.213, 6030.996, 7094.8844, 5168.4942],
                      [9202.5996, 7869.6527, 8257.5057, 6070.0618],
                      [10683.9459, 17196.5719, 22250.7572, 9649.8978],
                      [8809.7253, 5753.8654, 4300.523, 3655.4001],
                      [2010.7137, 1986.8567, 1687.1624, 1687.1624],
                      [1279.1165,3415.3073, 2476.1516, 3792.4102],
                      [4798.0871, 2642.0552, 4735.5697, 3525.7053]]

# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

# Set the font size for better readability
plt.rcParams['font.size'] = 12

# Create a box plot with enhanced aesthetics
plt.figure(figsize=(10, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df, palette='Set3', width=0.6)

# Add labels and title
plt.xlabel('')
plt.ylabel('HetCPIII Total Activity (a.u.)')
plt.title('')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Increase the spacing between the plot and the x-axis labels
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.3102101602383859
# p-value: 0.9422235480222728

# %%
# HetCPIII normalized total activity across plates (JB-2-8)
import pandas as pd
from scipy.stats import f_oneway
import seaborn as sns
import matplotlib.pyplot as plt

array =  [[9464.0281, 5101.5952, 6947.4182, 6619.0017] ,
                      [8532.213, 6030.996, 7094.8844, 5168.4942],
                      [9202.5996, 7869.6527, 8257.5057, 6070.0618],
                      [10683.9459, 17196.5719, 22250.7572, 9649.8978],
                      [8809.7253, 5753.8654, 4300.523, 3655.4001],
                      [2010.7137, 1986.8567, 1687.1624, 1687.1624],
                      [1279.1165,3415.3073, 2476.1516, 3792.4102],
                      [4798.0871, 2642.0552, 4735.5697, 3525.7053]]

result = []

for sublist in array:
    average = np.mean(sublist)
    sublist_result = [x / average for x in sublist]
    result.append(sublist_result)

enzyme_performance = result

# Sample data
plates = ['Plate 1', 'Plate 2', 'Plate 3', 'Plate 4', 'Plate 5', 'Plate 6', 'Plate 7', 'Plate 8']

# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

# Set the font size for better readability
plt.rcParams['font.size'] = 12

# Create a box plot with enhanced aesthetics
plt.figure(figsize=(10, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df, palette='Set3', width=0.6)

# Add labels and title
plt.xlabel('')
plt.ylabel('Normalized Total Activity')
plt.title('')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Increase the spacing between the plot and the x-axis labels
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.8063710775552378
# p-value: 0.590367917509711

# %%
#1-ANOVA for the variation of hits between plates- Is total activity differences between plates similar as with parent? 


import pandas as pd
from scipy.stats import f_oneway
import numpy as np

def bootstrap(data, num_samples=1000):
    n = len(data)
    bootstrap_samples = []

    for _ in range(num_samples):
        resampled_data = np.random.choice(data, size=n, replace=True)
        bootstrap_samples.append(resampled_data)

    return bootstrap_samples

# Example usage:
sample_data = [710.8735, 4715.3019, 13460.7849, 535.4703, 12221.9641, 7571.7986, 6043.7177,
           7435.8967, 4672.2424, 23316.6236, 6665.5294, 6220.8592, 8699.3435, 9591.7176,
           6537.3617, 3983.7407, 735.3925, 255.6069, 9859.1432, 337.1105, 156.0875,
           7734.9981, 2735.8117, 9236.6988, 1415.0003, 188.082, 12009.5292, 4261.5965,
           2116.1904, 5915.2408, 3018.4255, 3413.1389, 3818.2087, 3855.6638, 17793.5493,
           172.3724, 1436.6354, 17798.5194, 5764.6195, 351.3613, 85263.7744, 3659.4114,
           10088.1507, 3329.0995, 238.3569, 3852.0825, 6638.1312, 174.1739, 6793.3625,
           2300.9156, 6330.1086, 100.6138, 3360.629, 3816.2268, 3793.7576, 3009.3329,
           1104.0966, 28072.5436, 14466.7624, 2731.7141, 132.8621, 11590.7993, 1488.8743,
           7388.7668, 7806.8786, 2923.7778, 10368.9209]  

bootstrapped_samples = bootstrap(sample_data, num_samples=27)

# Extend the original sample data with the bootstrapped samples
sample_data_extended = np.concatenate([sample_data] + bootstrapped_samples).tolist()

sample_data_6 = sample_data_extended[0:96]
print(sample_data_6)


# Sample data
plates = ['Plate 1', 'Plate 2', 'Plate 3', 'Plate 4', 'Plate 5', 'Plate 6', 'Plate 7', 'Plate 8']
enzyme_performance = [[313.4445, 20426.2547, 18820.5954, 3529.9095, 333.4167, 5101.0386, 5855.8447, 12198.3275, 5211.4723, 5792.7682,
    2490.1198, 17648.2993, 492.3807, 194.4023, 24015.5284, 33610.3954, 5787.8114, 6962.8825, 11710.8967, 24015.1392,
           425.6321, 7188.594, 33181.8737, 1006.5159, 59046.8042, 20211.7446,
           1322.6745, 16130.1945, 12866.9036, 1561.0669, 4201.9377,
           9314.0026, 1413.2825, 9817.3685, 625.6914, 28957.4527, 17045.9236,
           12976.7426]])


# Compute mean for indices 1, 27, 53, and 79 for the first array
indices = [1, 27, 53, 79]
first_array_mean = np.mean(array_of_arrays[0, indices])

# Divide all values of the first array by the computed average
array_of_arrays[0] /= first_array_mean

# Divide values for the remaining arrays
for i in range(1, len(array_of_arrays)):
    array_mean = np.mean(array_of_arrays[i, indices])
    array_of_arrays[i] /= array_mean
    
enzyme_performance = array_of_arrays

for i in range(len(enzyme_performance)):
    inner_array_length = len(enzyme_performance[i])
    print("Length of inner array", i, ":", inner_array_length)


# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

import seaborn as sns
import matplotlib.pyplot as plt

# Create a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df)

# Add labels and title
plt.xlabel('')
plt.ylabel('Normalized Total Activity')
plt.title('')

# Display the plot
plt.show()
# Out:
# Length of inner array 0 : 96
# Length of inner array 1 : 96
# Length of inner array 2 : 96
# Length of inner array 3 : 96
# Length of inner array 4 : 96
# Length of inner array 5 : 96
# Length of inner array 6 : 96
# Length of inner array 7 : 96
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.16624350448401615
# p-value: 0.991674932101118

# %%
import numpy as np
from scipy.stats import f_oneway

# Assuming you have the array data with dimensions (8, 96)
array_of_arrays = np.array([[313.4445, 20426.2547, 18820.5954, 3529.9095, 333.4167, 5101.0386, 5855.8447, 12198.3275, 5211.4723, 5792.7682,
    2490.1198, 17648.2993, 492.3807, 194.4023, 24015.5284, 33610.3954, 5787.8114, 6962.8825, 11710.8967, 24015.1392,
    1577.1447, 368.4128, 21560.0051, 3025.8003, 277.4132, 269.0979, 8606.6173, 10982.1653, 12470.2797, 15480.7618,
    2234.4556, 8978.0635, 334.0956, 163.7203, 2122.6566, 1703.8805, 17686.5081, 12069.4693, 17364.8326, 8680.9989,
    10634.8393, 17346.0306, 9269.6721, 45483.2588, 6111.3347, 9587.7502, 10953.6572, 4005.5475, 15475.3203, 8940.3936,
    9942.7712, 35979.1549, 204.3344, 14792.2009, 9058.7775, 4275.5608, 14881.4604, 14768.9675, 13904.4548, 2593.9082,
    6802.2236, 14908.3039, 16672.9642, 8161.5605, 9527.047, 5193.2788, 2005.8915, 140.4443, 11515.5137, 149.1451,
    8462.5922, 11843.9215, 20112.252, 17847.9682, 53680.2895, 724.6395, 7901.0641, 8401.7202, 4378.5549, 13558.6009,
    9878.9781, 1022.4875, 300.2542, 25153.8818, 228.2647, 21017.5609, 10317.5475, 18748.4278, 18250.2243, 495.3395,
           1322.6745, 16130.1945, 12866.9036, 1561.0669, 4201.9377,
           9314.0026, 1413.2825, 9817.3685, 625.6914, 28957.4527, 17045.9236,
           12976.7426]])




# Compute mean for indices 1, 27, 53, and 79 for the first array
indices = [1, 27, 53, 79]
first_array_mean = np.mean(array_of_arrays[0, indices])

# Divide all values of the first array by the computed average
array_of_arrays[0] /= first_array_mean

# Divide values for the remaining arrays
for i in range(1, len(array_of_arrays)):
    array_mean = np.mean(array_of_arrays[i, indices])
    array_of_arrays[i] /= array_mean


# Extracting the edge values and the rest of the plate values
edge_values = np.concatenate((array_of_arrays[:, 1:12],  # A2-A12
                              array_of_arrays[1:7, 11],  # A12-G12
                              array_of_arrays[7, 1:12][::-1],  # H12-H2
                              array_of_arrays[1:7, 0][::-1]  # H2-A1
                              ), axis=None)

rest_values = array_of_arrays[1:7, 1:11].flatten()

# Creating a list of labels for the box plots
labels = ['Plate Edges', 'Rest of the Plate']

# Creating a list of data for the box plots
data = [edge_values, rest_values]

# Performing the one-way ANOVA
f_value, p_value = f_oneway(edge_values, rest_values)

# Printing the results
print("One-Way ANOVA:")
print("F-value:", f_value)
print("p-value:", p_value)

# Creating the box plots
plt.boxplot(data, labels=labels)

# Adding a title and labels to the plot
plt.title('')
plt.xlabel('')
plt.ylabel('Normalized Total Activity')

# Displaying the plot
plt.show()
# Out:
# One-Way ANOVA:
# F-value: 0.026704964650875792
# p-value: 0.870385739941367

# %%
##Bootstrap P06
import numpy as np
def bootstrap(data, num_samples=1000):
    n = len(data)
    bootstrap_samples = []

    for _ in range(num_samples):
        resampled_data = np.random.choice(data, size=n, replace=True)
        bootstrap_samples.append(resampled_data)

    return bootstrap_samples

# Example usage:
sample_data = [710.8735, 4715.3019, 13460.7849, 535.4703, 12221.9641, 7571.7986, 6043.7177,
           7435.8967, 4672.2424, 23316.6236, 6665.5294, 6220.8592, 8699.3435, 9591.7176,
           6537.3617, 3983.7407, 735.3925, 255.6069, 9859.1432, 337.1105, 156.0875,
           7734.9981, 2735.8117, 9236.6988, 1415.0003, 188.082, 12009.5292, 4261.5965,
           2116.1904, 5915.2408, 3018.4255, 3413.1389, 3818.2087, 3855.6638, 17793.5493,
           172.3724, 1436.6354, 17798.5194, 5764.6195, 351.3613, 85263.7744, 3659.4114,
           10088.1507, 3329.0995, 238.3569, 3852.0825, 6638.1312, 174.1739, 6793.3625,
           2300.9156, 6330.1086, 100.6138, 3360.629, 3816.2268, 3793.7576, 3009.3329,
           1104.0966, 28072.5436, 14466.7624, 2731.7141, 132.8621, 11590.7993, 1488.8743,
           7388.7668, 7806.8786, 2923.7778, 10368.9209]  

bootstrapped_samples = bootstrap(sample_data, num_samples=27)

# Extend the original sample data with the bootstrapped samples
sample_data_extended = sample_data.copy()
sample_data_extended.extend(bootstrap_sample for bootstrap_sample in bootstrapped_samples)

print(sample_data_extended)

# %%
##Bootstrap P06


a = [710.8735, 4715.3019, 13460.7849, 535.4703, 12221.9641, 7571.7986, 6043.7177,
           7435.8967, 4672.2424, 23316.6236, 6665.5294, 6220.8592, 8699.3435, 9591.7176,
           6537.3617, 3983.7407, 735.3925, 255.6069, 9859.1432, 337.1105, 156.0875,
           7734.9981, 2735.8117, 9236.6988, 1415.0003, 188.082, 12009.5292, 4261.5965,
           2116.1904, 5915.2408, 3018.4255, 3413.1389, 3818.2087, 3855.6638, 17793.5493,
           172.3724, 1436.6354, 17798.5194, 5764.6195, 351.3613, 85263.7744, 3659.4114,
           10088.1507, 3329.0995, 238.3569, 3852.0825, 6638.1312, 174.1739, 6793.3625,
           2300.9156, 6330.1086, 100.6138, 3360.629, 3816.2268, 3793.7576, 3009.3329,
           1104.0966, 28072.5436, 14466.7624, 2731.7141, 132.8621, 11590.7993, 1488.8743,
           7388.7668, 7806.8786, 2923.7778, 10368.9209]


print(len(a))
print(96-len(a))

# %%
import numpy as np

def bootstrap(data, num_samples=1000):
    n = len(data)
    bootstrap_samples = []

    for _ in range(num_samples):
        resampled_data = np.random.choice(data, size=n, replace=True)
        bootstrap_samples.append(resampled_data)

    return bootstrap_samples

# Example usage:
sample_data = [710.8735, 4715.3019, 13460.7849, 535.4703, 12221.9641, 7571.7986, 6043.7177,
           7435.8967, 4672.2424, 23316.6236, 6665.5294, 6220.8592, 8699.3435, 9591.7176,
           6537.3617, 3983.7407, 735.3925, 255.6069, 9859.1432, 337.1105, 156.0875,
           7734.9981, 2735.8117, 9236.6988, 1415.0003, 188.082, 12009.5292, 4261.5965,
           2116.1904, 5915.2408, 3018.4255, 3413.1389, 3818.2087, 3855.6638, 17793.5493,
           172.3724, 1436.6354, 17798.5194, 5764.6195, 351.3613, 85263.7744, 3659.4114,
           10088.1507, 3329.0995, 238.3569, 3852.0825, 6638.1312, 174.1739, 6793.3625,
           2300.9156, 6330.1086, 100.6138, 3360.629, 3816.2268, 3793.7576, 3009.3329,
           1104.0966, 28072.5436, 14466.7624, 2731.7141, 132.8621, 11590.7993, 1488.8743,
           7388.7668, 7806.8786, 2923.7778, 10368.9209]  

bootstrapped_samples = bootstrap(sample_data, num_samples=27)

# Extend the original sample data with the bootstrapped samples
sample_data_extended = np.concatenate([sample_data] + bootstrapped_samples).tolist()

sample_data_6 = sample_data_extended[0:95]
print(sample_data_6)

# %%
#Hit Identification Plots with Sequence Information (JB-2-8)

import matplotlib.pyplot as plt


data = [
    ["Parent", 1],
    ["L142P, K191R", 2.642043628],
    ["L142P", 2.089966714],
    ["Y189C", 1.952369583],
    ["Parent", 1],
    ["A183V, W185R", 2.501519513],
    ["Parent", 1],
    ["I149T, Y171C, F175C", 1.526106594],
    ["Parent", 1],
    ["L142P", 4.377705428],
    ["W185R", 4.226409396],
    ["L142P", 2.904211631],
    ["G162D, W185R", 2.103943987],
    ["I149T", 1.735796416],
    ["Parent", 1],
    ["Y147H, W185R", 11.81337798],
    ["I153T", 3.889477925],
    ["G169V", 2.466001987],
    ["I146T", 2.004383849],
    ["Parent", 1],
    ["I153T", 2.309725377],
    ["Parent", 1],
    ["E165K, W185R, Y189H", 3.255439459],
    ["P135L, R140H, W185R", 3.101789027],
    ["I153T", 2.781983164],
    ["I153T", 2.518302164],
    ["Y189H", 1.829422988],
    ["F156Y, P188T", 1.596517126],
    ["Y147H", 1.548751814]
]

import matplotlib.pyplot as plt
import numpy as np

# Extract labels and numerical values from the nested array
labels = []
values = []
parent_indices = []
parent_colors = []

for i, row in enumerate(data):
    label, value = row
    if label == "Parent":
        parent_indices.append(i)
        parent_colors.append('green')
    labels.append(label)
    values.append(value)

# Set up figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create histogram
bar_colors = plt.cm.get_cmap('viridis')(np.linspace(0.2, 0.8, len(labels)))
ax.bar(labels, values, edgecolor='black', alpha=0.8, color=bar_colors)

# Define custom colors for the histograms
custom_colors = ['green'] + ['blue'] * (len(labels) - 1)

# Create histogram with custom colors
for i, value in enumerate(values):
    if i in parent_indices:
        ax.bar(labels[i], value, edgecolor='black', alpha=0.8, color='green')
    else:
        ax.bar(labels[i], value, edgecolor='black', alpha=0.8, color='blue')

# Set parent bars color
for idx, color in zip(parent_indices, parent_colors):
    ax.get_children()[idx].set_color(color)


# Set labels and title
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity', fontsize=12)  # Increase the font size here
ax.set_title('')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.5)

# Add a horizontal line at the value of 1.5
ax.axhline(1.5, color='red', linestyle='--', linewidth=2, label='1.5 fold')

# Add a legend
ax.legend()


# Adjust the plot layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
labels_validated = ['Parent', 'P02 H8', 'P02 H2', 'P03 F1', 'P03 C1', 'P05 D12', 'P05 C10', 'P05 H6', 'P06 E11']
data_validated = [
    [14934.2604, 9530.7726, 21409.4894],
    [37141.8132, 15137.506, 28332.3944],
    [32042.6802, 6530.1392, 10226.942],
    [19992.8333, 15450.6379, 16400.6482],
    [37286.6548, 10518.9244, 10238.0644],
    [18382.0025, 4330.6847, 14426.2856],
    [15941.9741, 27868.4602, 15084.5704],
    [19419.5954, 17123.9468, 25332.3468],
    [27114.7242, 19625.8183, 23723.5849]
]

# Compute means and standard deviations
means = np.mean(data_validated, axis=1)
stds = np.std(data_validated, axis=1)

# Set up the figure and axes
fig, ax = plt.subplots()

# Plot the histogram bars
bar_width = 0.35
index = np.arange(len(labels_validated))
bars = ax.bar(index, means, bar_width, yerr=stds, alpha=0.5, capsize=4)

# Customize the plot
ax.set_xlabel('Labels')
ax.set_ylabel('Values')
ax.set_title('Histogram with Error Bars')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated)
ax.legend(['Data'])

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
labels_validated = ['Parent', 'P02 H8', 'P02 H2', 'P03 F1', 'P03 C1', 'P05 D12', 'P05 C10', 'P05 H6', 'P06 E11']
data_validated = [
    [14934.2604, 9530.7726, 21409.4894],
    [37141.8132, 15137.506, 28332.3944],
    [32042.6802, 6530.1392, 10226.942],
    [19992.8333, 15450.6379, 16400.6482],
    [37286.6548, 10518.9244, 10238.0644],
    [18382.0025, 4330.6847, 14426.2856],
    [15941.9741, 27868.4602, 15084.5704],
    [19419.5954, 17123.9468, 25332.3468],
    [27114.7242, 19625.8183, 23723.5849]
]

# Calculate ratios
first_element_average = np.mean(data_validated[0])
ratios = [np.mean(data) / first_element_average for data in data_validated]

# Set up the figure and axes
fig, ax = plt.subplots()

# Plot the histogram bars
bar_width = 0.35
index = np.arange(len(labels_validated))
bars = ax.bar(index, ratios, bar_width, alpha=0.5)

# Customize the plot
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity')
ax.set_title('')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated)
ax.legend(['Data'])

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Shapiro-Wilk test (Normality of data) & Levene's test (Homogeneity of Variance)

import scipy.stats as stats
import numpy as np

# Example data
data = np.array([[313.4445, 20426.2547, 18820.5954, 3529.9095, 333.4167, 5101.0386, 5855.8447, 12198.3275, 5211.4723, 5792.7682,
    2490.1198, 17648.2993, 492.3807, 194.4023, 24015.5284, 33610.3954, 5787.8114, 6962.8825, 11710.8967, 24015.1392,
    1577.1447, 368.4128, 21560.0051, 3025.8003, 277.4132, 269.0979, 8606.6173, 10982.1653, 12470.2797, 15480.7618,
    2234.4556, 8978.0635, 334.0956, 163.7203, 2122.6566, 1703.8805, 17686.5081, 12069.4693, 17364.8326, 8680.9989,
    10634.8393, 17346.0306, 9269.6721, 45483.2588, 6111.3347, 9587.7502, 10953.6572, 4005.5475, 15475.3203, 8940.3936,
    9942.7712, 35979.1549, 204.3344, 14792.2009, 9058.7775, 4275.5608, 14881.4604, 14768.9675, 13904.4548, 2593.9082,
    6802.2236, 14908.3039, 16672.9642, 8161.5605, 9527.047, 5193.2788, 2005.8915, 140.4443, 11515.5137, 149.1451,
    8462.5922, 11843.9215, 20112.252, 17847.9682, 53680.2895, 724.6395, 7901.0641, 8401.7202, 4378.5549, 13558.6009,
    9878.9781, 1022.4875, 300.2542, 25153.8818, 228.2647, 21017.5609, 10317.5475, 18748.4278, 18250.2243, 495.3395,
    25161.712, 372.3721, 18583.5787, 23570.3361, 20545.6166, 29015.6739],
                      [0, 18317.9607, 13760.5609, 20840.0054, 14712.4158, 2512.6349, 15983.1761, 14324.262,
                  235.8913, 45641.9385, 15139.393, 17707.9149, 1319.395, 10516.7169, 23525.2276,
                  19767.5611, 0, 255.4243, 7535.95, 6899.2446, 412.8875, 1131.9188, 12469.9756,
                  5377.7819, 19025.6197, 399.6957, 6783.3426, 13296.2531, 288.5898, 7825.6267,
                  1472.7328, 18130.3307, 8505.3563, 10886.0298, 16351.6574, 11046.4252, 8265.3657,
                  8359.0119, 4413.681, 3095.4774, 10119.6647, 10648.4998, 16999.2084, 9483.7082,
                  3727.6793, 16196.9239, 17797.2517, 11385.8025, 4422.1682, 10253.2037, 9033.8761,
                  11086.147, 5350.8043, 15456.882, 17575.0111, 22505.5702, 8264.392, 13049.4154,
                  13841.7541, 11379.0028, 9069.4723, 9008.7174, 3137.3483, 7750.2599, 10409.1826,
