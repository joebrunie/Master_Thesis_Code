# %%
# Validation Histograms Plate01 (JB-2-4) 


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_histogram_with_std(data, labels, sterile_values=None):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    if sterile_values is not None:
        labels = ['Sterile'] + labels
        mean = [sterile_values] + mean
        std_deviation = [0] + std_deviation

    # Ensure all arrays have the same length
    length = min(len(labels), len(mean), len(std_deviation))
    labels = labels[:length]
    mean = mean[:length]
    std_deviation = std_deviation[:length]

    df1 = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Convert 'Mean' column to numeric
    df1['Mean'] = pd.to_numeric(df1['Mean'], errors='coerce')

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.catplot(x='Conditions', y='Mean', data=df1, kind='bar', alpha=0.7, palette=colors, height=4, aspect=2)
    ax.ax.errorbar(
        range(length),
        df1['Mean'],
        yerr=df1['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(length), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(length), labels, fontsize=9.0, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


# Example usage
Monocyclopropanation_groups = [[1235.8944, 0],
                              [10754.6764, 7024.3869, 5349.0732],
                              [5627.3391, 4544.6597, 4209.1072],
                              [3653.0903, 4032.1194, 4849.0093],
                              [4464.5254, 4299.6654, 5445.4055],
                              [4650.8063, 4505.236, 5278.7667],
                              [6775.546, 4699.6971, 4808.1876],
                              [4882.5007, 2185.0921, 3726.6746],
                              [4411.6913, 4111.5427, 5565.3219],
                              [4874.7309, 4554.548, 3313.6228],
                              [4630.9465, 2650.1525, 6310.2984]]

Functionalization_groups = [[155.6016, 0],
                            [9221.9875, 6084.8393, 3613.8257],
                            [4213.4027, 3842.3089, 3465.0402],
                            [2499.848, 3048.0868, 3365.8196],
                            [4327.4118, 3522.0729, 2714.5327],
                            [3624.1615, 2875.1348, 3522.0745],
                            [4469.6943, 3210.4142, 2937.0171],
                            [3455.4893, 1893.0714, 1973.1595],
                            [2988.815, 2811.6734, 3358.6336],
                            [2823.4818, 2688.0615, 2031.8627],
                            [3341.278, 2590.7535, 5339.1118]]

Total_Activity = []

# Perform element-wise addition
for i in range(len(Monocyclopropanation_groups)):
    total_group = []
    for j in range(len(Monocyclopropanation_groups[i])):
        total_group.append(Monocyclopropanation_groups[i][j] + Functionalization_groups[i][j])
    Total_Activity.append(total_group)

labels = ['Sterile', 'Parent (HetCPIII)', 'P01 B6', 'P02 G12', 'P02 H5', 'P02 G4', 'P02 G3', 'P02 B6', 'P02 H3', 'P02 E3', 'P02 F3']
plot_histogram_with_std(Monocyclopropanation_groups, labels)
plot_histogram_with_std(Functionalization_groups, labels)
plot_histogram_with_std(Total_Activity, labels)


print(Total_Activity)
# Out:
# [[1391.4959999999999, 0], [19976.6639, 13109.226200000001, 8962.8989], [9840.7418, 8386.9686, 7674.1474], [6152.9383, 7080.2062000000005, 8214.8289], [8791.9372, 7821.7383, 8159.9382000000005], [8274.9678, 7380.3708, 8800.8412], [11245.240300000001, 7910.1113000000005, 7745.2047], [8337.99, 4078.1634999999997, 5699.8341], [7400.506300000001, 6923.2161, 8923.9555], [7698.2127, 7242.6095, 5345.4855], [7972.2245, 5240.906, 11649.410199999998]]

# %%
# Validation Histograms Plate02 (JB-2-4) 


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_histogram_with_std(data, labels, sterile_values=None):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    if sterile_values is not None:
        labels = ['Sterile'] + labels
        mean = [sterile_values] + mean
        std_deviation = [0] + std_deviation

    # Ensure all arrays have the same length
    length = min(len(labels), len(mean), len(std_deviation))
    labels = labels[:length]
    mean = mean[:length]
    std_deviation = std_deviation[:length]

    df1 = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Convert 'Mean' column to numeric
    df1['Mean'] = pd.to_numeric(df1['Mean'], errors='coerce')

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.catplot(x='Conditions', y='Mean', data=df1, kind='bar', alpha=0.7, palette=colors, height=4, aspect=2)
    ax.ax.errorbar(
        range(length),
        df1['Mean'],
        yerr=df1['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(length), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(length), labels, fontsize=9.0, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


# Example usage
Monocyclopropanation_groups = data = [[1638.4305, 326.8165], [7366.0962, 6848.8719], 
    [19577.2831, 8883.9985, 14995.5485],
    [16311.6697, 3591.2077, 5544.5898],
    [41640.0749, 26977.8709, 34988.8002],
    [4313.5172, 8576.9656, 7342.305],
    [10355.8908, 8227.202, 8577.5116],
    [19390.7684, 6117.5726, 5850.0433],
    [9504.615, 2380.7385, 7511.5366],
    [12354.4674, 12068.0063, 14122.7118],
    [21001.5802, 12805.9643, 12464.4627],
    [8965.5612, 14877.5967, 8135.4844],
    [3347.0457, 7681.8551, 6129.895],
    [11105.2531, 9377.4683, 13668.2707],
    [5795.6487, 7606.7039, 5391.1139],
    [5205.6915, 5532.9347, 4227.8433],
    [20293.8254, 14902.5008, 17870.4771],
    [3984.7102, 6398.3741, 3973.8549],
    [4694.1055, 5398.8218, 6744.6862],
    [8899.7147, 7230.536, 7120.7095],
    [10220.2937, 7230.536, 6577.057]
]

Functionalization_groups = data = [[397.4429, 243.6338], [5315.375, 5909.6859],
    [17564.5301, 6253.5075, 13336.8459],
    [15731.0105, 2938.9315, 4682.3522],
    [15950.2371, 9052.0032, 12818.8211],
    [3677.01, 6540.6476, 6440.8014],
    [9636.9425, 7223.4359, 7823.1366],
    [17895.8864, 4401.3518, 4388.0211],
    [8877.3875, 1949.9462, 6914.749],
    [28373.5273, 26953.9541, 34948.9216],
    [12782.1365, 6639.3926, 7260.1863],
    [6976.4129, 12990.8635, 6949.086],
    [6253.5075, 13336.8459, 2888.9426],
    [8314.3423, 7746.4785, 11664.0761],
    [5100.175, 5636.0692, 4543.1591],
    [3716.3676, 4474.7999, 3575.8367],
    [6820.8988, 4723.3175, 5853.1078],
    [3362.6035, 5375.2228, 3324.6309],
    [3353.2698, 4501.3956, 4578.9195],
    [6650.2961, 5128.7441, 5131.4061],
    [8620.1432, 6309.619, 5988.8809]
]

Total_Activity = []

# Perform element-wise addition
for i in range(len(Monocyclopropanation_groups)):
    total_group = []
    for j in range(len(Monocyclopropanation_groups[i])):
        total_group.append(Monocyclopropanation_groups[i][j] + Functionalization_groups[i][j])
    Total_Activity.append(total_group)

labels = [
    'Sterile', 'Parent (HetCPIII)', 'P02 H8', 'P02 H2', 'P03 G1',
    'P03 D12', 'P03 F01', 'P03 C01', 'P04 H02', 'P05 A09', 'P05 D12', 'P05 C10', 'P05 C09',
    'P05 H06', 'P05 F09', 'P05 G11', 'P06 E11', 'P06 C01', 'P06 B01', 'P06 B12', 'P06 E01'
]
plot_histogram_with_std(Monocyclopropanation_groups, labels)
plot_histogram_with_std(Functionalization_groups, labels)
plot_histogram_with_std(Total_Activity, labels)


print(Total_Activity)
# Out:
# [[2035.8734, 570.4503], [12681.4712, 12758.5578], [37141.813200000004, 15137.506, 28332.3944], [32042.680200000003, 6530.1392, 10226.942], [57590.312, 36029.8741, 47807.6213], [7990.5272, 15117.6132, 13783.1064], [19992.8333, 15450.6379, 16400.6482], [37286.654800000004, 10518.9244, 10238.0644], [18382.002500000002, 4330.6847, 14426.2856], [40727.9947, 39021.960399999996, 49071.6334], [33783.716700000004, 19445.3569, 19724.649], [15941.9741, 27868.4602, 15084.5704], [9600.5532, 21018.701, 9018.8376], [19419.5954, 17123.9468, 25332.3468], [10895.8237, 13242.7731, 9934.273000000001], [8922.0591, 10007.7346, 7803.68], [27114.7242, 19625.8183, 23723.5849], [7347.313700000001, 11773.5969, 7298.4858], [8047.3753, 9900.2174, 11323.6057], [15550.0108, 12359.2801, 12252.115600000001], [18840.4369, 13540.154999999999, 12565.9379]]

# %%
# Validation Histograms Plate03 (JB-2-4) 

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_histogram_with_std(data, labels, sterile_values=None):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    if sterile_values is not None:
        labels = ['Sterile'] + labels
        mean = [sterile_values] + mean
        std_deviation = [0] + std_deviation

    # Ensure all arrays have the same length
    length = min(len(labels), len(mean), len(std_deviation))
    labels = labels[:length]
    mean = mean[:length]
    std_deviation = std_deviation[:length]

    df1 = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Convert 'Mean' column to numeric
    df1['Mean'] = pd.to_numeric(df1['Mean'], errors='coerce')

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.catplot(x='Conditions', y='Mean', data=df1, kind='bar', alpha=0.7, palette=colors, height=4, aspect=2)
    ax.ax.errorbar(
        range(length),
        df1['Mean'],
        yerr=df1['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel('AUC (a.u)')
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(length), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(length), labels, fontsize=9.0, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


# Example usage
Monocyclopropanation_groups = [[392.5052, 349.7108], 
    [8039.3287, 5587.2997, 12067.0009],
    [5905.277, 3987.5903, 13662.5989],
    [7213.7085, 2468.8441, 3143.262],
    [8603.6906, 5140.015, 8021.0896],
    [10735.7026, 6089.7832, 7524.7196],
    [7467.985, 5957.6205, 9898.4783],
    [1890.4225, 1969.2858, 2551.0889],
    [28722.5176, 33538.0513, 41909.1935],
    [35532.6503, 27084.2498, 65243.5359],
    [15060.14, 9506.6418, 13961.9593],
    [6682.4645, 13433.7255, 17712.3234],
    [13880.8154, 8792.8674, 18106.0963],
    [24159.9511, 31050.2827, 30721.554],
    [3999.4541, 6601.3694, 6311.9245],
    [2867.2541, 2692.9946, 4029.2798],
    [3463.3606, 5738.3416, 9963.7666],
    [4503.3132, 10169.9625, 7821.559],
    [4336.4201, 7786.4194, 8965.5897],
    [6079.2082, 4559.5041, 11139.9648],
    [5569.7113, 14498.7654, 9509.5747]
]

Functionalization_groups = [[363.4674,289.6801], 
    [6894.9317, 3943.4729, 9342.4885],
    [4450.8537, 3158.4906, 11525.0756],
    [6254.0462, 1895.405, 2085.6462],
    [7894.2645, 4210.828, 6938.6968],
    [9825.6934, 4903.7285, 6083.1944],
    [7898.5779, 6983.8031, 10475.4899],
    [1574.418, 1719.623, 1995.4582],
    [9697.0151, 11674.5474, 16700.4807],
    [12332.4239, 9003.1749, 28647.3955],
    [13584.373, 7946.8631, 11863.207],
    [5191.1794, 12271.5962, 15830.1516],
    [10996.4443, 6102.5306, 13410.2004],
    [11509.0865, 15109.7312, 14421.6371],
    [3110.4464, 4496.418, 3810.7588],
    [2219.0088, 2111.4308, 3045.6696],
    [3205.3448, 4316.0444, 8678.079],
    [2833.2917, 8995.6289, 6531.5226],
    [2435.2878, 6416.1204, 7836.2417],
    [5132.3621, 3001.2092, 10629.5264],
    [4788.4292, 13182.8052, 8557.5144]
]


Total_Activity = []

# Perform element-wise addition
for i in range(len(Monocyclopropanation_groups)):
    total_group = []
    for j in range(len(Monocyclopropanation_groups[i])):
        total_group.append(Monocyclopropanation_groups[i][j] + Functionalization_groups[i][j])
    Total_Activity.append(total_group)

labels = ['Sterile', 
    'Parent (HetCPIII)', 'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 B4',
    'P07 G9', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A05', 'P08 A10', 'P08 F1',
    'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9'
]
plot_histogram_with_std(Monocyclopropanation_groups, labels)
plot_histogram_with_std(Functionalization_groups, labels)
plot_histogram_with_std(Total_Activity, labels)


print(Total_Activity)
# Out:
# [[755.9726, 639.3909], [14934.2604, 9530.7726, 21409.4894], [10356.1307, 7146.0809, 25187.6745], [13467.7547, 4364.2491, 5228.9082], [16497.9551, 9350.843, 14959.7864], [20561.396, 10993.5117, 13607.914], [15366.5629, 12941.4236, 20373.968200000003], [3464.8405, 3688.9088, 4546.5471], [38419.532699999996, 45212.5987, 58609.6742], [47865.0742, 36087.4247, 93890.9314], [28644.513, 17453.5049, 25825.1663], [11873.6439, 25705.3217, 33542.475], [24877.2597, 14895.398, 31516.2967], [35669.037599999996, 46160.0139, 45143.1911], [7109.9005, 11097.7874, 10122.6833], [5086.2629, 4804.4254, 7074.9493999999995], [6668.7054, 10054.385999999999, 18641.8456], [7336.6049, 19165.591399999998, 14353.081600000001], [6771.7079, 14202.539799999999, 16801.8314], [11211.5703, 7560.713299999999, 21769.4912], [10358.1405, 27681.5706, 18067.089099999997]]

# %%
# Validation Histograms Plate01 (JB-2-4) 

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_histogram_with_std(data, labels, sterile_values=None, y_label=''):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    if sterile_values is not None:
        labels = ['Sterile'] + labels
        mean = [sterile_values] + mean
        std_deviation = [0] + std_deviation

    # Ensure all arrays have the same length
    length = min(len(labels), len(mean), len(std_deviation))
    labels = labels[:length]
    mean = mean[:length]
    std_deviation = std_deviation[:length]

    df1 = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Convert 'Mean' column to numeric
    df1['Mean'] = pd.to_numeric(df1['Mean'], errors='coerce')

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

    # Plot histogram with error bars
    ax = sns.catplot(x='Conditions', y='Mean', data=df1, kind='bar', alpha=0.7, palette=colors, height=4, aspect=2)
    ax.ax.errorbar(
        range(length),
        df1['Mean'],
        yerr=df1['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Set labels and title
    plt.xlabel('')
    plt.ylabel(y_label, fontsize=10, va='center', labelpad=18)
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(length), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(length), labels, fontsize=9.0, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Example usage
Monocyclopropanation_groups = [
    [0.053436834],
    [1],
    [0.621801328],
    [0.541946776],
    [0.614385699],
    [0.624123305],
    [0.704052862],
    [0.466715829],
    [0.609152229],
    [0.550969668],
    [0.587656399]
]

Functionalization_groups = [
    [0.008223902],
    [1],
    [0.609224587],
    [0.471112421],
    [0.558332616],
    [0.529652495],
    [0.561139506],
    [0.386969752],
    [0.484080663],
    [0.398686356],
    [0.595705846]
]

Monocyclopropanation_2CHFunctionalization_Ratio = [
    [7.942684394],
    [1.222375206],
    [1.020643851],
    [1.150355524],
    [1.10039371],
    [1.17836376],
    [1.254684182],
    [1.206078322],
    [1.258369267],
    [1.381962688],
    [0.986487547]
]

_2CHFunctionalization_Monocyclopropanation_Ratio = [[1/x[0]] for x in Monocyclopropanation_2CHFunctionalization_Ratio]


Total_Activity = []

# Perform element-wise addition
for i in range(len(Monocyclopropanation_groups)):
    total_group = []
    for j in range(len(Monocyclopropanation_groups[i])):
        total_group.append(Monocyclopropanation_groups[i][j] + Functionalization_groups[i][j])
    Total_Activity.append(total_group)

Total_Activity = np.array(Total_Activity)  # Convert to NumPy array
Total_Activity_2 = Total_Activity / 2  # Divide by 2

labels = ['Sterile', 'Parent (HetCPIII)', 'P01 B6', 'P02 G12', 'P02 H5', 'P02 G4', 'P02 G3', 'P02 B6', 'P02 H3', 'P02 E3', 'P02 F3']

plot_histogram_with_std(Monocyclopropanation_groups, labels, y_label='Norm.\nMonocyclopropanation')
plot_histogram_with_std(Functionalization_groups, labels, y_label='Norm.\n2-CH Functionalization')
plot_histogram_with_std(Total_Activity_2, labels, y_label='Norm.\nTotal Activity Ratio')
plot_histogram_with_std(Monocyclopropanation_2CHFunctionalization_Ratio, labels, y_label='Monocyclopropanation/\n2-CH Functionalization')
plot_histogram_with_std(_2CHFunctionalization_Monocyclopropanation_Ratio, labels, y_label='2-CH Functionalization/\nMonocyclopropanation')

# %%
# Validation Histograms Plate 02 (JB-2-4) 

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_histogram_with_std(data, labels, sterile_values=None, y_label='', background_lines=None):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    if sterile_values is not None:
        labels = ['Sterile'] + labels
        mean = [sterile_values] + mean
        std_deviation = [0] + std_deviation

    # Ensure all arrays have the same length
    length = min(len(labels), len(mean), len(std_deviation))
    labels = labels[:length]
    mean = mean[:length]
    std_deviation = std_deviation[:length]

    df1 = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Convert 'Mean' column to numeric
    df1['Mean'] = pd.to_numeric(df1['Mean'], errors='coerce')

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]
    
    # Plot histogram with error bars
    ax = sns.catplot(x='Conditions', y='Mean', data=df1, kind='bar', alpha=0.7, palette=colors, height=4, aspect=2)
    ax.ax.errorbar(
        range(length),
        df1['Mean'],
        yerr=df1['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

    # Add background lines
    if background_lines is not None:
        for line in background_lines:
            ax.axhline(line, color='gray', linestyle='dashed', linewidth=0.5)

    # Set labels and title
    plt.xlabel('')
    plt.ylabel(y_label, fontsize=10, va='center', labelpad=18)
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(length), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(length), labels, fontsize=9.0, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


# Example usage
Monocyclopropanation_groups = [
    [0.138251946],
    [1],
    [2.038078444],
    [1.193458755],
    [4.859044601],
    [0.948895918],
    [1.273803041],
    [1.47067439],
    [0.909693217],
    [1.807727612],
    [2.170107213],
    [1.499763821],
    [0.80472901],
    [1.601644682],
    [0.881393302],
    [0.701911271],
    [2.488775818],
    [0.673324958],
    [0.789665906],
    [1.090444947],
    [1.126881961]
]

Functionalization_groups = [
    [0.0571112],
    [1],
    [2.206662623],
    [1.38691418],
    [2.24622754],
    [0.989361165],
    [1.465976605],
    [1.584862036],
    [1.053718571],
    [5.361598409],
    [1.58465156],
    [1.598587461],
    [1.335066016],
    [1.646607067],
    [0.907457782],
    [0.698853177],
    [1.033243042],
    [0.716400401],
    [0.738442016],
    [1.004326922],
    [1.242377408]
]
Monocyclopropanation_2CHFunctionalization_Ratio = [
    [1.532770572],
    [1.266359998],
    [0.923602196],
    [0.860513774],
    [2.163202309],
    [0.95909962],
    [0.868910893],
    [0.92795105],
    [0.863317059],
    [0.337162069],
    [1.369453871],
    [0.938180649],
    [0.602763459],
    [0.97269392],
    [0.971277473],
    [1.004375876],
    [2.408703198],
    [0.939872391],
    [1.069367519],
    [1.085747004],
    [0.907036746]
]

_2CHFunctionalization_Monocyclopropanation_Ratio = [[1/x[0]] for x in Monocyclopropanation_2CHFunctionalization_Ratio]

Total_Activity = []

# Perform element-wise addition
for i in range(len(Monocyclopropanation_groups)):
    total_group = []
    for j in range(len(Monocyclopropanation_groups[i])):
        total_group.append(Monocyclopropanation_groups[i][j] + Functionalization_groups[i][j])
    Total_Activity.append(total_group)

Total_Activity = np.array(Total_Activity)  # Convert to NumPy array
Total_Activity_2 = Total_Activity / 2  # Divide by 2

labels = [
    'Sterile', 'Parent (HetCPIII)', 'P02 H8', 'P02 H2', 'P03 G1',
    'P03 D12', 'P03 F01', 'P03 C01', 'P04 H02', 'P05 A09', 'P05 D12', 'P05 C10', 'P05 C09',
    'P05 H06', 'P05 F09', 'P05 G11', 'P06 E11', 'P06 C01', 'P06 B01', 'P06 B12', 'P06 E01'
]



plot_histogram_with_std(Monocyclopropanation_groups, labels, y_label='Norm.\nMonocyclopropanation')
plot_histogram_with_std(Functionalization_groups, labels, y_label='Norm.\n2-CH Functionalization')
plot_histogram_with_std(Total_Activity_2, labels, y_label='Norm.\nTotal Activity Ratio')
plot_histogram_with_std(Monocyclopropanation_2CHFunctionalization_Ratio, labels, y_label='Monocyclopropanation/\n2-CH Functionalization')
plot_histogram_with_std(_2CHFunctionalization_Monocyclopropanation_Ratio, labels, y_label='2-CH Functionalization/\nMonocyclopropanation')

# %%
# Validation Histograms Plate 03 (JB-2-4) 

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_histogram_with_std(data, labels, sterile_values=None, y_label=''):
    # Calculate measures of data variation
    mean = [np.mean(d) for d in data]
    std_deviation = [np.std(d) for d in data]

    # Create a DataFrame for plotting with Seaborn
    if sterile_values is not None:
        labels = ['Sterile'] + labels
        mean = [sterile_values] + mean
        std_deviation = [0] + std_deviation

    # Ensure all arrays have the same length
    length = min(len(labels), len(mean), len(std_deviation))
    labels = labels[:length]
    mean = mean[:length]
    std_deviation = std_deviation[:length]

    df1 = pd.DataFrame({'Conditions': labels, 'Mean': mean, 'Std Deviation': std_deviation})

    # Convert 'Mean' column to numeric
    df1['Mean'] = pd.to_numeric(df1['Mean'], errors='coerce')

    # Define colors for the histograms (blue and green)
    colors = ['#800080' if i in [0] else '#008000' if i in [1] else '#1f77b4' for i in range(len(labels))]

     # Plot histogram with error bars
    ax = sns.catplot(x='Conditions', y='Mean', data=df1, kind='bar', alpha=0.7, palette=colors, height=4, aspect=2)
    ax.ax.errorbar(
        range(length),
        df1['Mean'],
        yerr=df1['Std Deviation'],
        fmt='none',
        capsize=4,
        capthick=1,
        ecolor='black',
    )

   
    # Set labels and title
    plt.xlabel('')
    plt.ylabel(y_label, fontsize=10, va='center', labelpad=18)
    plt.title('')

    # Adjust tick label font size and make labels appear on multiple lines
    plt.xticks(range(length), [label.replace('Product+EDA', '\u200bProduct+EDA').replace('Product', '\nProduct').replace('Monocyclo', '\nMonocyclo').replace('2-CH Functio','\n2-CH Functio' ) for label in labels], fontsize=10, wrap=True)
    plt.xticks(range(length), labels, fontsize=9.0, rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Example usage
Monocyclopropanation_groups = [
    [0.043330741],
    [1],
    [0.916782364],
    [0.499182675],
    [0.847089173],
    [0.947713735],
    [0.907776925],
    [0.249509212],
    [4.054303158],
    [4.976347814],
    [1.499544523],
    [1.472291554],
    [1.587155268],
    [3.344478384],
    [0.658246751],
    [0.373225923],
    [0.74592299],
    [0.875502423],
    [0.820764905],
    [0.847629459],
    [1.151182305]
]

Functionalization_groups = [
    [0.048546972],
    [1],
    [0.948145347],
    [0.507167713],
    [0.943654436],
    [1.031303035],
    [1.256528677],
    [0.262104317],
    [1.886539065],
    [2.47674838],
    [1.654755463],
    [1.649725165],
    [1.51178519],
    [2.033629265],
    [0.56576402],
    [0.365499642],
    [0.802713147],
    [0.909793393],
    [0.826903439],
    [0.929745656],
    [1.314547809]
]


Monocyclopropanation_2CHFunctionalization_Ratio = [
    [1.136368125],
    [1.273166117],
    [0.966921755],
    [0.984255626],
    [0.89766883],
    [0.918947878],
    [0.722448235],
    [0.951946214],
    [2.149069284],
    [2.009226231],
    [0.906203096],
    [0.892446563],
    [1.049855018],
    [1.644586081],
    [1.163465204],
    [1.021138956],
    [0.929252241],
    [0.962309058],
    [0.99257648],
    [0.911678859],
    [0.875724943]
]

_2CHFunctionalization_Monocyclopropanation_Ratio = [[1/x[0]] for x in Monocyclopropanation_2CHFunctionalization_Ratio]

Total_Activity = []

# Perform element-wise addition
for i in range(len(Monocyclopropanation_groups)):
    total_group = []
    for j in range(len(Monocyclopropanation_groups[i])):
        total_group.append(Monocyclopropanation_groups[i][j] + Functionalization_groups[i][j])
    Total_Activity.append(total_group)

Total_Activity = np.array(Total_Activity)  # Convert to NumPy array
Total_Activity_2 = Total_Activity / 2  # Divide by 2

labels = ['Sterile', 
    'Parent (HetCPIII)', 'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 B4',
    'P07 G9', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A05', 'P08 A10', 'P08 F1',
    'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9'
]

plot_histogram_with_std(Monocyclopropanation_groups, labels, y_label='Norm.\nMonocyclopropanation')
plot_histogram_with_std(Functionalization_groups, labels, y_label='Norm.\n2-CH Functionalization')
plot_histogram_with_std(Total_Activity_2, labels, y_label='Norm.\nTotal Activity Ratio')
plot_histogram_with_std(Monocyclopropanation_2CHFunctionalization_Ratio, labels, y_label='Monocyclopropanation/\n2-CH Functionalization')
plot_histogram_with_std(_2CHFunctionalization_Monocyclopropanation_Ratio, labels, y_label='2-CH Functionalization/\nMonocyclopropanation')

# %%
#Significance Test for Validation Assays (Validation Plate 01)

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt


labels = ['P01 B6', 'P02 G12', 'P02 H5', 'P02 G4', 'P02 G3', 'P02 B6', 'P02 H3', 'P02 E3', 'P02 F3']

# Assay data
hit_assay_data = [[31591.0771], [25071.3222], [25267.8074], [25467.7417], [25924.519], [26861.7201], [27422.9874], [29299.0667], [29558.7265]]

validation_assay_data = [[9840.7418, 8386.9686, 7674.1474], [6152.9383, 7080.2062000000005, 8214.8289], 
                         [8791.9372, 7821.7383, 8159.9382000000005], [8274.9678, 7380.3708, 8800.8412], 
                         [11245.240300000001, 7910.1113000000005, 7745.2047], [8337.99, 4078.1634999999997, 5699.8341], 
                         [7400.506300000001, 6923.2161, 8923.9555], [7698.2127, 7242.6095, 5345.4855], 
                         [7972.2245, 5240.906, 11649.410199999998]]

# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.05

# Convert the list of p-values to a pandas DataFrame
df_plate01 = pd.DataFrame(p_values, columns=['P-value'])
df_plate01['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate01)

# Create the scatter plot
p = figure(title='', x_range=df_plate01['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)


# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)

# Check if the p-value is less than the significance level
if p_value > alpha:
    print("The validation assay validated the hit identification.")
else:
    print("The validation assay did not validate the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="694cd8da-b8c2-4e5a-8aec-79104afb8def" data-root-id="1004"></div>
# The validation assay did not validate the hit identification.

# %%
#Significance Test for Validation Assays (Validation Plate 01) Alpha 0.05

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats

labels = ['P01 B6', 'P02 G12', 'P02 H5', 'P02 G4', 'P02 G3', 'P02 B6', 'P02 H3', 'P02 E3', 'P02 F3']

# Assay data
hit_assay_data = [[31591.0771], [25071.3222], [25267.8074], [25467.7417], [25924.519], [26861.7201], [27422.9874], [29299.0667], [29558.7265]]

validation_assay_data = [[9840.7418, 8386.9686, 7674.1474], [6152.9383, 7080.2062000000005, 8214.8289], 
                         [8791.9372, 7821.7383, 8159.9382000000005], [8274.9678, 7380.3708, 8800.8412], 
                         [11245.240300000001, 7910.1113000000005, 7745.2047], [8337.99, 4078.1634999999997, 5699.8341], 
                         [7400.506300000001, 6923.2161, 8923.9555], [7698.2127, 7242.6095, 5345.4855], 
                         [7972.2245, 5240.906, 11649.410199999998]]


# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.05

# Convert the list of p-values to a pandas DataFrame
df_plate = pd.DataFrame(p_values, columns=['P-value'])
df_plate['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate)

# Create the scatter plot
p = figure(title='', x_range=df_plate['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)

# Add threshold line
p.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=alpha, y1=alpha, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)

# Check if any p-values are less than the significance level
significant_p_values = df_plate[df_plate['P-value'] < alpha]

# Output the results
if len(significant_p_values) > 0:
    print("The following samples did not validate the hit identification:")
    for sample in significant_p_values['Sample']:
        print(sample)
else:
    print("All samples validated the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="69702">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bd479d0e-1760-4d09-826a-f6f60be6cae5" data-root-id="69704"></div>
# The following samples did not validate the hit identification:
# P01 B6
# P02 G12
# P02 H5
# P02 G4
# P02 G3
# P02 B6
# P02 H3
# P02 E3
# P02 F3

# %%
#Significance Test for Validation Assays (Validation Plate 01), Alpha = 0.01

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats

labels = ['P01 B6', 'P02 G12', 'P02 H5', 'P02 G4', 'P02 G3', 'P02 B6', 'P02 H3', 'P02 E3', 'P02 F3']

# Assay data
hit_assay_data = [[31591.0771], [25071.3222], [25267.8074], [25467.7417], [25924.519], [26861.7201], [27422.9874], [29299.0667], [29558.7265]]

validation_assay_data = [[9840.7418, 8386.9686, 7674.1474], [6152.9383, 7080.2062000000005, 8214.8289], 
                         [8791.9372, 7821.7383, 8159.9382000000005], [8274.9678, 7380.3708, 8800.8412], 
                         [11245.240300000001, 7910.1113000000005, 7745.2047], [8337.99, 4078.1634999999997, 5699.8341], 
                         [7400.506300000001, 6923.2161, 8923.9555], [7698.2127, 7242.6095, 5345.4855], 
                         [7972.2245, 5240.906, 11649.410199999998]]


# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.01

# Convert the list of p-values to a pandas DataFrame
df_plate = pd.DataFrame(p_values, columns=['P-value'])
df_plate['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate)

# Create the scatter plot
p = figure(title='', x_range=df_plate['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)

# Add threshold line
p.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=alpha, y1=alpha, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)

# Check if any p-values are less than the significance level
significant_p_values = df_plate[df_plate['P-value'] < alpha]

# Output the results
if len(significant_p_values) > 0:
    print("The following samples did not validate the hit identification:")
    for sample in significant_p_values['Sample']:
        print(sample)
else:
    print("All samples validated the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1100">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="01e16ced-956a-49ee-9e9a-4ec878df22d0" data-root-id="1102"></div>
# The following samples did not validate the hit identification:
# P01 B6
# P02 G12
# P02 H5
# P02 G4
# P02 G3
# P02 B6
# P02 H3
# P02 E3
# P02 F3

# %%
#Significance Test for Validation Assays (Validation Plate 02)

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

labels = ['P02 H8', 'P02 H2', 'P03 G1',
    'P03 D12', 'P03 F1', 'P03 C1', 'P04 H2', 'P05 A9', 'P05 D12', 'P05 C10', 'P05 C9',
    'P05 H6', 'P05 F9', 'P05 G11', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1'
]

# Assay data
hit_assay_data = [[29558.7265], [32508.6703], [42660.047], [29334.8007], 
        [28891.3216], [27614.5395],[33321.7714],[56066.5022], [13495.6603], [13222.5701], 
        [12282.9385], [11927.5555], [10842.0355], [10859.6124],[46806.2199], [30959.258], [30325.0097],
       [29900.8834], [29638.9238]]

validation_assay_data = [[37141.8132, 15137.506, 28332.3944], [32042.6802, 6530.1392, 10226.942], 
                           [57590.312, 36029.8741, 47807.6213], [7990.5272, 15117.6132, 13783.1064], 
                           [19992.8333, 15450.6379, 16400.6482], [37286.6548, 10518.9244, 10238.0644], 
                           [18382.0025, 4330.6847, 14426.2856], [40727.9947, 39021.9604, 49071.6334], 
                           [33783.7167, 19445.3569, 19724.649], [15941.9741, 27868.4602, 15084.5704], 
                           [9600.5532, 21018.701, 9018.8376], [19419.5954, 17123.9468, 25332.3468], 
                           [10895.8237, 13242.7731, 9934.273], [8922.0591, 10007.7346, 7803.68], 
                           [27114.7242, 19625.8183, 23723.5849], [7347.3137, 11773.5969, 7298.4858], 
                           [8047.3753, 9900.2174, 11323.6057], [15550.0108, 12359.2801, 12252.1156], 
                           [18840.4369, 13540.155, 12565.9379]]


# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.05

# Convert the list of p-values to a pandas DataFrame
df_plate = pd.DataFrame(p_values, columns=['P-value'])
df_plate['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate)

# Create the scatter plot
p = figure(title='', x_range=df_plate['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)


# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)

# Check if the p-value is less than the significance level
if p_value > alpha:
    print("The validation assay validated the hit identification.")
else:
    print("The validation assay did not validate the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1223">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c933718a-657c-43be-986a-e05fae363d66" data-root-id="1225"></div>
# The validation assay validated the hit identification.

# %%
#Significance Test for Validation Assays (Validation Plate 02) Alpha = 0.05

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats

labels = ['P02 H8', 'P02 H2', 'P03 G1',
    'P03 D12', 'P03 F1', 'P03 C1', 'P04 H2', 'P05 A9', 'P05 D12', 'P05 C10', 'P05 C9',
    'P05 H6', 'P05 F9', 'P05 G11', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1'
]

# Assay data
hit_assay_data = [[29558.7265], [32508.6703], [42660.047], [29334.8007], 
        [28891.3216], [27614.5395],[33321.7714],[56066.5022], [13495.6603], [13222.5701], 
        [12282.9385], [11927.5555], [10842.0355], [10859.6124],[46806.2199], [30959.258], [30325.0097],
       [29900.8834], [29638.9238]]

validation_assay_data = [[37141.8132, 15137.506, 28332.3944], [32042.6802, 6530.1392, 10226.942], 
                           [57590.312, 36029.8741, 47807.6213], [7990.5272, 15117.6132, 13783.1064], 
                           [19992.8333, 15450.6379, 16400.6482], [37286.6548, 10518.9244, 10238.0644], 
                           [18382.0025, 4330.6847, 14426.2856], [40727.9947, 39021.9604, 49071.6334], 
                           [33783.7167, 19445.3569, 19724.649], [15941.9741, 27868.4602, 15084.5704], 
                           [9600.5532, 21018.701, 9018.8376], [19419.5954, 17123.9468, 25332.3468], 
                           [10895.8237, 13242.7731, 9934.273], [8922.0591, 10007.7346, 7803.68], 
                           [27114.7242, 19625.8183, 23723.5849], [7347.3137, 11773.5969, 7298.4858], 
                           [8047.3753, 9900.2174, 11323.6057], [15550.0108, 12359.2801, 12252.1156], 
                           [18840.4369, 13540.155, 12565.9379]]


# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.05

# Convert the list of p-values to a pandas DataFrame
df_plate = pd.DataFrame(p_values, columns=['P-value'])
df_plate['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate)

# Create the scatter plot
p = figure(title='', x_range=df_plate['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)

# Add threshold line
p.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=alpha, y1=alpha, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)

# Check if any p-values are less than the significance level
significant_p_values = df_plate[df_plate['P-value'] < alpha]

# Store the samples that validated
validated_samples = []
if len(significant_p_values) > 0:
    validated_samples = list(significant_p_values['Sample'])

# Output the validated samples
if len(validated_samples) > 0:
    print("\nSamples that validated the hit identification:")
    for sample in validated_samples:
        print(sample)
else:
    print("\nNo samples validated the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3751">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3441fbdc-702f-41a4-aed9-a0a8f5fe2a2a" data-root-id="3753"></div>
# Samples that validated the hit identification:
# P03 G1
# P05 F9
# P05 G11
# P06 C1
# P06 B1

# %%
#Significance Test for Validation Assays (Validation Plate 02) Alpha = 0.01

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats

labels = ['P02 H8', 'P02 H2', 'P03 G1',
    'P03 D12', 'P03 F1', 'P03 C1', 'P04 H2', 'P05 A9', 'P05 D12', 'P05 C10', 'P05 C9',
    'P05 H6', 'P05 F9', 'P05 G11', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1'
]


labels_validated = ['P02 H8', 'P02 H2', 'P03 F1', 'P03 C1', 'P05 D12',  'P05 C10', 'P05 H6', 'P06 E11'] 

data_validated = [[37141.8132, 15137.506, 28332.3944],[32042.6802, 6530.1392, 10226.942], 
                  [19992.8333, 15450.6379, 16400.6482], [37286.6548, 10518.9244, 10238.0644],
                  [18382.0025, 4330.6847, 14426.2856], 
                  [15941.9741, 27868.4602, 15084.5704], [19419.5954, 17123.9468, 25332.3468], [27114.7242, 19625.8183, 23723.5849]]


# Assay data
hit_assay_data = [[29558.7265], [32508.6703], [42660.047], [29334.8007], 
        [28891.3216], [27614.5395],[33321.7714],[56066.5022], [13495.6603], [13222.5701], 
        [12282.9385], [11927.5555], [10842.0355], [10859.6124],[46806.2199], [30959.258], [30325.0097],
       [29900.8834], [29638.9238]]

validation_assay_data = [[37141.8132, 15137.506, 28332.3944], [32042.6802, 6530.1392, 10226.942], 
                           [57590.312, 36029.8741, 47807.6213], [7990.5272, 15117.6132, 13783.1064], 
                           [19992.8333, 15450.6379, 16400.6482], [37286.6548, 10518.9244, 10238.0644], 
                           [18382.0025, 4330.6847, 14426.2856], [40727.9947, 39021.9604, 49071.6334], 
                           [33783.7167, 19445.3569, 19724.649], [15941.9741, 27868.4602, 15084.5704], 
                           [9600.5532, 21018.701, 9018.8376], [19419.5954, 17123.9468, 25332.3468], 
                           [10895.8237, 13242.7731, 9934.273], [8922.0591, 10007.7346, 7803.68], 
                           [27114.7242, 19625.8183, 23723.5849], [7347.3137, 11773.5969, 7298.4858], 
                           [8047.3753, 9900.2174, 11323.6057], [15550.0108, 12359.2801, 12252.1156], 
                           [18840.4369, 13540.155, 12565.9379]]


# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.01

# Convert the list of p-values to a pandas DataFrame
df_plate = pd.DataFrame(p_values, columns=['P-value'])
df_plate['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate)

# Create the scatter plot
p = figure(title='', x_range=df_plate['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)

# Add threshold line
p.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=alpha, y1=alpha, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)
# Check if any p-values are less than the significance level
significant_p_values = df_plate[df_plate['P-value'] < alpha]

# Output the results
if len(significant_p_values) > 0:
    print("The following samples did not validate the hit identification:")
    for sample in significant_p_values['Sample']:
        print(sample)
else:
    print("All samples validated the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1359">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b3033295-d573-4a3b-9b57-271558ad2fb1" data-root-id="1361"></div>
# All samples validated the hit identification.

# %%
#Significance Test for Validation Assays (Validation Plate 03)

labels = ['P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 B4',
    'P07 G9', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A05', 'P08 A10', 'P08 F1',
    'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9'
]


# Assay data
hit_assay_data = [[28115.4122], [27239.6369], [24422.4788], [24233.5866], 
       [23562.0597], [69387.9402], [10268.9034],[63534.8877], [44913.2821], [44592.3982], [41207.7695], 
                    [39227.6964], [32183.366925], [31833.2845], 
                    [31343.4156], [26097.131], [28723.6512], [27508.9285], [25962.3513]]


  
validation_assay_data =[[10356.1307, 7146.0809, 25187.6745], [13467.7547, 4364.2491, 5228.9082], 
                    [16497.9551, 9350.843, 14959.7864], [20561.396, 10993.5117, 13607.914], 
                    [15366.5629, 12941.4236, 20373.9682], [3464.8405, 3688.9088, 4546.5471], 
                    [38419.5327, 45212.5987, 58609.6742], [47865.0742, 36087.4247, 93890.9314], 
                    [28644.513, 17453.5049, 25825.1663], [11873.6439, 25705.3217, 33542.475], 
                    [24877.2597, 14895.398, 31516.2967], [35669.0376, 46160.0139, 45143.1911], 
                    [7109.9005, 11097.7874, 10122.6833], [5086.2629, 4804.4254, 7074.9494], 
                    [6668.7054, 10054.386, 18641.8456], [7336.6049, 19165.5914, 14353.0816], 
                    [6771.7079, 14202.5398, 16801.8314], [11211.5703, 7560.7133, 21769.4912],
                    [10358.1405, 27681.5706, 18067.0891]]

# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.05

# Convert the list of p-values to a pandas DataFrame
df_plate = pd.DataFrame(p_values, columns=['P-value'])
df_plate['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate)

# Create the scatter plot
p = figure(title='', x_range=df_plate['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)

# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)

# Check if the p-value is less than the significance level
if p_value > alpha:
    print("The validation assay validated the hit identification.")
else:
    print("The validation assay did not validate the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1504">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d1bbbe68-535d-4ff2-a194-4c4b15432ad1" data-root-id="1506"></div>
# The validation assay validated the hit identification.

# %%
#Significance Test for Validation Assays (Validation Plate 03) Alpha = 0.05

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats

labels = ['P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 B4',
    'P07 G9', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A05', 'P08 A10', 'P08 F1',
    'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9'
]


# Assay data
hit_assay_data = [[28115.4122], [27239.6369], [24422.4788], [24233.5866], 
       [23562.0597], [69387.9402], [10268.9034],[63534.8877], [44913.2821], [44592.3982], [41207.7695], 
                    [39227.6964], [32183.366925], [31833.2845], 
                    [31343.4156], [26097.131], [28723.6512], [27508.9285], [25962.3513]]


  
validation_assay_data =[[10356.1307, 7146.0809, 25187.6745], [13467.7547, 4364.2491, 5228.9082], 
                    [16497.9551, 9350.843, 14959.7864], [20561.396, 10993.5117, 13607.914], 
                    [15366.5629, 12941.4236, 20373.9682], [3464.8405, 3688.9088, 4546.5471], 
                    [38419.5327, 45212.5987, 58609.6742], [47865.0742, 36087.4247, 93890.9314], 
                    [28644.513, 17453.5049, 25825.1663], [11873.6439, 25705.3217, 33542.475], 
                    [24877.2597, 14895.398, 31516.2967], [35669.0376, 46160.0139, 45143.1911], 
                    [7109.9005, 11097.7874, 10122.6833], [5086.2629, 4804.4254, 7074.9494], 
                    [6668.7054, 10054.386, 18641.8456], [7336.6049, 19165.5914, 14353.0816], 
                    [6771.7079, 14202.5398, 16801.8314], [11211.5703, 7560.7133, 21769.4912],
                    [10358.1405, 27681.5706, 18067.0891]]


# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.05

# Convert the list of p-values to a pandas DataFrame
df_plate = pd.DataFrame(p_values, columns=['P-value'])
df_plate['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate)

# Create the scatter plot
p = figure(title='', x_range=df_plate['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)

# Add threshold line
p.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=alpha, y1=alpha, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)

# Check if any p-values are less than the significance level
significant_p_values = df_plate[df_plate['P-value'] < alpha]

# Output the results
if len(significant_p_values) > 0:
    print("The following samples did not validate the hit identification:")
    for sample in significant_p_values['Sample']:
        print(sample)
else:
    print("All samples validated the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1225">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ff526a11-b274-44b5-8202-e82323a7814c" data-root-id="1227"></div>
# The following samples did not validate the hit identification:
# P06 C2
# P06 B2
# P06 E12
# P06 D9
# P06 A10
# P07 B4
# P08 C10
# P08 A10
# P08 F1
# P08 H10
# P08 H9
# P08 C3
# P08 C2

# %%
#Significance Test for Validation Assays (Validation Plate 03) Alpha = 0.01

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats

labels = ['P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 B4',
    'P07 G9', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A05', 'P08 A10', 'P08 F1',
    'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9'
]


# Assay data
hit_assay_data = [[28115.4122], [27239.6369], [24422.4788], [24233.5866], 
       [23562.0597], [69387.9402], [10268.9034],[63534.8877], [44913.2821], [44592.3982], [41207.7695], 
                    [39227.6964], [32183.366925], [31833.2845], 
                    [31343.4156], [26097.131], [28723.6512], [27508.9285], [25962.3513]]


  
validation_assay_data =[[10356.1307, 7146.0809, 25187.6745], [13467.7547, 4364.2491, 5228.9082], 
                    [16497.9551, 9350.843, 14959.7864], [20561.396, 10993.5117, 13607.914], 
                    [15366.5629, 12941.4236, 20373.9682], [3464.8405, 3688.9088, 4546.5471], 
                    [38419.5327, 45212.5987, 58609.6742], [47865.0742, 36087.4247, 93890.9314], 
                    [28644.513, 17453.5049, 25825.1663], [11873.6439, 25705.3217, 33542.475], 
                    [24877.2597, 14895.398, 31516.2967], [35669.0376, 46160.0139, 45143.1911], 
                    [7109.9005, 11097.7874, 10122.6833], [5086.2629, 4804.4254, 7074.9494], 
                    [6668.7054, 10054.386, 18641.8456], [7336.6049, 19165.5914, 14353.0816], 
                    [6771.7079, 14202.5398, 16801.8314], [11211.5703, 7560.7133, 21769.4912],
                    [10358.1405, 27681.5706, 18067.0891]]


# Perform statistical analysis (t-test) for each set of three values in the validation assay data against the hit assay data
p_values = []
for validation_values in validation_assay_data:
    _, p_value = stats.ttest_ind(hit_assay_data, validation_values)
    p_values.append(p_value)

# Set significance level
alpha = 0.01

# Convert the list of p-values to a pandas DataFrame
df_plate = pd.DataFrame(p_values, columns=['P-value'])
df_plate['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df_plate)

# Create the scatter plot
p = figure(title='', x_range=df_plate['Sample'], y_axis_label='p-value',
           plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p.circle('Sample', 'P-value', source=source, size=10, color='red', alpha=0.8)

# Add hover tool to display sample names and p-values
hover = HoverTool(tooltips=[('Sample', '@Sample'), ('P-value', '@{P-value}{0.2e}')])
p.add_tools(hover)

# Add threshold line
p.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=alpha, y1=alpha, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p.title.text_font_size = '16px'
p.title.align = 'center'
p.xaxis.major_label_text_font_size = '12px'
p.yaxis.major_label_text_font_size = '12px'
p.yaxis.formatter = PrintfTickFormatter(format='%.1e')
p.xaxis.major_label_orientation = 45
p.xgrid.visible = False
p.ygrid.visible = False

# Show the plot
show(p)

# Check if any p-values are less than the significance level
significant_p_values = df_plate[df_plate['P-value'] < alpha]

# Output the results
if len(significant_p_values) > 0:
    print("The following samples did not validate the hit identification:")
    for sample in significant_p_values['Sample']:
        print(sample)
else:
    print("All samples validated the hit identification.")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="76037">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="09368250-5cd8-429b-8b4d-8909912f79cd" data-root-id="76039"></div>
# The following samples did not validate the hit identification:
# P06 B2
# P07 B4
# P08 A10
# P08 F1

# %%
# Z-plot Factor (Validation Plate 01)
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats


labels = ['Negative Control', 'Parent (HetCPIII)', 'P01 B6', 'P02 G12', 'P02 H5', 'P02 G4', 'P02 G3', 'P02 B6', 'P02 H3', 'P02 E3', 'P02 F3']


# Assay data
hit_assay_data = [[0], [15452.54235], [31591.0771], [25071.3222], [25267.8074], [25467.7417], [25924.519], [26861.7201], [27422.9874], [29299.0667], [29558.7265]]

validation_assay_data = [[1391.496, 0], [19976.6639, 13109.2262, 8962.8989], [9840.7418, 8386.9686, 7674.1474], [6152.9383, 7080.2062000000005, 8214.8289], 
                         [8791.9372, 7821.7383, 8159.9382000000005], [8274.9678, 7380.3708, 8800.8412], 
                         [11245.240300000001, 7910.1113000000005, 7745.2047], [8337.99, 4078.1634999999997, 5699.8341], 
                         [7400.506300000001, 6923.2161, 8923.9555], [7698.2127, 7242.6095, 5345.4855], 
                         [7972.2245, 5240.906, 11649.410199999998]]

# Calculate Z-scores for each set of three values in the validation assay data
z_scores = []
for validation_values in validation_assay_data:
    z_score = (np.mean(validation_values) - np.mean(hit_assay_data)) / np.std(hit_assay_data)
    z_scores.append(z_score)

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.8)

# Add hover tool to display sample names and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@Z-score{0.2f}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=2, y1=2, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-2, y1=-2, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '12px'
p_z_scores.yaxis.major_label_text_font_size = '12px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False

# Show the Z-score plot
show(p_z_scores)


## The Z-score is a measure of how many standard deviations an observation or sample mean is away from the mean of a distribution. Typically, Z-scores between -2 and 2 are considered within the normal range, meaning they are close to the mean. 
#In the provided code, threshold lines are added at Z-score values of 2 and -2. These lines indicate a threshold beyond which Z-scores are considered statistically significant. 
#If a Z-score falls outside this range, it suggests that the corresponding sample mean deviates significantly from the mean of the hit assay data. #Therefore, in the Z-plot, Z-scores between 2 and -2 are considered within the normal range, indicating that the corresponding sample means are relatively close to the mean of the hit assay data. Z-scores outside this range indicate a significant deviation from the mean.
#It is important to note that the interpretation of Z-scores depends on the context and the underlying distribution of the data. The range of -2 to 2 for normality is a common convention, but it may vary depending on the specific application and domain knowledge.
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="53348">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="59df2365-1d6c-464c-a93a-33dbd7306d63" data-root-id="53350"></div>

# %%
# Z-plot Factor (Validation Plate 02)


from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats

labels = ['Negative Control', 'Parent (HetCPIII)', 'P02 H8', 'P02 H2', 'P03 G1',
    'P03 D12', 'P03 F1', 'P03 C1', 'P04 H2', 'P05 A9', 'P05 D12', 'P05 C10', 'P05 C9',
    'P05 H6', 'P05 F9', 'P05 G11', 'P06 E11', 'P06 C1', 'P06 B1', 'P06 B12', 'P06 E1'
]

# Assay data
hit_assay_data = [[80.6087875], [17694.12284], [29558.7265], [32508.6703], [42660.047], [29334.8007], 
        [28891.3216], [27614.5395],[33321.7714],[56066.5022], [13495.6603], [13222.5701], 
        [12282.9385], [11927.5555], [10842.0355], [10859.6124],[46806.2199], [30959.258], [30325.0097],
       [29900.8834], [29638.9238]]

validation_assay_data = [[2035.8734, 0], [12681.4712, 12758.5578], [37141.8132, 15137.506, 28332.3944], [32042.6802, 6530.1392, 10226.942], 
                           [57590.312, 36029.8741, 47807.6213], [7990.5272, 15117.6132, 13783.1064], 
                           [19992.8333, 15450.6379, 16400.6482], [37286.6548, 10518.9244, 10238.0644], 
                           [18382.0025, 4330.6847, 14426.2856], [40727.9947, 39021.9604, 49071.6334], 
                           [33783.7167, 19445.3569, 19724.649], [15941.9741, 27868.4602, 15084.5704], 
                           [9600.5532, 21018.701, 9018.8376], [19419.5954, 17123.9468, 25332.3468], 
                           [10895.8237, 13242.7731, 9934.273], [8922.0591, 10007.7346, 7803.68], 
                           [27114.7242, 19625.8183, 23723.5849], [7347.3137, 11773.5969, 7298.4858], 
                           [8047.3753, 9900.2174, 11323.6057], [15550.0108, 12359.2801, 12252.1156], 
                           [18840.4369, 13540.155, 12565.9379]]

# Calculate Z-scores for each set of three values in the validation assay data
z_scores = []
for validation_values in validation_assay_data:
    z_score = (np.mean(validation_values) - np.mean(hit_assay_data)) / np.std(hit_assay_data)
    z_scores.append(z_score)

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.8)

# Add hover tool to display sample names and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@Z-score{0.2f}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=2, y1=2, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-2, y1=-2, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '12px'
p_z_scores.yaxis.major_label_text_font_size = '12px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False

# Show the Z-score plot
show(p_z_scores)


## The Z-score is a measure of how many standard deviations an observation or sample mean is away from the mean of a distribution. Typically, Z-scores between -2 and 2 are considered within the normal range, meaning they are close to the mean. 
#In the provided code, threshold lines are added at Z-score values of 2 and -2. These lines indicate a threshold beyond which Z-scores are considered statistically significant. 
#If a Z-score falls outside this range, it suggests that the corresponding sample mean deviates significantly from the mean of the hit assay data. #Therefore, in the Z-plot, Z-scores between 2 and -2 are considered within the normal range, indicating that the corresponding sample means are relatively close to the mean of the hit assay data. Z-scores outside this range indicate a significant deviation from the mean.
#It is important to note that the interpretation of Z-scores depends on the context and the underlying distribution of the data. The range of -2 to 2 for normality is a common convention, but it may vary depending on the specific application and domain knowledge.
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="77339">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f9ca741d-385b-42ba-b1f1-e091349f7b76" data-root-id="77341"></div>

# %%
# Z-plot Factor (Validation Plate 03)
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, PrintfTickFormatter, Segment
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
from scipy import stats

labels = ['Negative Control', 'Parent (HetCPIII)', 'P06 C2', 'P06 B2', 'P06 E12', 'P06 D9', 'P06 A10', 'P07 B4',
    'P07 G9', 'P08 C10', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A05', 'P08 A10', 'P08 F1',
    'P08 H10', 'P08 H9', 'P08 C3', 'P08 C2', 'P08 C9'
]

# Assay data
hit_assay_data = [[0], [17185.76466], 
[28115.4122], [27239.6369], [24422.4788], [24233.5866], 
       [23562.0597], [69387.9402], [10268.9034],[63534.8877], [44913.2821], [44592.3982], [41207.7695], 
                    [39227.6964], [32183.366925], [31833.2845], 
                    [31343.4156], [26097.131], [28723.6512], [27508.9285], [25962.3513]]


  
validation_assay_data =[[755.9726,639.3909],  [[14934.2604, 9530.7726, 21409.4894]],  [10356.1307, 7146.0809, 25187.6745], [13467.7547, 4364.2491, 5228.9082], 
                    [16497.9551, 9350.843, 14959.7864], [20561.396, 10993.5117, 13607.914], 
                    [15366.5629, 12941.4236, 20373.9682], [3464.8405, 3688.9088, 4546.5471], 
                    [38419.5327, 45212.5987, 58609.6742], [47865.0742, 36087.4247, 93890.9314], 
                    [28644.513, 17453.5049, 25825.1663], [11873.6439, 25705.3217, 33542.475], 
                    [24877.2597, 14895.398, 31516.2967], [35669.0376, 46160.0139, 45143.1911], 
                    [7109.9005, 11097.7874, 10122.6833], [5086.2629, 4804.4254, 7074.9494], 
                    [6668.7054, 10054.386, 18641.8456], [7336.6049, 19165.5914, 14353.0816], 
                    [6771.7079, 14202.5398, 16801.8314], [11211.5703, 7560.7133, 21769.4912],
                    [10358.1405, 27681.5706, 18067.0891]]

# Calculate Z-scores for each set of three values in the validation assay data
z_scores = []
for validation_values in validation_assay_data:
    z_score = (np.mean(validation_values) - np.mean(hit_assay_data)) / np.std(hit_assay_data)
    z_scores.append(z_score)

# Convert the list of Z-scores to a pandas DataFrame
df_z_scores = pd.DataFrame(z_scores, columns=['Z-score'])
df_z_scores['Sample'] = labels

# Set up Bokeh
output_notebook()

# Create a ColumnDataSource from the DataFrame
source_z_scores = ColumnDataSource(df_z_scores)

# Create the Z-score plot
p_z_scores = figure(title='', x_range=df_z_scores['Sample'], y_axis_label='Z-score',
                    plot_width=800, plot_height=400, background_fill_color='white')

# Add scatter glyphs
p_z_scores.circle('Sample', 'Z-score', source=source_z_scores, size=10, color='blue', alpha=0.8)

# Add hover tool to display sample names and Z-scores
hover_z_scores = HoverTool(tooltips=[('Sample', '@Sample'), ('Z-score', '@Z-score{0.2f}')])
p_z_scores.add_tools(hover_z_scores)

# Add threshold lines
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=2, y1=2, line_color='black', line_dash='dashed', line_width=1)
)
p_z_scores.add_glyph(
    Segment(x0=-0.5, x1=len(labels)-0.5, y0=-2, y1=-2, line_color='black', line_dash='dashed', line_width=1)
)

# Customize plot aesthetics
p_z_scores.title.text_font_size = '16px'
p_z_scores.title.align = 'center'
p_z_scores.xaxis.major_label_text_font_size = '12px'
p_z_scores.yaxis.major_label_text_font_size = '12px'
p_z_scores.xaxis.major_label_orientation = 45
p_z_scores.xgrid.visible = False
p_z_scores.ygrid.visible = False

# Show the Z-score plot
show(p_z_scores)


## The Z-score is a measure of how many standard deviations an observation or sample mean is away from the mean of a distribution. Typically, Z-scores between -2 and 2 are considered within the normal range, meaning they are close to the mean. 
#In the provided code, threshold lines are added at Z-score values of 2 and -2. These lines indicate a threshold beyond which Z-scores are considered statistically significant. 
#If a Z-score falls outside this range, it suggests that the corresponding sample mean deviates significantly from the mean of the hit assay data. #Therefore, in the Z-plot, Z-scores between 2 and -2 are considered within the normal range, indicating that the corresponding sample means are relatively close to the mean of the hit assay data. Z-scores outside this range indicate a significant deviation from the mean.
#It is important to note that the interpretation of Z-scores depends on the context and the underlying distribution of the data. The range of -2 to 2 for normality is a common convention, but it may vary depending on the specific application and domain knowledge.
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="78672">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="54e64fe7-dc82-44ab-be13-e19f6e312b9c" data-root-id="78674"></div>

# %%
#The Z-score is a measure of how many standard deviations an observation or sample mean is away from the mean of a distribution. Typically, Z-scores between -2 and 2 are considered within the normal range, meaning they are close to the mean.
#In the provided code, threshold lines are added at Z-score values of 2 and -2. These lines indicate a threshold beyond which Z-scores are considered statistically significant. If a Z-score falls outside this range, it suggests that the corresponding sample mean deviates significantly from the mean of the hit assay data.
#Therefore, in the Z-plot, Z-scores between 2 and -2 are considered within the normal range, indicating that the corresponding sample means are relatively close to the mean of the hit assay data. Z-scores outside this range indicate a signifi3cant deviation from the mean.
#It is important to note that the interpretation of Z-scores depends on the context and the underlying distribution of the data. The range of -2 to 2 for normality is a common convention, but it may vary depending on the specific application and domain knowledge.

# %%
#Plate 02 Validated Plot (Most promising variants (Validated) 

data_validated =[[1], [2.112463881], [1.278818285], [1.358596968], [1.521058109], [1.91178300], [1.543368385], [1.621483712], [1.846542114]]


labels_validated = ['Parent', 
    'P02 H8',
    'P02 H2',
    'P03 F1',
    'P03 C1',
    'P05 D12',
    'P05 C10',
    'P05 H06',
    'P06 E11'
]


# Set up the figure and axes
fig, ax = plt.subplots()

# Plot the histogram bars
bar_width = 0.5
index = np.arange(len(labels_validated))
colors = ['green'] + ['blue'] * (len(labels_validated) - 1)  # Set colors for bars
bars = ax.bar(index, [item[0] for item in data_validated], bar_width, alpha=0.7, color=colors)

# Customize the plot
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity', fontsize=11)
ax.set_title('')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated, fontsize=10, rotation=45, ha='right')  # Set tilted x-axis labels

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')


# Set the y-axis range
ax.set_ylim([0, max([item[0] for item in data_validated]) * 1.2])  # Stretch the y-axis range by 20%

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Plate 03 Validated Plot (Most promising variants (Validated) 
import matplotlib.pyplot as plt
import numpy as np

labels_validated = ['Parent', 'P07 G9', 'P08 H12', 'P08 H11', 'P8 B12', 'P08 A5']
data_validated = [[1], [3.100671095], [1.567824152], [1.550347271], [1.553998836], [2.76781612]]


# Set up the figure and axes
fig, ax = plt.subplots()

# Plot the histogram bars
bar_width = 0.5
index = np.arange(len(labels_validated))
colors = ['green'] + ['blue'] * (len(labels_validated) - 1)  # Set colors for bars
bars = ax.bar(index, [item[0] for item in data_validated], bar_width, alpha=0.7, color=colors)

# Customize the plot
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity', fontsize=11)
ax.set_title('')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated, fontsize=10, rotation=45, ha='right')  # Set tilted x-axis labels

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')


# Set the y-axis range
ax.set_ylim([0, max([item[0] for item in data_validated]) * 1.2])  # Stretch the y-axis range by 20%

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Combined Data set (Validated Variants)


data_validated =[[1], [2.112463881], [1.278818285], [1.358596968], [1.521058109], [1.91178300], [1.543368385], [1.621483712], [1.846542114], 
                [1], [3.100671095], [1.567824152], [1.550347271], [1.553998836], [2.76781612]]


labels_validated = ['Parent', 
    'P02 H8',
    'P02 H2',
    'P03 F1',
    'P03 C1',
    'P05 D12',
    'P05 C10',
    'P05 H06',
    'P06 E11', 'Parent', 'P07 G9', 'P08 H12', 'P08 H11', 'P08 B12', 'P08 A5'
]

# Set up the figure and axes
fig, ax = plt.subplots()

# Plot the histogram bars
bar_width = 0.5
index = np.arange(len(labels_validated))
colors = ['green'] + ['blue'] * (len(labels_validated) - 1)  # Set colors for bars
bars = ax.bar(index, [item[0] for item in data_validated], bar_width, alpha=0.7, color=colors)

# Customize the plot
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity', fontsize=11)
ax.set_title('')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated, fontsize=10, rotation=45, ha='right')  # Set tilted x-axis labels

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')


# Set the y-axis range
ax.set_ylim([0, max([item[0] for item in data_validated]) * 1.2])  # Stretch the y-axis range by 20%

# Show the plot
plt.tight_layout()
 # Add legend
blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

# Adjust y-axis limits
plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5960\2208641625.py in <module>
#      51
#      52 # Adjust y-axis limits
# ---> 53 plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
#      54 plt.show()
#      55
#
# TypeError: 'numpy.float64' object is not iterable

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data_validated = [[0.99696987,
1.00303013], [2.919950539, 1.190054147, 2.227386958], [2.51907576, 0.513375138, 0.804003958], [1.571761833, 1.214671406, 1.289357665], 
[2.931337445, 0.826958523, 0.804878359], [2.655949543, 1.528721284, 1.550678185], [1.253298422, 2.190914185, 1.185892548], 
[1.526696011, 1.346220698, 1.991534428], [2.131658278, 1.542908485, 1.86505958], 
                [1, 0.638181761, 1.433582168], [2.572576858, 3.027441433, 3.924511334], [1.91804028, 1.168688936, 1.729256462], 
    [0.795060725, 1.721231652, 2.246008446], [1.665784514, 0.997397769, 2.110335287], [2.388403352, 3.090880476, 3.022793891]]

labels_validated = ['Parent', 'P02 H8', 'P02 H2', 'P03 F1', 'P03 C1', 'P05 D12', 'P05 C10', 'P05 H06', 'P06 E11',
                    'Parent', 'P07 G9', 'P08 H12', 'P08 H11', 'P8 B12', 'P08 A5']


# Set up the figure and axes
fig, ax = plt.subplots()

# Plot the histogram bars
bar_width = 0.5
index = np.arange(len(labels_validated))
colors = ['green'] + ['blue'] * (len(labels_validated) - 7) + ['green'] + ['blue'] +  ['blue']  + ['blue']+ ['blue'] + ['blue'] # Set colors for bars
bars = ax.bar(index, [item[0] for item in data_validated], bar_width, alpha=0.7, color=colors)

# Customize the plot
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity', fontsize=11)
ax.set_title('')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated, fontsize=10, rotation=45, ha='right')  # Set tilted x-axis labels

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')

# Set the y-axis range
ax.set_ylim([0, max([item[0] for item in data_validated]) * 1.2])  # Stretch the y-axis range by 20%

# Show the plot
plt.tight_layout()
 # Add legend
blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

# Adjust y-axis limits
plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18116\4206852584.py in <module>
#      45
#      46 # Adjust y-axis limits
# ---> 47 plt.ylim([0, max(mean) + max(std_deviation) + 0.5])
#      48 plt.show()
#
# NameError: name 'mean' is not defined

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data_validated = [[0.99696987, 1.00303013], [2.919950539, 1.190054147, 2.227386958], [2.51907576, 0.513375138, 0.804003958], [1.571761833, 1.214671406, 1.289357665], 
                [2.931337445, 0.826958523, 0.804878359], [2.655949543, 1.528721284, 1.550678185], [1.253298422, 2.190914185, 1.185892548], 
                [1.526696011, 1.346220698, 1.991534428], [2.131658278, 1.542908485, 1.86505958], 
                [1, 0.638181761, 1.433582168], [2.572576858, 3.027441433, 3.924511334], [1.91804028, 1.168688936, 1.729256462], 
                [0.795060725, 1.721231652, 2.246008446], [1.665784514, 0.997397769, 2.110335287], [2.388403352, 3.090880476, 3.022793891]]

labels_validated = ['Parent', 'P02 H8', 'P02 H2', 'P03 F1', 'P03 C1', 'P05 D12', 'P05 C10', 'P05 H06', 'P06 E11',
                    'Parent', 'P07 G9', 'P08 H12', 'P08 H11', 'P8 B12', 'P08 A5']


# Set up the figure and axes
fig, ax = plt.subplots()

# Plot each histogram with error bars
bar_width = 0.5
index = np.arange(len(labels_validated))
colors = ['green'] + ['blue'] * (len(labels_validated) - 7) + ['green'] + ['blue'] + ['blue'] + ['blue']+ ['blue'] + ['blue'] # Set colors for bars

for i, data in enumerate(data_validated):
    bars = ax.bar(index[i], [np.mean(data)], bar_width, alpha=0.7, color=colors[i], yerr=np.std(data))

# Customize the plot
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity', fontsize=11)
ax.set_title('')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated, fontsize=10, rotation=45, ha='right')  # Set tilted x-axis labels

# Add value labels to the bars
for container in bars:
    for bar in container:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')

# Set the y-axis range
ax.set_ylim([0, max(np.concatenate(data_validated)) * 1.2])  # Stretch the y-axis range by 20%

# Show the plot
plt.tight_layout()

# Add legend
blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

# Adjust y-axis limits
mean = np.mean(np.concatenate(data_validated))
std_deviation = np.std(np.concatenate(data_validated))
plt.ylim([0, mean + std_deviation + 0.5])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18116\2863234765.py in <module>
#      35 # Add value labels to the bars
#      36 for container in bars:
# ---> 37     for bar in container:
#      38         height = bar.get_height()
#      39         ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
#
# TypeError: 'Rectangle' object is not iterable

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data_validated = [[0.99696987, 1.00303013], [2.919950539, 1.190054147, 2.227386958], [2.51907576, 0.513375138, 0.804003958], [1.571761833, 1.214671406, 1.289357665], 
                [2.931337445, 0.826958523, 0.804878359], [2.655949543, 1.528721284, 1.550678185], [1.253298422, 2.190914185, 1.185892548], 
                [1.526696011, 1.346220698, 1.991534428], [2.131658278, 1.542908485, 1.86505958], 
                [1, 0.638181761, 1.433582168], [2.572576858, 3.027441433, 3.924511334], [1.91804028, 1.168688936, 1.729256462], 
                [0.795060725, 1.721231652, 2.246008446], [1.665784514, 0.997397769, 2.110335287], [2.388403352, 3.090880476, 3.022793891]]

labels_validated = ['Parent', 'P02 H8', 'P02 H2', 'P03 F1', 'P03 C1', 'P05 D12', 'P05 C10', 'P05 H06', 'P06 E11',
                    'Parent', 'P07 G9', 'P08 H12', 'P08 H11', 'P8 B12', 'P08 A5']


# Set up the figure and axes
fig, ax = plt.subplots()

# Plot each histogram with error bars
bar_width = 0.5
index = np.arange(len(labels_validated))
colors = ['green'] + ['blue'] * (len(labels_validated) - 7) + ['green'] + ['blue'] + ['blue'] + ['blue']+ ['blue'] + ['blue'] # Set colors for bars

for i, data in enumerate(data_validated):
    bars = ax.bar(index[i], [np.mean(data)], bar_width, alpha=0.7, color=colors[i], yerr=np.std(data))

    # Add value labels to the bars
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')

# Customize the plot
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity', fontsize=11)
ax.set_title('')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated, fontsize=10, rotation=45, ha='right')  # Set tilted x-axis labels

# Set the y-axis range
ax.set_ylim([0, max(np.concatenate(data_validated)) * 1.2])  # Stretch the y-axis range by 20%

# Show the plot
plt.tight_layout()

# Add legend
blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

# Adjust y-axis limits
mean = np.mean(np.concatenate(data_validated))
std_deviation = np.std(np.concatenate(data_validated))
plt.ylim([0, mean + std_deviation + 0.5])

plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data_validated = [[0.99696987, 1.00303013], [2.919950539, 1.190054147, 2.227386958], [2.51907576, 0.513375138, 0.804003958], [1.571761833, 1.214671406, 1.289357665], 
                [2.931337445, 0.826958523, 0.804878359], [2.655949543, 1.528721284, 1.550678185], [1.253298422, 2.190914185, 1.185892548], 
                [1.526696011, 1.346220698, 1.991534428], [2.131658278, 1.542908485, 1.86505958], 
                [1, 0.638181761, 1.433582168], [2.572576858, 3.027441433, 3.924511334], [1.91804028, 1.168688936, 1.729256462], 
                [0.795060725, 1.721231652, 2.246008446], [1.665784514, 0.997397769, 2.110335287], [2.388403352, 3.090880476, 3.022793891]]

labels_validated = ['Parent', 'P02 H8', 'P02 H2', 'P03 F1', 'P03 C1', 'P05 D12', 'P05 C10', 'P05 H06', 'P06 E11',
                    'Parent', 'P07 G9', 'P08 H12', 'P08 H11', 'P8 B12', 'P08 A5']


# Set up the figure and axes
fig, ax = plt.subplots()

# Compute the mean and standard deviation for each dataset
means = [np.mean(data) for data in data_validated]
stds = [np.std(data) for data in data_validated]

# Plot the grouped bar plot with error bars
bar_width = 0.5
index = np.arange(len(labels_validated))
colors = ['green'] + ['blue'] * (len(labels_validated) - 7) + ['green'] + ['blue'] + ['blue'] + ['blue']+ ['blue'] + ['blue'] # Set colors for bars

bars = ax.bar(index, means, bar_width, alpha=0.7, color=colors, yerr=stds, capsize=5)

# Customize the plot
ax.set_xlabel('')
ax.set_ylabel('Normalized Total Activity', fontsize=11)
ax.set_title('')
ax.set_xticks(index)
ax.set_xticklabels(labels_validated, fontsize=10, rotation=45, ha='right')  # Set tilted x-axis labels

# Set the y-axis range
ax.set_ylim([0, max(means) * 1.2])  # Stretch the y-axis range by 20%

# Show the plot
plt.tight_layout()

# Add legend
blue_patch = plt.Line2D([0], [0], color='#1f77b4', lw=4)
green_patch = plt.Line2D([0], [0], color='#2ca02c', lw=4)
plt.legend([blue_patch, green_patch], ['Variant', 'Parent'])

# Adjust y-axis limits
plt.ylim([0, max(means) + max(stds) + 0.5])

plt.show()

# %%
#Validation vs. Hit Plates 1-way ANOVA

import pandas as pd
from scipy.stats import f_oneway
import seaborn as sns
import matplotlib.pyplot as plt
import random
import numpy as np


import random

data = [17943.0884, 17322.0138, 14461.3583, 19137.2628,
        17572.8463, 18556.7563, 16969.3551, 19881.7846,
        28919.7813, 17650.1863, 11217.3279, 12281.0732,
        30114.854, 24713.2064, 26630.9387, 27728.6128,
        30114.854, 24713.2064, 26630.9387, 27728.6128,
        5689.4407, 6212.2138, 8861.4002, 8106.1888,
        13972.7262, 18861.8692, 15656.5803, 19175.6216,
        21694.6703, 21028.2304, 15559.9028, 14268.7582]

subsample_fraction = 0.25  # Fraction of data to be included in the subsample

subsample_size = int(subsample_fraction * len(data))
subsample = random.sample(data, subsample_size)

array = [[21028.2304, 21694.6703, 26630.9387, 30114.854, 27728.6128, 19137.2628, 17572.8463, 17322.0138], 
         [14934.2604, 9530.7726, 21409.4894, 12681.4712, 12758.5578, 19976.6639, 13109.226200000001, 8962.8989]]
array[0] = subsample

array = [[21028.2304, 21694.6703, 26630.9387, 30114.854, 27728.6128, 19137.2628, 17572.8463, 17322.0138], 
         [14934.2604, 9530.7726, 21409.4894, 12681.4712, 12758.5578, 19976.6639, 13109.226200000001, 8962.8989]]

result = []

for sublist in array:
    average = np.mean(sublist)
    sublist_result = [x / average for x in sublist]
    result.append(sublist_result)

enzyme_performance = result

# Sample data
plates = ['Hit Identification (Parent)', 'Hit Validation (Parent)']

# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(*[df.loc[df['Plate'] == plate, 'Enzyme Performance'] for plate in plates])

# Print the results
print("One-way ANOVA Results")
print("---------------------")
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

# Set the font size for better readability
plt.rcParams['font.size'] = 16

# Create a box plot with enhanced aesthetics
plt.figure(figsize=(10, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df, palette='Set3', width=0.6)

# Add labels and title
plt.xlabel('')
plt.ylabel('Normalized Total Activity')
plt.title('')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=0)

# Increase the spacing between the plot and the x-axis labels
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# One-way ANOVA Results
# ---------------------
# F-Statistic: 0.8835852560011355
# p-value: 0.3631581547444572

# %%
import random

data = [17943.0884, 17322.0138, 14461.3583, 19137.2628,
        17572.8463, 18556.7563, 16969.3551, 19881.7846,
        28919.7813, 17650.1863, 11217.3279, 12281.0732,
        30114.854, 24713.2064, 26630.9387, 27728.6128,
        30114.854, 24713.2064, 26630.9387, 27728.6128,
        5689.4407, 6212.2138, 8861.4002, 8106.1888,
        13972.7262, 18861.8692, 15656.5803, 19175.6216,
        21694.6703, 21028.2304, 15559.9028, 14268.7582]

subsample_fraction = 0.25  # Fraction of data to be included in the subsample

subsample_size = int(subsample_fraction * len(data))
subsample = random.sample(data, subsample_size)

print(subsample)
# Out:
# [6212.2138, 26630.9387, 19881.7846, 24713.2064, 12281.0732, 14461.3583, 18861.8692, 15656.5803]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
plates = ['Hit Identification (Parent)', 'Hit Validation (Parent)']

# Flatten the enzyme_performance list of lists
enzyme_performance_flat = [value for sublist in enzyme_performance for value in sublist]

# Create a DataFrame
df = pd.DataFrame({'Plate': plates * len(enzyme_performance[0]),
                   'Enzyme Performance': enzyme_performance_flat})

# Set the font size for better readability
plt.rcParams['font.size'] = 25

# Set the style and context of the plot
sns.set(style='ticks', context='notebook')

# Set the color palette
colors = ['#A6CEE3', '#1F78B4']

# Create a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Plate', y='Enzyme Performance', data=df, palette=colors, width=0.6)

# Add labels and title
plt.xlabel('')
plt.ylabel('Normalized Total Activity')
plt.title('')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=0)

# Remove the top and right spines
sns.despine()

# Adjust the plot layout
plt.tight_layout()

# Display the plot
plt.show()
